# %%
using HDF5

# %%
function read_omega_and_decay_rates(file, γᵢ)

    h5open(file,"r") do fid
        γ_group = open_group(fid, "gamma_"*γᵢ) # create coupling group   

        omega = read(γ_group["omega"])
        relaxation = read(γ_group["gamma_relaxation"])
        de_phasing = read(γ_group["gamma_de_phasing"])
        #exitation = read(γ_group["gamma_exitation"])
        de_polarisation = read(γ_group["gamma_de_polarisation"])

        return(omega, relaxation, de_phasing, de_polarisation)
        
    end
end
# Out:
# read_omega_and_decay_rates (generic function with 1 method)

# %%
file = "../TESTS/POP_LME_5_random_trn4_tst20_2024-Jan-16_at_16-36.h5"
gammas = ["0.079477", "0.25133", "0.79477", "2.5133", "7.9477", "25.133", "79.477", "251.33"]
# Out:
# 8-element Vector{String}:
#  "0.079477"
#  "0.25133"
#  "0.79477"
#  "2.5133"
#  "7.9477"
#  "25.133"
#  "79.477"
#  "251.33"

# %%
γᵢ = "0.079477"
# Out:
# "0.079477"

# %%
w, r, ϕ, p = read_omega_and_decay_rates(file, "0.079477")
# Out:
# (25.12611363705183, 0.07945784832167743, 7.459590438943091e-13, 5.4309948711488515e-6)

# %%
H = [ w   0
      0   0. ]

J₁ = [ 0   r
       0   0. ]

J₂ = ϕ * [ 1    0
           0   -1. ]

#J₃ = [ 0   0
#       e   0. ]

J₄ = p * [ 0    1
           1    0. ]

J₅ = p * [ 0   -im
           im   0  ]

J₆ = p * [ 1    0
           0   -1. ]
# Out:
# 2×2 Matrix{Float64}:
#  5.43099e-6   0.0
#  0.0         -5.43099e-6

# %%
include("../LiPoSID.jl")

data_dir = "../DATA/"
dodeca_files = ["State_D"*string(n) for n=1:20];
df = dodeca_files[11]

ρₛ, tₛ = LiPoSID.get_rho_series(data_dir*df*"_2CUT_data.h5", γᵢ)
# Out:
# (Any[ComplexF64[0.213696804984 + 0.0im -0.305946230303 + 0.269859962847im; -0.305946230303 - 0.269859962847im 0.786303195016 + 0.0im], ComplexF64[0.214907560795 + 0.0im -0.13821221632 + 0.383380758318im; -0.13821221632 - 0.383380758318im 0.785092439205 + 0.0im], ComplexF64[0.216219937126 + 0.0im 0.063426066747 + 0.401936453718im; 0.063426066747 - 0.401936453718im 0.783780062874 + 0.0im], ComplexF64[0.217586266601 + 0.0im 0.249061635171 + 0.321087002784im; 0.249061635171 - 0.321087002784im 0.782413733399 + 0.0im], ComplexF64[0.218969014286 + 0.0im 0.372823611919 + 0.160978211043im; 0.372823611919 - 0.160978211043im 0.781030985714 + 0.0im], ComplexF64[0.220324731245 + 0.0im 0.404211523796 - 0.038677365972im; 0.404211523796 + 0.038677365972im 0.779675268755 + 0.0im], ComplexF64[0.221625556008 + 0.0im 0.335611718522 - 0.228451897395im; 0.335611718522 + 0.228451897395im 0.778374443992 + 0.0im], ComplexF64[0.222872082684 + 0.0im 0.184143514594 - 0.361441154203im; 0.184143514594 + 0.361441154203im 0.777127917316 + 0.0im], ComplexF64[0.224074087553 + 0.0im -0.012612496999 - 0.404856457528im; -0.012612496999 + 0.404856457528im 0.7759259124469999 + 0.0im], ComplexF64[0.225241098527 + 0.0im -0.205938226523 - 0.348107091296im; -0.205938226523 + 0.348107091296im 0.774758901473 + 0.0im]  …  ComplexF64[0.89202410308 + 0.0im -0.051461703283 - 0.14156865155im; -0.051461703283 + 0.14156865155im 0.10797589691999998 + 0.0im], ComplexF64[0.892265885069 + 0.0im -0.11323992006 - 0.099070584383im; -0.11323992006 + 0.099070584383im 0.10773411493100005 + 0.0im], ComplexF64[0.892497970131 + 0.0im -0.146946075266 - 0.032236261524im; -0.146946075266 + 0.032236261524im 0.10750202986900004 + 0.0im], ComplexF64[0.892722946346 + 0.0im -0.14433040068 + 0.042398953289im; -0.14433040068 - 0.042398953289im 0.10727705365399998 + 0.0im], ComplexF64[0.892938274318 + 0.0im -0.1061144848 + 0.106426236794im; -0.1061144848 - 0.106426236794im 0.10706172568200001 + 0.0im], ComplexF64[0.893136634427 + 0.0im -0.041792956331 + 0.144090584283im; -0.041792956331 - 0.144090584283im 0.10686336557300002 + 0.0im], ComplexF64[0.893322894035 + 0.0im 0.03272550522 + 0.146156953081im; 0.03272550522 - 0.146156953081im 0.10667710596500002 + 0.0im], ComplexF64[0.893496730361 + 0.0im 0.099049448058 + 0.1121801486im; 0.099049448058 - 0.1121801486im 0.10650326963900003 + 0.0im], ComplexF64[0.893659545799 + 0.0im 0.14083752184 + 0.050596084526im; 0.14083752184 - 0.050596084526im 0.10634045420100002 + 0.0im], ComplexF64[0.893814558475 + 0.0im 0.147820447387 - 0.023379578668im; 0.147820447387 + 0.023379578668im 0.10618544152499998 + 0.0im]], Any[0.06, 0.08, 0.1, 0.12, 0.14, 0.16, 0.18, 0.2, 0.22, 0.24  …  24.98, 25.0, 25.02, 25.04, 25.06, 25.08, 25.1, 25.12, 25.14, 25.16])

# %%
using QuantumOptics
basis = NLevelBasis(2)
using LinearAlgebra

ρᵗˢᵗ = [DenseOperator(basis,Hermitian(ρₜ)) for ρₜ in ρₛ]
tᵗˢᵗ = convert(Vector{Float64}, tₛ)

tˢⁱᵈ, ρˢⁱᵈ  = timeevolution.master(tᵗˢᵗ, ρᵗˢᵗ[1], DenseOperator(basis,H), 
            [ DenseOperator(basis,J₁), DenseOperator(basis,J₂),
             DenseOperator(basis,J₄), DenseOperator(basis,J₅), DenseOperator(basis,J₆)]);

# %%
bᵗˢᵗ = LiPoSID.bloch([ρₜ.data for ρₜ in ρˢⁱᵈ])
# Out:
# 3×1256 Matrix{Float64}:
#  -0.611892  -0.276278   0.127603  …   0.357358   0.63278    0.751716
#  -0.53972   -0.767657  -0.805766     -0.663657  -0.409466  -0.0540703
#  -0.572606  -0.572408  -0.572209     -0.342478  -0.342308  -0.342139

# %%
bˢⁱᵈ = LiPoSID.bloch(ρₛ)
# Out:
# 3×1256 Matrix{Float64}:
#  -0.611892  -0.276424   0.126852  …   0.198099   0.281675  0.295641
#  -0.53972   -0.766762  -0.803873     -0.22436   -0.101192  0.0467592
#  -0.572606  -0.570185  -0.56756       0.786993   0.787319  0.787629

# %%
function xyz(b)
    x = b[1, :]
    y = b[2, :]
    z = b[3, :]
    return x,y,z
end

using Plots  #; plotlyjs()

function sphere(r, C)   # r: radius; C: center [cx,cy,cz]
    n = 100
    u = range(-π, π; length = n)
    v = range(0, π; length = n)
    x = C[1] .+ r*cos.(u) * sin.(v)'
    y = C[2] .+ r*sin.(u) * sin.(v)'
    z = C[3] .+ r*ones(n) * cos.(v)'
    return x, y, z
end
# Out:
# sphere (generic function with 1 method)

# %%
surface(sphere(1, [0,0,0]), alpha=0.4, c=cgrad(:plasma, rev=true), showaxis = false, colorbar=false, size = (1200, 1200))

# %%
surface(sphere(1, [0,0,0]), alpha=0.4, c=cgrad(:plasma, rev=true), showaxis = false, colorbar=false, size = (600, 600))
Plots.plot!(xyz(bˢⁱᵈ), linewidth=5)

# %%
plt = surface(sphere(1, [0,0,0]), alpha=0.4, c=cgrad(:plasma, rev=true), showaxis = false, colorbar=false, size = (1200, 1200))
plt = Plots.plot!(xyz(bˢⁱᵈ), label="POP-LME", linewidth=5)
plt = Plots.plot!(xyz(bᵗˢᵗ), label = "EXACT-SB", linewidth=5)
#plt = Plots.plot!(xyz(bᵗˢᵗᴱᴿᴬ), label="", linewidth=5) 
#savefig(plt, "Trajectory_in_Bloch.pdf")

# %%
show(plt)
# Out:
# Plot{Plots.GRBackend() n=3}

# %%
plot(xyz(bˢⁱᵈ), label="POP-LME", linewidth=1)

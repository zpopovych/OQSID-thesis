# %%
from boson_data_lib import *
import numpy as np
import scipy.linalg as sl
import os
import pandas as pd
import glob

# %%
best_init_rho =  np.array([[ 0.0+0.j,  0.0+0.0j],
                            [ 0.0-0.0j, 1.0+0.0j] ]) # exited state

data_dir = "../DATA/"
fid_dists = fidelity_distances(data_dir, best_init_rho);

# %%
def read_as_dataframe(filename, tests_dir, fid_dists):

    df = pd.DataFrame()
    
    print("Processing...")
    
    with h5py.File(tests_dir+filename, "r") as f:          
        for gamma in f.keys():
            
            print(gamma)
            
            g = gamma[6:]

            states = ["State_D"+str(i+1) for i in range(20)]

            for state in states:

                F_b4dmd = f[gamma][state]["F_b4dmd_sb"][()]

                print(min(F_b4dmd))

                F_b4a = f[gamma][state]["F_b4a_sb"][()] 

                t = f[gamma][state]["time"][()]
                ser_len = len(t)

                gamma_column = [g] * ser_len
                state_column = [state] * ser_len

                time_column = t
                gamma_time_column = np.array(t)*float(g) 

                fid_dist_column = [fid_dists[int(state[7:])-1]] * ser_len 

                d_ser = {'Gamma': gamma_column,
                        'State': state_column,
                        'Distance': fid_dist_column,
                        'Time': time_column,
                        'gt': gamma_time_column,
                        'Fidelity_b4DMD': F_b4dmd[:ser_len],
                        'Infidelity_b4DMD': 1-F_b4dmd[:ser_len],
                        'Fidelity_b4a': F_b4a[:ser_len],
                        'Infidelity_b4a': 1-F_b4a[:ser_len]}

                df_ser = pd.DataFrame(data = d_ser)   
                df = pd.concat([df, df_ser])
    
    print(" done!")
    
    return df

# %%
tests_dir = "../TESTS/"
tests_file = "DMD-Bloch4D_SB_trn4_tst20_2023-Oct-07_at_13-53.h5"

tests_dir
# Out:
# '../TESTS/'

# %%
df = read_as_dataframe(tests_file, tests_dir, fid_dists)
# Out:
# Processing...
# gamma_0.0
# 0.9999873821005936
# 0.9999949579071838
# 0.999998863774757
# 0.999999003478756
# 0.9999978511185711
# 0.999997847940937
# 0.9999988739816609
# 0.9999989092367341
# 0.999910452801475
# 0.9999981298866208
# 0.999998710480471
# 0.9999987649087003
# 0.9999858318534148
# 0.9999940509317141
# 0.9999990230642806
# 0.9999990008636539
# 0.999998874653903
# 0.9999989243969736
# 0.9999979209765739
# 0.9999103115997575
# gamma_0.079477
# 0.9999873821005936
# 0.9999949579071838
# 0.999998863774757
# 0.999999003478756
# 0.9999978511185711
# 0.999997847940937
# 0.9999988739816609
# 0.9999989092367341
# 0.999910452801475
# 0.9999981298866208
# 0.999998710480471
# 0.9999987649087003
# 0.9999858318534148
# 0.9999940509317141
# 0.9999990230642806
# 0.9999990008636539
# 0.999998874653903
# 0.9999989243969736
# 0.9999979209765739
# 0.9999103115997575
# gamma_0.25133
# 0.9999710367831462
# 0.9999891794663665
# 0.9999972048970833
# 0.9999976589823127
# 0.9999949703908103
# 0.9999950739893126
# 0.9999993793944495
# 0.9999988922820745
# 0.9999387507841344
# 0.9999959541882015
# 0.9999963410318277
# 0.9999963616611507
# 0.9999624504969198
# 0.9999834068849207
# 0.9999979269629881
# 0.9999976677870324
# 0.9999989190795282
# 0.9999994092334042
# 0.9999949113716078
# 0.9999253686676433
# gamma_0.79477
# 0.9999407308672501
# 0.9999779798039108
# 0.9999913891946253
# 0.9999942890833884
# 0.9999837950486379
# 0.9999866757167237
# 0.9999968176156904
# 0.9999875640988678
# 0.999849576153423
# 0.9999910677829271
# 0.9999857036454319
# 0.9999839950168068
# 0.999887864109531
# 0.9999357279984902
# 0.9999908139445903
# 0.9999875750013761
# 0.9999886033983321
# 0.9999973896844099
# 0.9999845303526542
# 0.9997660957570133
# gamma_2.5133
# 0.9999387846901581
# 0.9999605125746089
# 0.9999622137107269
# 0.9999750558147078
# 0.9999098999247158
# 0.999891805855447
# 0.9999839910450032
# 0.9998709968738427
# 0.9997494544170328
# 0.9999848751961404
# 0.9999352366341907
# 0.9999152507232828
# 0.999709251051073
# 0.9997034512674634
# 0.9999441370496097
# 0.999909515220663
# 0.9998929142025887
# 0.9999890234370188
# 0.9999540543223546
# 0.9993859111015635
# gamma_25.133
# 0.9960559906937946
# 0.9859374825070562
# 0.9966100701720058
# 0.9837864486628312
# 0.9777931160764278
# 0.9838165932978965
# 0.9968285777691447
# 0.9648626014222338
# 0.9997646276303653
# 0.9992064410110383
# 0.9969839437984359
# 0.9734169574358169
# 0.9972581175739816
# 0.9698850346180925
# 0.9827735938442704
# 0.9794368872022537
# 0.9878805158909383
# 0.9814410638390537
# 0.9957000137988794
# 0.9936996033680793
# gamma_251.33
# 0.9958039380274811
# 0.9982978602999774
# 0.9986998753101909
# 0.9938619587333307
# 0.9924035795837453
# 0.9961349304756892
# 0.9993885649054879
# 0.9984344581088735
# 0.9972000018191384
# 0.9966952547943169
# 0.9959260370784148
# 0.998101889178159
# 0.998896589197236
# 0.9939597511924179
# 0.9923996895050182
# 0.9961026025312913
# 0.9994570142382757
# 0.998255739553332
# 0.9973386925194393
# 0.9965608402739957
# gamma_7.9477
# 0.9995795715103513
# 0.9997201134916116
# 0.9995598100314005
# 0.9997896637539734
# 0.9990467221416461
# 0.9985575239137103
# 0.9997175991145795
# 0.999100637221195
# 0.9998627475622058
# 0.9999612986272336
# 0.9994006659896162
# 0.9994023868561372
# 0.9985328079781723
# 0.9988536702007045
# 0.9990536444161471
# 0.9990748810415482
# 0.999196618913807
# 0.9999370098877618
# 0.9997800526440141
# 0.9992691543105913
# gamma_79.477
# 0.999900904601421
# 0.9999325262648233
# 0.9997112508845202
# 0.9997245882243259
# 0.9998354925366201
# 0.99983087238663
# 0.999931738943175
# 0.9996981015729858
# 0.9998996998889748
# 0.9995564784431923
# 0.9994808772881252
# 0.999530966810962
# 0.9998547769650987
# 0.9999165607858049
# 0.9996249907615258
# 0.9996751417193397
# 0.9997023545713147
# 0.9999506973891212
# 0.9993937801442432
# 0.9999186898236716
#  done!

# %%
df_pickle_filename = "../TESTS/dataframe_"+tests_file[:-3]+".pkl"
df.to_pickle(df_pickle_filename)
print(df_pickle_filename)
# Out:
# ../TESTS/dataframe_DMD-Bloch4D_SB_trn4_tst20_2023-Oct-07_at_13-53.pkl

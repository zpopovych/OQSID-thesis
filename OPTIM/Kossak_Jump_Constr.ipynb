# %%
using JuMP
using Ipopt
#using NLopt
using LinearAlgebra
using BlackBoxOptim

#using Optim
using HDF5

# %%
function read_timeevolution(file_name, state, γ)
    h5open(file_name, "r") do file
        ρᵧ = read(file[state][string(γ)])
        t = ρᵧ["t"]
        ρ₀₀ = ρᵧ["p0"]; Re_ρ₀₁ = ρᵧ["s_re"];  Im_ρ₀₁ = ρᵧ["s_im"]
        ρ_series = []
        t_series = []

        for i in 1:length(t)
            ρᵢ= [ ρ₀₀[i]                      Re_ρ₀₁[i] + im * Im_ρ₀₁[i]
                  Re_ρ₀₁[i] - im * Im_ρ₀₁[i]  1 - ρ₀₀[i]                 ]
            push!(ρ_series, convert(Matrix{ComplexF64}, ρᵢ))
            push!(t_series, convert(Float64, t[i]))
        end
        return(t_series, ρ_series)
    end
end
# Out:
# read_timeevolution (generic function with 1 method)

# %% [markdown]
# Fidelity for qubit can be written:
#
# $F(\rho, \sigma) = \operatorname{tr}(\rho \sigma) + 2\sqrt{\det(\rho) \det(\sigma)}$

# %%
function infidelity_norm(ρ, σ)
    abs(1 - real(tr(ρ * σ)) - 2*sqrt(abs(det(ρ)*det(σ))))#^2
end
# Out:
# infidelity_norm (generic function with 1 method)

# %%
# Define the Pauli matrices
σˣ = [0 1; 1 0]
σʸ = [0 im; -im 0]
σᶻ = [1 0; 0 -1]

# Define the basis elements
fᴷ₁ = σˣ / 2
fᴷ₂ = σʸ / 2
fᴷ₃ = σᶻ / 2

# Check orthogonality and normalization
@assert tr(fᴷ₁ * fᴷ₂) ≈ 0
@assert tr(fᴷ₁ * fᴷ₃) ≈ 0
@assert tr(fᴷ₂ * fᴷ₃) ≈ 0
@assert tr(fᴷ₁ * fᴷ₁) ≈ 1 / 2
@assert tr(fᴷ₂ * fᴷ₂) ≈ 1 / 2
@assert tr(fᴷ₃ * fᴷ₃) ≈ 1 / 2

fᴼᴺᴮ = [fᴷ₁, fᴷ₂, fᴷ₃]

# Function to calculate Dc
function Dc(ρ, t, H, C)
    U = (H * ρ - ρ * H) / im
    D = sum(C .* [2 * fᵢ * ρ * fⱼ' - ρ * fⱼ' * fᵢ - fⱼ' * fᵢ * ρ for fᵢ in fᴼᴺᴮ, fⱼ in fᴼᴺᴮ]) / 2
    return U + D
end
# Out:
# Dc (generic function with 1 method)

# %% [markdown]
# ### Kossakowski objective for two-level system
#
# A linear operator $L: M(2) \rightarrow M(2)$ is the generator of a dynamical semigroup $t \rightarrow \Lambda_t$ of $M(2)$ iff it can be written in the form:
#
# $L = -i[H,\rho] + \frac{1}{2} \sum_{i,j}^3 C_{ij} \{[f_i, \rho f_j] + [f_i\rho, f_j]\}, \quad \rho \in M(2)$
#
# where
#
# (i) $H = \sum_1^3 h_i f_i, \quad h_i \in \R$
#
# (ii) $f_i f_j = \frac{1}{4}\delta_{ij}I  +\frac{i}{2} \sum_{k=1}^3 \epsilon_{ijk} f_k$ which means:
#
# $ \operatorname{tr}(f_i f_j)=\frac{1}{2}\delta_{ij}, \quad \operatorname{tr}(f_i) = 0$
#
#
# (iii) $\{C_{ij}\}= \begin{pmatrix}
# \gamma - 2\gamma_1    & - i a_3            &  i a_2 \\
# i a_3                 & \gamma - 2\gamma_2 & -i a_1 \\
# -i a_2                & i a_1              & \gamma - 2\gamma_3
# \end{pmatrix} =$
#
# $=\begin{pmatrix}
# -\gamma_1 + \gamma_2 + \gamma_3   & - i a_3   &  i a_2 \\
# i a_3                 & \gamma_1 - \gamma_2 + \gamma_3 & -i a_1 \\
# -i a_2                & i a_1      & \gamma_1 + \gamma_2 - \gamma_3
# \end{pmatrix}$

# %%
# Define functions to construct H and C from parameters
function construct_H(ϵ, h_Re, h_Im)
    return [
             ϵ                     h_Re + im * h_Im
             h_Re - im * h_Im     -ϵ
           ] / 2
end

function construct_C(γ, a)
    return [
        -γ[1] + γ[2] + γ[3]  -im * a[3]            im * a[2]
        im * a[3]            γ[1] - γ[2] + γ[3]   -im * a[1]
        -im * a[2]           im * a[1]             γ[1] + γ[2] - γ[3]
    ]
end

# JuMP model setup
model = Model(Ipopt.Optimizer)

# Set options for higher precision
set_optimizer_attribute(model, "tol", 1e-10)  # Convergence tolerance
set_optimizer_attribute(model, "acceptable_tol", 1e-10)  # Acceptable tolerance
set_optimizer_attribute(model, "constr_viol_tol", 1e-12)  # Constraint violation tolerance
set_optimizer_attribute(model, "compl_inf_tol", 1e-12)  # Complementarity tolerance
set_optimizer_attribute(model, "dual_inf_tol", 1e-12)  # Dual infeasibility tolerance


#model = Model(optimizer_with_attributes(NLopt.Optimizer, "algorithm" => :LD_SLSQP )) #:AUGLAG :LD_SLSQP :LD_MMA

# Define variables in JuMP
@variable(model, ϵ)
@variable(model, h_Re)
@variable(model, h_Im)
@variable(model, γ[1:3])
@variable(model, a[1:3])

# Define κ terms in JuMP
@expression(model, κ₁, -γ[1] + γ[2] + γ[3])
@expression(model, κ₂, γ[1] - γ[2] + γ[3])
@expression(model, κ₃, γ[1] + γ[2] - γ[3])

# Define the real and imaginary parts of Cˢʸᵐᵇ matrix in JuMP
@variable(model, C_Re[1:3, 1:3])
@variable(model, C_Im[1:3, 1:3])

# Define constraints for real and imaginary parts separately
@constraint(model, C_Re[1, 1] == κ₁)
@constraint(model, C_Re[1, 2] == 0)
@constraint(model, C_Re[1, 3] == 0)
@constraint(model, C_Re[2, 1] == 0)
@constraint(model, C_Re[2, 2] == κ₂)
@constraint(model, C_Re[2, 3] == 0)
@constraint(model, C_Re[3, 1] == 0)
@constraint(model, C_Re[3, 2] == 0)
@constraint(model, C_Re[3, 3] == κ₃)

@constraint(model, C_Im[1, 1] == 0)
@constraint(model, C_Im[1, 2] == -a[3])
@constraint(model, C_Im[1, 3] == a[2])
@constraint(model, C_Im[2, 1] == a[3])
@constraint(model, C_Im[2, 2] == 0)
@constraint(model, C_Im[2, 3] == -a[1])
@constraint(model, C_Im[3, 1] == -a[2])
@constraint(model, C_Im[3, 2] == a[1])
@constraint(model, C_Im[3, 3] == 0)

# Define constraints in JuMP
@constraint(model, ϵ >= 0)
@constraint(model, γ[1] >= 0)
@constraint(model, γ[2] >= 0)
@constraint(model, γ[3] >= 0)
@constraint(model, κ₁ + κ₂ + κ₃ >= 0)
@constraint(model, κ₁ >= 0)
@constraint(model, κ₂ >= 0)
@constraint(model, κ₃ >= 0)
@NLconstraint(model, κ₁ * κ₂ + κ₃ * κ₁ + κ₂ * κ₃ - a[1]^2 - a[2]^2 - a[3]^2 >= 0)
@NLconstraint(model, κ₁ * κ₂ * κ₃ - κ₁ * a[1]^2 - κ₂ * a[2]^2 - κ₃ * a[3]^2 >= 0)
# Out:
# ((((-1.0 * γ[1] + γ[2] + γ[3]) * (γ[1] + -1.0 * γ[2] + γ[3]) * (γ[1] + γ[2] + -1.0 * γ[3]) - (-1.0 * γ[1] + γ[2] + γ[3]) * a[1] ^ 2.0) - (γ[1] + -1.0 * γ[2] + γ[3]) * a[2] ^ 2.0) - (γ[1] + γ[2] + -1.0 * γ[3]) * a[3] ^ 2.0) - 0.0 ≥ 0

# %%
# Objective function

function kossak_obj(ϵ, h_Re, h_Im, γ, a, ρ, t)
    H = construct_H(ϵ, h_Re, h_Im)
    C = construct_C(γ, a)
    obj = 0.0
    for i in 3:length(ρ)
        ρ1 = ρ[i]
        ρ2 = ρ[i - 2] + (t[i] - t[i - 1]) * (Dc(ρ[i], t[i], H, C) - 4 * Dc(ρ[i - 1], t[i - 1], H, C) + Dc(ρ[i - 2], t[i - 2], H, C)) / 3
        obj += infidelity_norm(ρ1,ρ2)
    end
    return obj
end

# Define the objective function wrapper
function objectiveGEXY(ϵ, h_Re, h_Im, γ1, γ2, γ3, a1, a2, a3)
    γ = [γ1, γ2, γ3]
    a = [a1, a2, a3]
    objGEXY = kossak_obj(ϵ, h_Re, h_Im, γ, a, ρᵍ, tᵍ) + 
              kossak_obj(ϵ, h_Re, h_Im, γ, a, ρᵉ, tᵉ) + 
              kossak_obj(ϵ, h_Re, h_Im, γ, a, ρˣ, tˣ) + 
              kossak_obj(ϵ, h_Re, h_Im, γ, a, ρʸ, tʸ)
    return objGEXY
end


# Register the objective function with JuMP
register(model, :objectiveGEXY, 9, objectiveGEXY, autodiff = true)

# %%
# Define the density matrix evolution and time points

file_name = "../DATA/ALL_GAMMAS_B4_D10.h5"

#γ = [ "0.079477",  "0.25133", "0.79477", "2.5133", "7.9477", "25.133", "79.477", "251.33"]

γᵢ = "0.25133"
γᶠ = parse(ComplexF64, γᵢ)

tᵍ, ρᵍ = read_timeevolution(file_name, "B1", γᵢ)
tᵉ, ρᵉ = read_timeevolution(file_name, "B2", γᵢ)
tˣ, ρˣ = read_timeevolution(file_name, "B3", γᵢ)
tʸ, ρʸ = read_timeevolution(file_name, "B4", γᵢ);

# %%
# Define the objective function in JuMP
@NLobjective(model, Min, objectiveGEXY(ϵ, h_Re, h_Im, γ[1], γ[2], γ[3], a[1], a[2], a[3]))

# Optimize the model
JuMP.optimize!(model)
# Out:
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.4, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:       33
# Number of nonzeros in inequality constraint Jacobian.:       28
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:       27
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       18
# Total number of inequality constraints...............:       10
#         inequality constraints with only lower bounds:       10
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  3.2695883e+01 0.00e+00 1.29e+00   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  3.2698003e+01 1.36e-04 7.99e-01  -8.0 1.54e-02    -  5.52e-01 9.90e-01h  1
#    2  3.2696263e+01 8.67e-19 2.99e-02  -4.1 9.88e-03    -  1.00e+00 9.95e-01h  1
#    3  3.2695938e+01 8.67e-19 5.65e-03  -9.9 4.57e-03    -  1.00e+00 9.87e-01h  1
#    4  3.2695877e+01 1.73e-18 3.81e-03 -10.9 4.50e-03    -  1.00e+00 8.38e-01h  1
#    5  3.2695823e+01 2.02e-06 1.57e+02  -6.1 8.60e-03    -  1.00e+00 7.17e-01h  1
#    6  3.2695865e+01 9.56e-10 5.76e+01  -5.6 2.41e-03    -  6.65e-01 1.00e+00H  1
#    7  3.2695818e+01 1.08e-06 9.09e-03  -5.6 3.78e-03    -  1.00e+00 1.00e+00h  1
#    8  3.2695816e+01 1.75e-06 3.44e+01  -6.5 1.41e-03    -  1.00e+00 6.04e-01h  1
#    9  3.2695815e+01 1.03e-06 5.20e+01  -6.3 8.40e-04    -  1.00e+00 8.69e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  3.2695820e+01 1.00e-06 5.97e-03  -6.3 9.82e-04    -  1.00e+00 1.00e+00f  1
#   11  3.2695821e+01 5.32e-07 8.65e-04  -6.6 6.07e-04    -  1.00e+00 6.64e-01h  1
#   12  3.2695824e+01 1.58e-07 9.19e-04  -8.2 2.79e-04    -  1.00e+00 9.03e-01h  1
#   13  3.2695826e+01 2.37e-08 1.18e-03  -9.2 1.10e-04    -  1.00e+00 1.00e+00h  1
#   14  3.2695826e+01 2.00e-08 6.13e-04  -7.9 2.09e-04    -  1.00e+00 2.50e-01h  3
#   15  3.2695827e+01 1.87e-08 2.72e-03  -9.2 1.28e-04    -  1.00e+00 8.12e-01h  1
#   16  3.2695826e+01 9.04e-09 4.02e-04  -9.3 7.84e-05    -  1.00e+00 1.00e+00h  1
#   17  3.2695827e+01 2.88e-09 9.31e-04  -9.7 3.77e-05    -  1.00e+00 9.72e-01h  1
#   18  3.2695827e+01 1.42e-09 1.15e-03 -11.5 3.58e-05    -  1.00e+00 9.93e-01h  1
#   19  3.2695827e+01 9.10e-10 1.12e-03 -12.0 2.30e-05    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  3.2695827e+01 4.88e-10 6.58e-04 -11.5 2.13e-05    -  1.00e+00 1.00e+00h  1
#   21  3.2695827e+01 1.33e-10 8.27e-04 -12.2 9.43e-06    -  1.00e+00 1.00e+00h  1
#   22  3.2695827e+01 8.47e-11 5.47e-04 -12.3 7.74e-06    -  1.00e+00 1.00e+00h  1
#   23  3.2695827e+01 2.17e-11 1.71e-04 -12.3 4.11e-06    -  1.00e+00 1.00e+00h  1
#   24  3.2695827e+01 4.63e-13 1.71e-04 -12.3 1.95e-06    -  1.00e+00 1.00e+00h  1
#   25  3.2695827e+01 4.56e-11 3.56e-04 -12.3 2.90e-05    -  1.00e+00 1.00e+00h  1
#   26  3.2695827e+01 2.71e-10 1.86e-03 -12.3 2.03e-04    -  1.00e+00 1.00e+00h  1
#   27  3.2695827e+01 4.82e-09 2.95e-03 -12.3 3.46e-03    -  1.00e+00 2.57e-01h  1
#   28  3.2695827e+01 1.20e-08 1.52e-03 -12.3 1.41e-04    -  1.94e-04 1.00e+00h  1
#   29  3.2695827e+01 1.36e-09 3.72e-04 -12.3 1.62e-04    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  3.2695827e+01 2.12e-10 1.92e-04 -12.3 1.49e-04    -  1.00e+00 1.00e+00h  1
#   31  3.2695827e+01 2.06e-11 7.14e-04 -12.3 5.45e-04    -  1.00e+00 1.00e+00H  1
#   32  3.2695827e+01 1.14e-11 2.65e-03 -12.3 1.25e-03    -  1.00e+00 1.00e+00H  1
#   33  3.2695827e+01 4.67e-09 5.27e-03 -12.3 3.27e-02    -  3.91e-01 2.32e-02h  3
#   34  3.2695827e+01 6.02e-08 1.04e-02 -12.3 9.91e-04    -  2.52e-01 1.00e+00h  1
#   35  3.2695827e+01 4.65e-08 3.40e-03 -12.3 3.39e-03    -  1.00e+00 5.00e-01h  2
#   36  3.2695827e+01 6.69e-08 4.13e-03 -12.3 1.38e-02    -  5.65e-01 6.79e-02h  2
#   37  3.2695827e+01 1.64e-08 3.76e-03 -12.3 1.53e-03    -  3.88e-01 1.00e+00h  1
#   38  3.2695827e+01 1.58e-08 2.25e-03 -12.3 4.05e-03    -  1.00e+00 2.50e-01h  3
#   39  3.2695826e+01 2.77e-07 1.67e-03 -12.3 1.10e-02    -  1.00e+00 1.20e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  3.2695825e+01 5.63e-07 1.55e-03 -12.3 9.69e-04    -  1.39e-04 1.00e+00f  1
#   41  3.2695825e+01 3.12e-07 2.14e-03 -12.3 6.13e-04    -  1.00e+00 1.00e+00h  1
#   42  3.2695825e+01 5.91e-08 5.46e-03 -12.3 2.63e-04    -  1.00e+00 1.00e+00h  1
#   43  3.2695826e+01 2.28e-08 9.82e-04 -10.4 3.12e-04    -  1.00e+00 1.00e+00H  1
#   44  3.2695827e+01 8.95e-09 1.44e-03 -10.5 1.30e-04    -  1.00e+00 1.00e+00h  1
#   45  3.2695827e+01 5.22e-09 1.15e-03 -10.5 9.87e-05    -  6.50e-01 1.00e+00h  1
#   46  3.2695827e+01 2.69e-09 7.14e-04 -11.0 8.52e-05    -  1.00e+00 1.00e+00h  1
#   47  3.2695827e+01 9.77e-10 8.03e-04 -12.2 2.72e-05    -  1.00e+00 1.00e+00h  1
#   48  3.2695827e+01 1.24e-10 7.28e-04 -12.3 1.71e-05    -  1.00e+00 1.00e+00h  1
#   49  3.2695827e+01 8.41e-11 3.01e-04 -12.3 8.43e-06    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  3.2695827e+01 6.96e-12 1.15e-04 -12.3 4.36e-06    -  1.00e+00 1.00e+00h  1
#   51  3.2695827e+01 3.46e-13 4.78e-05 -12.3 5.86e-07    -  1.00e+00 1.00e+00h  1
#   52  3.2695827e+01 3.02e-12 5.70e-05 -12.3 2.19e-06    -  1.00e+00 1.00e+00h  1
#   53  3.2695827e+01 1.97e-10 6.91e-04 -12.3 1.87e-05    -  1.00e+00 1.00e+00h  1
#   54  3.2695827e+01 7.05e-11 4.51e-05 -12.3 1.01e-05    -  1.00e+00 1.00e+00h  1
#   55  3.2695827e+01 4.73e-14 4.10e-05 -12.3 1.67e-06    -  1.00e+00 1.00e+00h  1
#   56  3.2695827e+01 1.29e-16 3.26e-05 -12.3 2.98e-06    -  1.00e+00 1.00e+00h  1
#   57  3.2695827e+01 6.98e-13 1.11e-04 -12.3 2.20e-05    -  1.00e+00 1.00e+00h  1
#   58  3.2695827e+01 1.22e-10 2.77e-04 -12.3 1.71e-03    -  1.00e+00 2.50e-02h  4
#   59  3.2695827e+01 1.71e-10 4.55e-04 -12.3 2.25e-04    -  1.00e+00 7.84e-02h  4
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60  3.2695827e+01 5.05e-11 1.89e-04 -12.3 6.97e-05    -  8.45e-01 1.00e+00h  1
#   61  3.2695827e+01 8.58e-12 1.35e-04 -12.3 7.32e-05    -  1.00e+00 1.00e+00h  1
#   62  3.2695827e+01 6.12e-13 5.28e-05 -12.3 6.16e-05    -  1.00e+00 1.00e+00H  1
#   63  3.2695827e+01 8.93e-10 1.58e-04 -12.3 6.04e-05    -  1.00e+00 1.00e+00h  1
#   64  3.2695827e+01 2.53e-10 1.39e-04 -12.3 1.38e-04    -  1.00e+00 1.00e+00h  1
#   65  3.2695827e+01 4.36e-10 3.63e-04 -12.3 6.58e-03    -  1.00e+00 1.78e-02h  5
#   66  3.2695827e+01 1.20e-10 1.19e-04 -12.3 9.55e-05    -  1.00e+00 1.00e+00h  1
#   67  3.2695827e+01 1.71e-10 3.30e-04 -12.3 8.04e-04    -  3.00e-01 6.25e-02h  5
#   68  3.2695827e+01 2.43e-18 5.02e-04 -12.3 1.50e-04    -  1.00e+00 1.00e+00H  1
#   69  3.2695827e+01 5.53e-13 5.06e-04 -12.3 3.27e-03    -  1.00e+00 3.35e-03h  9
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   70  3.2695827e+01 4.66e-09 7.26e-04 -12.3 2.60e-04    -  1.00e+00 1.00e+00h  1
#   71  3.2695827e+01 4.13e-09 6.19e-04 -12.3 4.88e-04    -  1.00e+00 2.50e-01h  3
#   72  3.2695827e+01 3.04e-08 4.81e-03 -12.3 1.25e-02    -  4.19e-02 1.22e-01h  4
#   73  3.2695827e+01 2.69e-08 4.80e-03 -12.3 3.96e-03    -  1.00e+00 1.25e-01h  4
#   74  3.2695827e+01 4.20e-08 1.11e-02 -12.3 2.20e-02    -  6.71e-01 7.72e-02h  2
#   75  3.2695827e+01 4.52e-08 5.80e-03 -12.3 7.22e-03    -  1.79e-01 2.50e-01h  3
#   76  3.2695826e+01 6.71e-08 1.83e-03 -12.3 2.76e-02    -  1.00e+00 9.21e-02h  2
#   77  3.2695826e+01 6.09e-08 1.10e-03 -12.3 1.71e-02    -  1.01e-01 1.25e-01h  4
#   78  3.2695826e+01 1.52e-07 1.79e-03 -12.3 1.30e-02    -  3.87e-01 9.72e-02h  4
#   79  3.2695827e+01 3.28e-08 1.39e-03 -12.3 2.70e-03    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   80  3.2695827e+01 4.30e-08 2.06e-03 -12.3 5.37e-02    -  1.39e-01 1.56e-02h  7
#   81  3.2695826e+01 1.04e-07 6.36e-03 -12.3 2.04e-02    -  1.00e+00 1.30e-01h  1
#   82  3.2695826e+01 8.93e-08 7.31e-03 -12.3 6.42e-03    -  2.19e-03 2.50e-01f  3
#   83  3.2695826e+01 3.23e-07 7.40e-03 -12.3 9.90e-02    -  6.90e-01 7.41e-02h  2
#   84  3.2695826e+01 2.40e-07 3.93e-03 -12.3 1.62e-02    -  1.00e+00 5.00e-01h  2
#   85  3.2695825e+01 6.56e-06 8.06e-01 -12.3 2.24e-02    -  2.64e-01 4.89e-01h  1
#   86  3.2695825e+01 3.71e-06 2.54e+03 -12.3 1.10e-02    -  4.44e-06 5.00e-01f  2
#   87  3.2695798e+01 8.06e-06 3.86e+03 -12.3 7.33e-02    -  4.98e-02 2.05e-01h  1
#   88  3.2695798e+01 8.06e-06 3.24e+03 -10.8 2.27e-02    -  1.00e+00 1.22e-04f 14
#   89  3.2695824e+01 7.55e-06 1.20e+03 -10.8 1.63e-02    -  5.79e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   90  3.2695818e+01 7.24e-06 1.17e+03 -10.8 3.18e-02    -  1.72e-02 6.29e-02h  1
#   91  3.2695793e+01 7.13e-06 1.55e+03 -10.8 1.96e-02    -  1.22e-04 3.16e-01f  1
#   92  3.2695793e+01 6.83e-06 5.99e+02 -10.8 1.05e-02    -  1.00e+00 1.09e-01f  1
#   93  3.2695793e+01 6.83e-06 5.99e+02 -10.8 2.65e-03    -  1.58e-05 1.22e-04h 14
#   94  3.2695801e+01 4.71e-06 4.81e+02 -10.8 4.52e-03    -  2.39e-04 4.01e-01h  1
#   95  3.2695801e+01 4.67e-06 4.94e+02 -10.8 2.09e-03    -  3.20e-04 7.81e-03h  8
#   96  3.2695829e+01 1.39e-06 5.63e+02 -10.8 3.40e-03    -  7.09e-03 1.00e+00h  1
#   97  3.2695832e+01 7.29e-07 4.45e-03 -10.8 1.92e-03    -  6.89e-02 6.13e-01h  1
#   98  3.2695823e+01 7.76e-07 2.13e-03 -10.8 1.13e-03    -  8.52e-01 8.49e-01f  1
#   99  3.2695823e+01 7.75e-07 2.13e-03 -10.8 7.08e-04    -  6.18e-04 4.88e-04h 12
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  100  3.2695820e+01 7.96e-07 1.34e-02 -10.8 9.24e-04    -  7.97e-01 1.00e+00h  1
#  101  3.2695823e+01 1.89e-07 2.19e-03  -8.6 5.74e-04    -  1.00e+00 1.00e+00h  1
#  102  3.2695824e+01 7.83e-08 3.58e-04  -9.2 3.15e-04    -  1.00e+00 1.00e+00h  1
#  103  3.2695826e+01 3.11e-08 6.79e-04  -9.4 1.47e-04    -  1.00e+00 1.00e+00h  1
#  104  3.2695827e+01 6.66e-09 1.34e-03  -8.4 1.38e-04    -  1.00e+00 1.00e+00h  1
#  105  3.2695827e+01 5.06e-09 2.33e-03  -8.4 8.36e-05    -  1.00e+00 9.06e-01H  1
#  106  3.2695827e+01 5.13e-09 3.23e-04  -8.4 7.74e-05    -  1.00e+00 1.00e+00f  1
#  107  3.2695827e+01 5.39e-10 1.56e-03  -8.4 5.20e-05    -  1.00e+00 1.00e+00h  1
#  108  3.2695827e+01 2.81e-12 1.35e-03  -8.4 2.45e-05    -  1.00e+00 1.00e+00h  1
#  109  3.2695827e+01 1.57e-12 8.47e-04  -8.4 2.47e-05    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  110  3.2695827e+01 3.18e-13 5.02e-04  -8.4 9.84e-06    -  1.00e+00 1.00e+00h  1
#  111  3.2695827e+01 2.03e-14 2.84e-04  -8.4 8.51e-06    -  1.00e+00 1.00e+00h  1
#  112  3.2695827e+01 1.39e-19 2.30e-04  -8.4 5.72e-06    -  1.00e+00 1.00e+00h  1
#  113  3.2695827e+01 5.25e-20 3.85e-04  -8.4 1.87e-05    -  1.00e+00 1.00e+00h  1
#  114  3.2695827e+01 4.74e-20 4.27e-04  -8.4 6.45e-05    -  1.00e+00 1.00e+00h  1
#  115  3.2695827e+01 1.48e-13 1.47e-03  -8.4 3.63e-03    -  1.00e+00 2.92e-01h  2
#  116  3.2695827e+01 1.39e-13 1.43e-03  -8.4 2.14e-03    -  1.00e+00 6.25e-02h  5
#  117  3.2695827e+01 4.74e-09 1.11e-03  -8.4 1.22e-03    -  2.87e-01 5.00e-01h  2
#  118  3.2695827e+01 1.04e-09 3.52e-04  -8.4 8.32e-05    -  1.00e+00 1.00e+00h  1
#  119  3.2695827e+01 1.98e-11 3.22e-04  -8.4 9.79e-05    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  120  3.2695827e+01 1.73e-13 1.63e-03  -8.4 1.68e-04    -  1.00e+00 5.00e-01h  2
#  121  3.2695827e+01 4.47e-09 7.95e-04  -8.4 2.90e-04    -  1.00e+00 5.00e-01h  2
#  122  3.2695827e+01 4.01e-09 3.72e-04  -8.4 1.13e-04    -  1.00e+00 1.00e+00h  1
#  123  3.2695827e+01 2.76e-09 2.84e-04  -8.4 1.01e-03    -  1.00e+00 2.50e-01h  3
#  124  3.2695827e+01 2.28e-09 5.70e-04  -8.4 1.76e-03    -  1.00e+00 1.25e-01h  4
#  125  3.2695827e+01 1.49e-09 1.21e-03  -8.4 4.03e-04    -  4.95e-01 5.00e-01h  2
#  126  3.2695827e+01 2.36e-13 5.17e-04  -8.4 1.07e-04    -  1.00e+00 1.00e+00h  1
#  127  3.2695827e+01 4.34e-19 1.53e-03  -8.4 9.33e-04    -  1.00e+00 1.00e+00H  1
#  128  3.2695827e+01 1.73e-18 4.13e-04  -8.4 1.09e-03    -  1.00e+00 1.00e+00H  1
#  129  3.2695827e+01 1.65e-18 1.58e-04  -8.4 1.84e-03    -  1.00e+00 4.84e-02h  5
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  130  3.2695827e+01 1.55e-18 1.15e-04  -8.4 1.52e-03    -  1.00e+00 6.25e-02h  5
#  131  3.2695827e+01 1.35e-18 1.31e-04  -8.4 6.91e-04    -  1.00e+00 1.25e-01h  4
#  132  3.2695827e+01 1.33e-18 1.51e-04  -8.4 7.73e-03    -  1.00e+00 1.22e-02h  5
#  133  3.2695827e+01 4.34e-19 2.88e-04  -8.4 5.32e-05    -  1.00e+00 1.00e+00h  1
#  134  3.2695827e+01 4.34e-19 2.00e-04  -8.4 1.02e-03    -  1.00e+00 1.56e-02h  7
#  135  3.2695827e+01 2.17e-19 3.10e-05  -8.4 5.50e-05    -  1.00e+00 1.00e+00h  1
#  136  3.2695827e+01 4.34e-19 6.75e-04  -8.4 3.56e-04    -  1.00e+00 1.00e+00H  1
#  137  3.2695827e+01 4.68e-19 5.00e-04  -8.4 4.28e-04    -  1.00e+00 1.00e+00H  1
#  138  3.2695827e+01 5.13e-19 3.01e-04  -8.4 3.53e-03    -  1.27e-01 1.56e-02h  7
#  139  3.2695828e+01 4.34e-19 8.30e-04  -8.4 2.60e-03    -  1.00e+00 1.00e+00H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  140  3.2695828e+01 2.22e-19 8.62e-04  -8.4 4.66e-03    -  5.05e-01 7.81e-03h  8
#  141  3.2695827e+01 9.41e-09 2.06e-03  -8.4 1.64e-01    -  2.42e-01 7.90e-03f  2
#  142  3.2695827e+01 1.55e-07 8.73e-03  -8.4 2.46e-02    -  7.44e-02 1.65e-01h  3
#  143  3.2695827e+01 4.00e-07 2.00e-02  -8.4 3.49e-02    -  1.39e-01 5.57e-02h  3
#  144  3.2695825e+01 5.00e-07 1.22e-02  -8.4 4.98e-03    -  1.00e+00 9.40e-01h  1
#  145  3.2695825e+01 4.42e-07 1.09e-02  -8.4 1.17e-02    -  1.36e-02 1.25e-01f  4
#  146  3.2695827e+01 4.34e-07 2.66e-03  -8.4 4.01e-02    -  1.00e+00 6.62e-02h  3
#  147  3.2695827e+01 3.78e-07 2.79e-03  -8.4 3.44e-03    -  7.85e-01 1.00e+00h  1
#  148  3.2695826e+01 3.09e-07 3.08e-03  -8.4 2.43e-02    -  2.53e-01 2.50e-01h  3
#  149  3.2695826e+01 3.09e-07 2.73e-03  -8.4 9.94e-02    -  1.00e+00 1.83e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  150  3.2695826e+01 2.76e-07 2.45e-03  -8.4 1.32e-02    -  1.00e+00 1.25e-01f  4
#  151  3.2695825e+01 3.26e-07 1.80e-03  -8.4 4.75e-03    -  6.88e-02 2.50e-01h  3
#  152  3.2695823e+01 1.77e-06 1.49e+02  -8.4 1.06e-02    -  8.03e-01 5.57e-01h  1
#  153  3.2695822e+01 9.69e-07 1.09e-02  -8.4 9.74e-03    -  1.99e-03 5.00e-01f  2
#  154  3.2695810e+01 1.19e-05 1.89e+03  -8.4 3.83e-02    -  1.19e-01 3.88e-01h  1
#  155  3.2695804e+01 6.36e-06 1.26e+03  -8.4 1.91e-02    -  1.00e+00 7.62e-01f  1
#  156  3.2695804e+01 6.23e-06 1.28e+03  -8.4 3.24e-03    -  3.54e-02 2.03e-02h  4
#  157  3.2695818e+01 4.74e-06 1.39e+03  -8.4 2.65e-02    -  6.34e-01 5.42e-01h  1
#  158  3.2695815e+01 3.28e-06 9.77e+02  -8.4 1.35e-02    -  3.61e-03 4.77e-01f  1
#  159  3.2695814e+01 2.77e-06 1.20e+03  -8.4 2.60e-02    -  4.73e-01 1.82e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  160  3.2695812e+01 2.96e-06 1.14e+03  -8.4 2.06e-02    -  1.59e-01 3.47e-02f  1
#  161  3.2695812e+01 2.95e-06 1.14e+03  -8.4 1.34e-03    -  7.92e-03 1.95e-03f 10
#  162  3.2695810e+01 5.61e-06 2.04e+02  -8.4 7.93e-03    -  3.12e-01 5.17e-01h  1
#  163  3.2695811e+01 4.94e-06 8.64e+02  -8.4 2.03e-02    -  1.00e+00 1.25e-01h  4
#  164  3.2695820e+01 1.61e-06 1.03e-02  -8.4 2.12e-03    -  1.00e+00 1.00e+00h  1
#  165  3.2695823e+01 6.23e-07 5.04e-03  -8.4 1.49e-03    -  9.00e-01 1.00e+00h  1
#  166  3.2695824e+01 4.75e-07 2.46e-03  -8.4 1.34e-03    -  1.00e+00 5.00e-01h  2
#  167  3.2695823e+01 5.71e-07 2.68e-03  -8.4 3.67e-03    -  2.06e-02 5.00e-01h  2
#  168  3.2695823e+01 4.72e-07 7.97e-03  -8.4 2.57e-03    -  1.00e+00 4.92e-01h  1
#  169  3.2695823e+01 4.43e-07 3.63e-03  -8.4 2.14e-03    -  1.00e+00 6.25e-02f  5
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  170  3.2695825e+01 1.26e-07 1.85e-03  -8.4 1.85e-03    -  1.00e+00 1.00e+00h  1
#  171  3.2695822e+01 6.31e-07 9.10e-03  -8.4 1.31e-03    -  1.00e+00 1.00e+00h  1
#  172  3.2695822e+01 2.38e-07 1.33e-03  -8.4 1.22e-03    -  1.00e+00 1.00e+00h  1
#  173  3.2695825e+01 4.83e-08 1.01e-03  -9.1 5.33e-04    -  1.00e+00 9.97e-01h  1
#  174  3.2695826e+01 3.12e-08 1.80e-03 -10.0 2.71e-04    -  1.00e+00 1.00e+00h  1
#  175  3.2695826e+01 1.13e-08 9.85e-04 -10.3 3.26e-04    -  1.00e+00 1.00e+00h  1
#  176  3.2695827e+01 6.08e-09 8.99e-04 -11.0 2.50e-04    -  1.00e+00 1.00e+00h  1
#  177  3.2695827e+01 1.77e-09 1.44e-03 -11.3 8.90e-05    -  1.00e+00 1.00e+00h  1
#  178  3.2695827e+01 1.48e-09 5.20e-04 -11.6 4.34e-05    -  1.00e+00 5.00e-01h  2
#  179  3.2695827e+01 5.39e-10 1.34e-03 -12.3 7.62e-05    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  180  3.2695827e+01 4.89e-10 7.82e-04 -12.3 5.33e-05    -  1.00e+00 1.00e+00h  1
#  181  3.2695827e+01 1.82e-10 3.73e-04 -12.3 2.35e-05    -  1.00e+00 1.00e+00h  1
#  182  3.2695827e+01 3.31e-11 2.09e-04 -12.3 1.83e-05    -  1.00e+00 1.00e+00h  1
#  183  3.2695827e+01 6.59e-11 1.75e-04 -12.3 2.97e-05    -  1.00e+00 1.00e+00h  1
#  184  3.2695827e+01 9.97e-11 6.66e-04 -12.3 1.05e-03    -  6.86e-01 3.12e-02h  6
#  185  3.2695827e+01 1.19e-11 4.25e-04 -12.3 5.15e-04    -  1.00e+00 1.00e+00H  1
#  186  3.2695827e+01 6.93e-11 3.34e-04 -12.3 4.31e-03    -  4.65e-01 3.12e-02h  6
#  187  3.2695827e+01 2.45e-10 6.93e-04 -12.3 7.37e-05    -  1.00e+00 1.00e+00h  1
#  188  3.2695827e+01 1.96e-10 1.33e-04 -12.3 1.53e-04    -  1.00e+00 1.00e+00h  1
#  189  3.2695827e+01 2.68e-10 1.48e-04 -12.3 1.21e-03    -  1.00e+00 6.25e-02h  5
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  190  3.2695827e+01 3.93e-10 2.65e-04 -12.3 1.04e-02    -  2.02e-01 1.56e-02h  7
#  191  3.2695827e+01 4.25e-10 1.81e-04 -12.3 2.96e-03    -  1.00e+00 7.99e-03h  6
#  192  3.2695827e+01 3.78e-10 1.54e-04 -12.3 5.83e-05    -  1.00e+00 1.25e-01h  4
#  193  3.2695827e+01 3.66e-10 1.41e-04 -12.3 5.84e-05    -  1.00e+00 3.12e-02h  6
#  194  3.2695827e+01 2.27e-16 1.32e-04 -12.3 1.40e-04    -  1.00e+00 1.00e+00H  1
#  195  3.2695827e+01 4.80e-12 3.10e-03 -12.3 5.07e-04    -  1.00e+00 1.00e+00H  1
#  196  3.2695827e+01 1.62e-09 8.96e-04 -12.3 8.07e-04    -  1.00e+00 1.00e+00h  1
#  197  3.2695827e+01 2.38e-09 8.16e-04 -12.3 1.18e-02    -  4.58e-01 3.12e-02h  6
#  198  3.2695827e+01 2.14e-09 3.63e-04 -12.3 1.61e-03    -  1.00e+00 1.25e-01h  4
#  199  3.2695827e+01 2.22e-09 3.54e-04 -12.3 8.16e-03    -  9.56e-01 6.85e-03h  5
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  200  3.2695827e+01 2.14e-09 7.04e-04 -12.3 1.20e-03    -  1.00e+00 5.70e-02h  5
#  201  3.2695827e+01 2.11e-09 5.97e-04 -12.3 9.73e-04    -  1.00e+00 5.80e-02h  5
#  202  3.2695827e+01 2.03e-09 2.86e-04 -12.3 7.98e-04    -  6.71e-01 1.25e-01h  4
#  203  3.2695827e+01 1.24e-09 4.11e-04 -12.3 4.82e-04    -  1.00e+00 5.00e-01h  2
#  204  3.2695827e+01 1.16e-09 3.37e-04 -12.3 7.64e-04    -  1.00e+00 1.25e-01h  4
#  205  3.2695827e+01 6.72e-16 1.34e-03 -12.3 3.54e-04    -  1.00e+00 1.00e+00H  1
#  206  3.2695827e+01 5.21e-12 1.29e-03 -12.3 4.35e-03    -  1.67e-01 7.81e-03h  8
#  207  3.2695827e+01 7.64e-12 1.22e-03 -12.3 9.36e-04    -  1.00e+00 3.91e-03h  9
#  208  3.2695827e+01 9.45e-12 1.06e-03 -12.3 1.23e-03    -  1.00e+00 2.21e-03h  7
#  209  3.2695827e+01 9.76e-13 9.42e-04 -12.3 8.25e-04    -  8.83e-01 1.00e+00H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  210  3.2695827e+01 2.50e-09 2.48e-03 -12.3 5.58e-02    -  8.74e-01 1.91e-02h  6
#  211  3.2695827e+01 3.40e-09 3.18e-03 -12.3 8.54e-03    -  1.00e+00 4.74e-02h  3
#  212  3.2695827e+01 3.82e-09 2.57e-03 -12.3 9.79e-03    -  5.25e-01 2.50e-01h  3
#  213  3.2695827e+01 1.86e-08 1.84e-03 -12.3 5.96e-03    -  1.00e+00 1.25e-01h  4
#  214  3.2695827e+01 3.78e-08 3.36e-03 -12.3 2.23e-02    -  1.00e+00 9.92e-02h  2
#  215  3.2695827e+01 6.64e-08 3.43e-03 -12.3 1.34e-02    -  2.50e-02 2.09e-02h  5
#  216  3.2695827e+01 5.27e-09 1.10e-03 -12.3 6.79e-04    -  1.00e+00 1.00e+00h  1
#  217  3.2695827e+01 3.49e-09 1.05e-03 -12.3 3.04e-03    -  1.00e+00 5.00e-01h  2
#  218  3.2695827e+01 5.01e-09 3.07e-03 -12.3 5.11e-02    -  3.35e-01 1.18e-02h  2
#  219  3.2695827e+01 2.88e-09 1.60e-03 -12.3 2.46e-03    -  6.77e-01 5.00e-01h  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  220  3.2695827e+01 1.44e-08 3.07e-03 -12.3 2.51e-02    -  1.00e+00 5.83e-02h  4
#  221  3.2695827e+01 2.36e-08 2.58e-03 -12.3 7.07e-03    -  3.86e-01 1.25e-01h  4
#  222  3.2695827e+01 4.68e-07 7.82e-03 -12.3 2.23e-02    -  2.16e-01 1.07e-01h  1
#  223  3.2695827e+01 4.11e-07 7.40e-03 -12.3 2.20e-03    -  6.86e-01 1.25e-01f  4
#  224  3.2695825e+01 4.21e-07 5.43e-03 -12.3 1.66e-03    -  4.29e-01 1.00e+00h  1
#  225  3.2695825e+01 4.21e-07 9.92e-04 -12.3 4.43e-02    -  1.00e+00 1.34e-04h  1
#  226  3.2695825e+01 4.15e-07 7.01e-04 -12.3 3.76e-03    -  1.00e+00 1.56e-02h  7
#  227  3.2695825e+01 4.06e-07 1.25e-03 -12.3 2.30e-02    -  7.52e-01 6.25e-02h  5
#  228  3.2695825e+01 4.01e-07 1.19e-03 -12.3 2.43e-02    -  4.61e-01 5.12e-02h  4
#  229  3.2695825e+01 4.01e-07 2.84e-03 -12.3 6.50e-02    -  4.64e-01 5.52e-03h  8
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  230  3.2695826e+01 1.98e-07 1.19e-03 -12.3 1.95e-03    -  1.00e+00 5.00e-01h  2
#  231  3.2695826e+01 2.00e-07 1.47e-03 -12.3 1.77e-02    -  2.60e-01 2.35e-02h  5
#  232  3.2695827e+01 8.15e-12 1.87e-03 -12.3 1.19e-03    -  1.00e+00 1.00e+00h  1
#  233  3.2695827e+01 1.82e-09 1.70e-03 -12.3 1.15e-03    -  1.00e+00 5.00e-01h  2
#  234  3.2695827e+01 4.27e-09 1.33e-03 -12.3 1.85e-03    -  6.81e-01 2.50e-01h  3
#  235  3.2695827e+01 3.31e-08 1.18e-03 -12.3 9.81e-04    -  1.00e+00 5.00e-01h  2
#  236  3.2695827e+01 3.29e-08 1.58e-03 -12.3 3.04e-03    -  6.34e-01 1.25e-01h  4
#  237  3.2695827e+01 3.19e-08 1.98e-03 -12.3 4.90e-03    -  1.00e+00 4.39e-01h  2
#  238  3.2695827e+01 4.13e-08 2.13e-03 -12.3 1.25e-02    -  1.00e+00 1.32e-01h  1
#  239  3.2695827e+01 3.89e-08 1.95e-03 -12.3 9.97e-04    -  2.05e-03 6.25e-02f  5
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  240  3.2695826e+01 4.21e-08 1.38e-02 -12.3 1.80e-03    -  1.00e+00 1.00e+00h  1
#  241  3.2695826e+01 3.28e-07 1.08e-02 -12.3 4.01e-03    -  1.00e+00 5.00e-01h  2
#  242  3.2695825e+01 3.11e-07 7.98e-03 -12.3 1.99e-02    -  2.52e-01 7.87e-02h  4
#  243  3.2695825e+01 2.40e-07 2.01e-03 -12.3 3.82e-03    -  1.00e+00 4.22e-01h  2
#  244  3.2695826e+01 1.19e-07 1.42e-03 -12.3 1.64e-03    -  1.00e+00 1.00e+00h  1
#  245  3.2695826e+01 9.45e-08 2.03e-03 -12.3 5.22e-03    -  2.49e-01 3.98e-01h  2
#  246  3.2695826e+01 9.99e-08 1.94e-03 -12.3 1.05e-02    -  1.00e+00 1.25e-01h  4
#  247  3.2695826e+01 2.73e-08 4.88e-04 -12.3 2.17e-03    -  1.00e+00 1.00e+00h  1
#  248  3.2695826e+01 2.72e-08 7.76e-04 -12.3 4.77e-03    -  1.00e+00 1.01e-01h  3
#  249  3.2695826e+01 2.39e-08 1.06e-03 -12.3 2.61e-03    -  1.87e-01 2.50e-01h  3
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  250  3.2695827e+01 8.27e-09 1.28e-03 -12.3 6.47e-04    -  1.00e+00 1.00e+00h  1
#  251  3.2695827e+01 5.82e-09 3.45e-04 -12.3 2.79e-04    -  1.00e+00 5.00e-01h  2
#  252  3.2695827e+01 5.31e-09 5.03e-04 -12.3 3.22e-04    -  1.00e+00 2.50e-01h  3
#  253  3.2695827e+01 4.13e-09 3.30e-04 -12.3 1.17e-04    -  1.00e+00 2.50e-01h  3
#  254  3.2695827e+01 1.06e-09 1.63e-03 -12.3 5.33e-05    -  1.00e+00 1.00e+00h  1
#  255  3.2695827e+01 4.85e-10 1.03e-03 -12.3 8.78e-05    -  3.95e-01 1.00e+00H  1
#  256  3.2695827e+01 1.76e-10 3.48e-04 -12.3 4.55e-05    -  1.00e+00 1.00e+00h  1
#  257  3.2695827e+01 2.68e-11 2.40e-04 -12.3 1.33e-05    -  1.00e+00 1.00e+00h  1
#  258  3.2695827e+01 9.75e-12 7.95e-05 -12.3 6.21e-06    -  1.00e+00 1.00e+00h  1
#  259  3.2695827e+01 4.51e-14 7.40e-05 -12.3 9.99e-06    -  1.00e+00 1.00e+00H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  260  3.2695827e+01 1.17e-10 1.08e-04 -12.3 2.60e-05    -  1.00e+00 1.00e+00h  1
#  261  3.2695827e+01 2.12e-11 5.15e-05 -12.3 2.35e-05    -  1.00e+00 1.00e+00h  1
#  262  3.2695827e+01 2.55e-11 8.10e-05 -12.3 4.60e-05    -  1.00e+00 1.00e+00h  1
#  263  3.2695827e+01 2.17e-19 1.13e-04 -12.3 3.92e-05    -  1.00e+00 1.00e+00H  1
#  264  3.2695827e+01 6.10e-20 4.87e-04 -12.3 3.04e-04    -  1.00e+00 1.00e+00H  1
#  265  3.2695827e+01 4.34e-19 4.67e-04 -12.3 2.02e-03    -  1.00e+00 1.08e-04h 14
#  266  3.2695827e+01 2.17e-19 4.65e-04 -12.3 7.35e-03    -  8.77e-02 6.10e-05h 15
#  267  3.2695827e+01 1.06e-09 1.97e-04 -12.3 3.79e-04    -  1.00e+00 1.00e+00h  1
#  268  3.2695827e+01 1.06e-09 1.25e-04 -12.3 5.30e-04    -  1.00e+00 4.10e-03h  8
#  269  3.2695827e+01 4.46e-10 2.39e-04 -12.3 8.63e-05    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  270  3.2695827e+01 4.29e-10 2.62e-04 -12.3 1.67e-03    -  1.00e+00 6.25e-02h  5
#  271  3.2695827e+01 4.16e-10 2.83e-04 -12.3 3.77e-04    -  1.00e+00 6.25e-02h  5
#  272  3.2695827e+01 2.08e-09 2.87e-03 -12.3 2.79e-04    -  5.22e-01 1.00e+00h  1
#  273  3.2695827e+01 1.94e-09 1.66e-03 -12.3 2.63e-04    -  1.00e+00 1.00e+00h  1
#  274  3.2695827e+01 1.89e-09 5.33e-04 -12.3 8.84e-04    -  1.00e+00 6.25e-02h  5
#  275  3.2695827e+01 1.89e-09 4.04e-04 -12.3 1.60e-03    -  1.00e+00 2.20e-03h  8
#  276  3.2695827e+01 1.95e-10 7.63e-04 -12.3 1.38e-04    -  1.00e+00 1.00e+00h  1
#  277  3.2695827e+01 2.07e-09 9.30e-04 -12.0 1.87e-03    -  1.00e+00 2.50e-01h  3
#  278  3.2695827e+01 4.34e-19 8.18e-04 -12.2 1.15e-03    -  1.00e+00 1.00e+00H  1
#  279  3.2695827e+01 2.16e-10 1.00e-03 -12.2 9.09e-04    -  1.00e+00 2.50e-01h  3
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  280  3.2695827e+01 7.04e-10 1.72e-03 -12.2 3.54e-03    -  1.00e+00 9.81e-02h  2
#  281  3.2695827e+01 1.21e-09 8.87e-04 -12.2 3.29e-04    -  5.79e-01 2.50e-01h  3
#  282  3.2695827e+01 4.23e-08 1.23e-02 -12.2 1.40e-03    -  1.00e+00 9.19e-01h  1
#  283  3.2695827e+01 2.00e-07 8.04e-03 -12.2 9.05e-04    -  2.42e-03 1.00e+00f  1
#  284  3.2695827e+01 1.05e-07 1.41e-03 -12.2 5.43e-03    -  1.00e+00 5.00e-01h  2
#  285  3.2695827e+01 1.07e-07 9.99e-04 -12.2 4.07e-02    -  3.17e-01 9.00e-03h  1
#  286  3.2695827e+01 8.61e-08 7.53e-04 -12.2 1.33e-03    -  4.40e-02 2.50e-01h  3
#  287  3.2695827e+01 8.61e-08 1.29e-03 -12.2 1.42e-02    -  1.00e+00 2.12e-06h  2
#  288  3.2695827e+01 8.33e-08 1.85e-03 -12.2 2.56e-02    -  2.87e-01 6.25e-02h  5
#  289  3.2695827e+01 8.45e-08 2.10e-03 -12.2 2.19e-02    -  7.67e-02 2.77e-03h  8
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  290  3.2695827e+01 5.01e-08 2.28e-03 -12.2 2.88e-03    -  1.14e-01 5.00e-01h  2
#  291  3.2695827e+01 3.40e-08 4.96e-03 -12.2 6.12e-03    -  1.00e+00 3.86e-01h  1
#  292  3.2695827e+01 3.40e-08 4.95e-03 -12.2 1.36e-03    -  2.21e-04 4.88e-04h 12
#  293  3.2695827e+01 3.40e-08 3.04e-01 -12.2 1.41e-02    -  1.00e+00 3.24e-05h  1
#  294  3.2695827e+01 3.03e-08 2.18e-03 -12.2 2.15e-03    -  9.96e-01 1.25e-01f  4
#  295  3.2695826e+01 4.36e-07 5.10e-03 -12.2 3.51e-02    -  1.04e-07 1.07e-01f  2
#  296  3.2695823e+01 1.04e-06 3.40e-02 -12.2 5.15e-03    -  1.00e+00 1.00e+00h  1
#  297  3.2695823e+01 9.99e-07 1.28e-03 -12.2 5.85e-02    -  1.00e+00 7.36e-02h  1
#  298  3.2695823e+01 9.83e-07 1.27e-03 -12.2 8.64e-03    -  4.98e-04 1.56e-02h  7
#  299  3.2695823e+01 9.53e-07 1.99e-03 -12.2 3.72e-02    -  6.86e-01 6.25e-02h  5
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  300  3.2695822e+01 1.53e-06 4.75e+02 -12.2 2.35e-02    -  3.38e-02 3.44e-01h  2
#  301  3.2695822e+01 1.25e-06 7.41e+02 -12.2 6.59e-03    -  7.75e-01 2.07e-01h  1
#  302  3.2695821e+01 1.13e-06 4.06e+03 -12.2 1.04e-02    -  9.55e-05 5.00e-01f  2
#  303  3.2695821e+01 1.13e-06 2.98e+03 -12.2 2.52e-03    -  1.00e+00 3.22e-03h  1
#  304  3.2695821e+01 1.11e-06 2.87e+03 -12.2 5.57e-03    -  5.12e-02 1.56e-02h  7
# In iteration 304, 1 Slack too small, adjusting variable bound
#  305  3.2695824e+01 8.93e-07 4.61e-03 -12.2 9.59e-03    -  7.79e-01 3.28e-01h  1
#  306  3.2695825e+01 5.57e-07 2.73e-03 -12.2 1.66e-03    -  1.00e+00 1.00e+00h  1
#  307  3.2695826e+01 8.53e-09 2.34e-03 -12.2 2.07e-03    -  1.00e+00 1.00e+00h  1
#  308  3.2695823e+01 2.83e-07 8.29e-03 -12.2 8.77e-03    -  3.13e-01 2.50e-01h  3
#  309  3.2695823e+01 1.69e-07 1.94e-03 -12.2 1.52e-03    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  310  3.2695825e+01 4.01e-08 1.21e-03 -12.3 2.22e-03    -  1.00e+00 1.00e+00h  1
#  311  3.2695825e+01 3.56e-08 9.18e-04 -12.3 6.54e-03    -  1.00e+00 2.50e-01h  3
#  312  3.2695825e+01 3.49e-08 6.16e-04 -12.3 4.91e-03    -  1.00e+00 1.25e-01h  4
#  313  3.2695827e+01 7.26e-09 1.35e-03 -12.3 2.11e-03    -  1.00e+00 1.00e+00h  1
#  314  3.2695826e+01 1.77e-08 1.86e-03 -12.0 1.02e-02    -  1.00e+00 7.08e-02h  1
#  315  3.2695826e+01 1.54e-07 1.57e-03 -12.2 1.61e-03    -  8.58e-05 1.00e+00h  1
#  316  3.2695825e+01 2.75e-07 3.06e-03 -12.2 1.35e-03    -  1.00e+00 1.00e+00h  1
#  317  3.2695825e+01 2.03e-07 4.42e-03 -12.2 3.19e-03    -  1.00e+00 1.00e+00h  1
#  318  3.2695824e+01 3.55e-07 3.60e-04 -12.2 3.38e-03    -  1.00e+00 1.00e+00h  1
#  319  3.2695825e+01 2.29e-07 1.31e-03 -12.2 1.26e-03    -  1.00e+00 5.00e-01h  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  320  3.2695827e+01 1.78e-11 2.02e-03 -12.2 1.86e-03    -  1.00e+00 1.00e+00h  1
#  321  3.2695826e+01 4.18e-08 2.58e-03 -12.2 4.81e-03    -  4.19e-02 1.89e-01h  3
#  322  3.2695824e+01 1.33e-07 2.93e-03 -12.2 1.29e-03    -  1.00e+00 1.00e+00h  1
#  323  3.2695826e+01 3.63e-08 9.25e-04 -12.2 1.16e-03    -  1.00e+00 1.00e+00h  1
#  324  3.2695826e+01 3.37e-08 9.32e-04 -12.2 1.62e-03    -  1.00e+00 2.50e-01h  3
#  325  3.2695827e+01 2.52e-08 2.22e-03 -12.3 9.71e-04    -  1.00e+00 1.00e+00H  1
#  326  3.2695827e+01 1.53e-07 1.74e-03 -12.3 2.35e-03    -  1.00e+00 1.00e+00h  1
#  327  3.2695826e+01 1.13e-07 1.69e-03 -12.3 2.73e-03    -  1.00e+00 4.28e-01h  1
#  328  3.2695826e+01 1.13e-07 1.68e-03 -12.3 1.01e-03    -  5.59e-04 3.91e-03h  9
#  329  3.2695825e+01 1.98e-07 1.41e-02 -12.3 8.54e-03    -  1.00e+00 3.63e-01h  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  330  3.2695827e+01 7.98e-09 5.73e-03 -12.3 4.52e-03    -  1.00e+00 1.00e+00h  1
#  331  3.2695827e+01 5.38e-08 3.32e-03 -12.3 2.49e-03    -  7.91e-01 2.50e-01h  3
#  332  3.2695826e+01 2.14e-08 4.06e-04 -12.3 2.58e-03    -  1.00e+00 1.00e+00h  1
#  333  3.2695826e+01 1.78e-08 9.53e-04 -12.3 1.28e-03    -  1.00e+00 5.00e-01h  2
#  334  3.2695826e+01 1.92e-08 5.87e-04 -12.3 4.47e-03    -  8.59e-01 2.84e-02h  6
#  335  3.2695826e+01 1.71e-08 6.62e-04 -12.3 4.38e-04    -  1.00e+00 5.00e-01h  2
#  336  3.2695827e+01 2.82e-12 1.55e-03 -12.3 8.82e-04    -  1.00e+00 1.00e+00H  1
#  337  3.2695827e+01 1.43e-08 1.30e-03 -12.3 3.73e-04    -  1.99e-01 1.00e+00h  1
#  338  3.2695827e+01 8.76e-09 2.10e-03 -12.3 3.56e-04    -  1.00e+00 1.00e+00h  1
#  339  3.2695827e+01 1.78e-09 8.81e-04 -12.3 5.94e-04    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  340  3.2695828e+01 7.12e-10 4.63e-03 -12.3 4.06e-03    -  1.00e+00 1.83e-01H  1
#  341  3.2695827e+01 8.15e-10 1.89e-03 -12.3 2.05e-03    -  7.30e-03 1.00e+00F  1
#  342  3.2695827e+01 1.20e-09 1.93e-03 -12.3 4.22e-03    -  1.00e+00 8.19e-03h  7
#  343  3.2695826e+01 1.05e-08 1.69e-03 -12.3 7.02e-04    -  1.04e-02 1.00e+00h  1
#  344  3.2695827e+01 9.75e-12 1.28e-03 -12.3 5.39e-04    -  1.00e+00 1.00e+00H  1
#  345  3.2695828e+01 6.07e-12 4.22e-03 -12.1 2.99e-03    -  1.00e+00 6.97e-01H  1
#  346  3.2695828e+01 1.18e-09 4.55e-03 -12.2 3.83e-03    -  1.00e+00 3.14e-01h  2
#  347  3.2695827e+01 9.72e-08 4.20e-03 -12.2 3.01e-02    -  3.43e-02 1.60e-01h  3
#  348  3.2695827e+01 1.21e-07 4.30e-03 -12.2 4.01e-02    -  5.15e-01 6.25e-02h  5
#  349  3.2695824e+01 1.06e-06 8.71e+02 -12.2 2.38e-03    -  6.76e-01 4.27e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  350  3.2695824e+01 1.03e-06 6.06e+02 -12.2 1.70e-03    -  6.44e-04 3.12e-02h  6
#  351  3.2695824e+01 1.03e-06 2.09e+05 -12.2 4.24e-02    -  4.96e-01 3.69e-06H  1
#  352  3.2695824e+01 8.31e-07 4.03e-02 -12.2 1.37e-02    -  2.81e-01 2.50e-01f  3
#  353  3.2695824e+01 8.82e-07 8.62e-02 -12.2 2.26e-01    -  3.66e-02 1.56e-02h  7
#  354  3.2695826e+01 4.46e-07 1.55e-02 -12.2 3.76e-03    -  1.00e+00 5.00e-01h  2
#  355  3.2695826e+01 4.08e-07 3.13e-03 -12.2 4.09e-02    -  8.26e-01 1.25e-01h  4
#  356  3.2695826e+01 6.50e-07 3.29e-03 -12.2 4.36e-01    -  1.31e-02 6.02e-03h  3
#  357  3.2695826e+01 6.34e-07 2.56e-03 -12.2 6.51e-02    -  2.22e-01 3.06e-02h  3
#  358  3.2695825e+01 3.13e-07 2.36e-03 -12.2 4.06e-03    -  3.23e-01 1.00e+00h  1
#  359  3.2695824e+01 3.20e-07 2.49e-03 -12.2 5.89e-03    -  5.20e-01 6.79e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  360  3.2695824e+01 3.09e-07 2.61e-03 -12.2 1.78e-03    -  1.00e+00 3.47e-02f  4
#  361  3.2695823e+01 3.22e-07 2.31e-03 -12.2 9.71e-03    -  1.02e-01 4.83e-02h  1
#  362  3.2695807e+01 3.87e-06 9.60e+02 -12.2 3.74e-03    -  6.76e-01 5.10e-01f  1
#  363  3.2695808e+01 3.41e-06 1.08e+03 -12.2 3.51e-03    -  6.53e-06 1.25e-01h  4
#  364  3.2695816e+01 1.93e-06 1.82e-02 -12.2 1.51e-03    -  1.00e+00 1.00e+00h  1
#  365  3.2695821e+01 4.71e-07 2.14e-03  -9.4 1.56e-03    -  1.00e+00 1.00e+00h  1
#  366  3.2695822e+01 2.60e-07 1.94e-03 -10.8 8.12e-04    -  1.00e+00 1.00e+00h  1
#  367  3.2695823e+01 1.35e-07 7.00e-04  -9.4 7.50e-04    -  1.00e+00 1.00e+00h  1
#  368  3.2695825e+01 6.03e-08 9.35e-04  -9.6 3.29e-04    -  1.00e+00 1.00e+00h  1
#  369  3.2695826e+01 1.90e-08 1.80e-03  -9.7 1.41e-04    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  370  3.2695826e+01 1.31e-08 7.90e-04  -9.7 2.93e-04    -  1.00e+00 1.00e+00h  1
#  371  3.2695827e+01 5.10e-09 1.08e-03  -9.7 6.41e-05    -  1.00e+00 1.00e+00h  1
#  372  3.2695827e+01 4.52e-09 1.19e-03  -9.7 6.51e-05    -  1.00e+00 1.00e+00h  1
#  373  3.2695827e+01 1.21e-09 9.90e-04  -9.7 3.32e-05    -  1.00e+00 1.00e+00h  1
#  374  3.2695827e+01 6.90e-10 7.17e-04  -9.7 2.50e-05    -  1.00e+00 1.00e+00h  1
#  375  3.2695827e+01 9.13e-11 8.11e-04  -9.7 3.13e-05    -  1.00e+00 1.00e+00h  1
#  376  3.2695827e+01 6.04e-11 8.58e-04  -9.7 1.12e-05    -  1.00e+00 1.00e+00h  1
#  377  3.2695827e+01 1.38e-11 2.84e-04  -9.7 7.33e-06    -  1.00e+00 1.00e+00h  1
#  378  3.2695827e+01 1.60e-14 1.81e-04  -9.7 1.18e-05    -  1.00e+00 1.00e+00h  1
#  379  3.2695827e+01 9.65e-16 1.66e-04  -9.7 3.57e-05    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  380  3.2695827e+01 3.29e-10 1.82e-03  -9.7 1.57e-03    -  1.00e+00 3.67e-01H  1
#  381  3.2695827e+01 3.61e-10 1.72e-03  -9.7 1.73e-03    -  1.54e-02 5.00e-01f  2
#  382  3.2695827e+01 1.08e-09 1.15e-03  -9.7 1.63e-03    -  1.00e+00 1.25e-01h  4
#  383  3.2695827e+01 7.55e-14 6.00e-04  -9.7 2.52e-04    -  3.39e-01 1.00e+00H  1
#  384  3.2695827e+01 3.71e-10 2.29e-04  -9.7 1.12e-04    -  1.00e+00 1.00e+00H  1
#  385  3.2695827e+01 2.91e-10 6.88e-04  -9.7 5.33e-04    -  1.00e+00 1.00e+00h  1
#  386  3.2695827e+01 1.04e-10 1.04e-03  -9.7 7.01e-04    -  1.00e+00 1.00e+00h  1
#  387  3.2695827e+01 5.73e-10 6.95e-04  -9.7 1.57e-02    -  1.00e+00 7.66e-03h  5
#  388  3.2695827e+01 8.56e-10 9.83e-04  -9.7 3.41e-03    -  9.24e-02 3.12e-02h  6
#  389  3.2695827e+01 1.32e-14 4.36e-04  -9.7 5.62e-04    -  1.00e+00 1.00e+00H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  390  3.2695827e+01 1.42e-10 1.04e-03  -9.7 1.08e-02    -  1.00e+00 2.73e-02h  2
#  391  3.2695827e+01 9.62e-12 1.39e-04  -9.7 1.36e-04    -  5.88e-01 1.00e+00h  1
#  392  3.2695827e+01 2.30e-11 9.68e-04 -10.8 5.45e-04    -  9.98e-01 1.00e+00H  1
#  393  3.2695827e+01 1.04e-08 1.56e-03 -10.9 1.25e-04    -  1.00e+00 1.00e+00h  1
#  394  3.2695827e+01 1.90e-07 1.13e-02 -10.9 1.09e-03    -  3.13e-01 1.00e+00h  1
#  395  3.2695826e+01 2.16e-07 7.57e-03 -10.9 1.57e-03    -  1.00e+00 1.00e+00h  1
#  396  3.2695827e+01 1.91e-07 9.18e-03 -10.9 2.21e-02    -  5.71e-01 3.63e-03H  1
#  397  3.2695827e+01 1.42e-07 7.64e-03 -10.9 2.03e-03    -  1.79e-03 2.50e-01f  3
#  398  3.2695827e+01 6.14e-09 3.03e-03 -10.9 9.81e-04    -  1.00e+00 1.00e+00h  1
#  399  3.2695827e+01 1.30e-08 2.43e-03 -10.9 1.84e-03    -  1.00e+00 5.00e-01h  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  400  3.2695827e+01 7.24e-08 1.81e-03 -10.9 1.79e-02    -  1.05e-01 7.81e-02h  4
#  401  3.2695826e+01 1.60e-07 5.34e-02 -10.9 5.26e-03    -  1.00e+00 1.87e-01h  1
#  402  3.2695826e+01 1.17e-07 1.52e-02 -10.9 4.32e-03    -  1.00e+00 2.89e-01f  1
#  403  3.2695826e+01 1.12e-07 1.48e-02 -10.9 7.27e-03    -  1.13e-04 1.61e-01f  3
#  404  3.2695826e+01 1.59e-06 7.93e+03 -10.9 1.18e-02    -  3.32e-01 1.26e-01h  1
#  405  3.2695826e+01 1.59e-06 7.93e+03 -10.9 1.56e-03    -  4.05e-06 4.44e-05h 15
#  406  3.2695820e+01 1.40e-06 5.84e+04 -10.9 2.20e-03    -  1.52e-01 9.74e-01h  1
#  407  3.2695820e+01 1.39e-06 3.74e+04 -10.9 2.17e-03    -  5.44e-01 3.91e-03h  9
#  408  3.2695825e+01 8.52e-07 1.95e-02 -10.9 7.06e-03    -  6.24e-02 7.91e-01h  1
#  409  3.2695825e+01 8.52e-07 1.37e-03 -10.9 3.59e-02    -  1.00e+00 6.72e-05f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  410  3.2695825e+01 8.52e-07 1.29e-03 -10.9 3.92e-03    -  8.91e-02 1.22e-04f 14
#  411  3.2695825e+01 8.52e-07 1.32e-03 -10.9 1.06e-01    -  1.06e-01 3.21e-05h 12
#  412  3.2695825e+01 5.56e-07 7.06e-03 -10.9 3.82e-03    -  2.16e-01 1.00e+00h  1
#  413  3.2695825e+01 5.47e-07 1.02e-02 -10.9 2.06e-02    -  8.87e-01 2.33e-03H  1
#  414  3.2695825e+01 4.80e-07 8.71e-03 -10.9 2.74e-03    -  2.79e-03 1.25e-01f  4
#  415  3.2695823e+01 7.08e-07 3.14e-03 -10.9 5.88e-03    -  1.00e+00 2.20e-01h  2
#  416  3.2695825e+01 1.87e-07 8.59e-04 -10.9 3.84e-03    -  9.24e-01 1.00e+00h  1
#  417  3.2695825e+01 1.84e-07 1.71e-03 -10.9 5.64e-03    -  1.00e+00 2.50e-01h  3
#  418  3.2695825e+01 1.85e-07 1.13e-03 -10.9 7.11e-03    -  3.05e-01 1.25e-01h  4
#  419  3.2695825e+01 1.50e-07 1.10e-03 -10.9 4.00e-03    -  1.00e+00 3.41e-01h  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  420  3.2695826e+01 1.11e-07 1.71e-03 -10.9 2.17e-03    -  1.00e+00 1.00e+00h  1
#  421  3.2695826e+01 1.18e-07 2.28e-03 -10.9 8.22e-03    -  1.88e-01 2.50e-01h  3
#  422  3.2695823e+01 7.70e-07 2.82e-03 -10.9 1.08e-03    -  1.00e+00 1.00e+00h  1
#  423  3.2695824e+01 3.37e-07 9.22e-04 -10.9 2.48e-03    -  1.00e+00 1.00e+00h  1
#  424  3.2695825e+01 2.54e-07 8.72e-04 -10.9 4.23e-03    -  1.00e+00 2.50e-01h  3
#  425  3.2695826e+01 1.48e-07 1.30e-03 -10.9 4.15e-03    -  1.00e+00 5.00e-01h  2
#  426  3.2695826e+01 1.22e-07 1.84e-03 -10.9 5.07e-03    -  1.00e+00 2.50e-01h  3
#  427  3.2695826e+01 6.54e-08 2.77e-03 -10.9 5.43e-04    -  1.00e+00 1.00e+00h  1
#  428  3.2695825e+01 4.94e-08 2.04e-03 -10.9 4.75e-04    -  3.30e-01 1.00e+00h  1
#  429  3.2695827e+01 2.79e-08 1.31e-03 -10.9 2.46e-04    -  1.00e+00 1.00e+00H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  430  3.2695827e+01 3.13e-08 8.58e-03 -10.9 2.70e-04    -  1.00e+00 8.81e-01h  1
#  431  3.2695827e+01 3.13e-08 1.62e-03 -10.9 5.79e-05    -  1.00e+00 2.44e-04f 13
#  432  3.2695827e+01 2.22e-09 9.17e-04 -10.9 1.36e-04    -  7.71e-01 1.00e+00h  1
#  433  3.2695827e+01 1.19e-09 8.72e-04 -11.2 2.91e-05    -  1.00e+00 1.00e+00h  1
#  434  3.2695827e+01 1.13e-09 1.90e-03 -11.4 7.01e-05    -  1.00e+00 1.00e+00h  1
#  435  3.2695827e+01 6.75e-10 7.04e-04 -11.4 5.81e-05    -  1.00e+00 1.00e+00H  1
#  436  3.2695827e+01 8.35e-10 6.34e-04 -11.4 2.98e-05    -  1.00e+00 1.00e+00h  1
#  437  3.2695827e+01 5.40e-11 1.94e-04 -11.4 9.07e-06    -  1.00e+00 1.00e+00h  1
#  438  3.2695827e+01 2.46e-11 5.93e-05 -11.4 7.94e-06    -  1.00e+00 1.00e+00h  1
#  439  3.2695827e+01 2.73e-17 1.06e-04 -11.4 1.95e-05    -  1.00e+00 1.00e+00H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  440  3.2695827e+01 4.04e-12 4.99e-05 -11.4 3.44e-05    -  1.00e+00 1.00e+00H  1
#  441  3.2695827e+01 1.07e-11 2.02e-04 -11.4 9.03e-05    -  1.00e+00 1.00e+00h  1
#  442  3.2695827e+01 4.72e-11 2.12e-04 -11.4 5.95e-05    -  1.00e+00 1.00e+00h  1
#  443  3.2695827e+01 1.38e-11 1.83e-04 -11.4 3.79e-05    -  1.00e+00 1.00e+00h  1
#  444  3.2695827e+01 2.08e-13 6.82e-05 -11.4 1.77e-05    -  1.00e+00 1.00e+00H  1
#  445  3.2695827e+01 4.34e-19 1.46e-03 -11.4 5.71e-05    -  1.00e+00 1.00e+00H  1
#  446  3.2695827e+01 6.00e-10 2.15e-04 -11.4 6.43e-05    -  1.00e+00 1.00e+00h  1
#  447  3.2695827e+01 5.67e-12 2.39e-04 -11.4 7.69e-06    -  1.00e+00 1.00e+00h  1
#  448  3.2695827e+01 1.95e-13 6.60e-05 -11.4 7.51e-06    -  1.00e+00 1.00e+00h  1
#  449  3.2695827e+01 2.70e-16 1.04e-05 -12.3 2.78e-06    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  450  3.2695827e+01 2.17e-19 5.33e-05 -12.3 5.65e-06    -  1.00e+00 1.00e+00H  1
#  451  3.2695827e+01 1.68e-12 2.81e-05 -12.3 4.13e-06    -  1.00e+00 1.00e+00h  1
#  452  3.2695827e+01 4.34e-19 9.60e-05 -12.3 9.78e-06    -  1.00e+00 1.00e+00H  1
#  453  3.2695827e+01 6.10e-12 6.46e-06 -12.3 6.38e-06    -  1.00e+00 1.00e+00h  1
#  454  3.2695827e+01 3.39e-20 2.08e-05 -12.3 2.29e-05    -  1.00e+00 1.00e+00H  1
#  455  3.2695827e+01 3.89e-11 3.66e-06 -12.3 1.34e-05    -  1.00e+00 1.00e+00h  1
#  456  3.2695827e+01 2.96e-11 9.26e-05 -12.3 8.02e-06    -  1.00e+00 2.50e-01h  3
#  457  3.2695827e+01 2.25e-13 1.86e-06 -12.3 1.98e-06    -  1.00e+00 1.00e+00h  1
#  458  3.2695827e+01 4.34e-19 1.85e-06 -12.3 1.07e-07    -  1.00e+00 1.00e+00h  1
#  459  3.2695827e+01 3.29e-18 8.95e-06 -12.3 1.09e-05    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  460  3.2695827e+01 2.17e-19 3.44e-04 -12.3 2.64e-05    -  1.00e+00 1.00e+00H  1
#  461  3.2695827e+01 1.15e-10 2.26e-05 -12.3 2.73e-05    -  1.00e+00 1.00e+00h  1
#  462  3.2695827e+01 2.77e-13 3.63e-05 -12.3 1.32e-06    -  1.00e+00 1.00e+00h  1
#  463  3.2695827e+01 1.46e-14 6.76e-06 -12.3 8.09e-07    -  1.00e+00 1.00e+00h  1
#  464  3.2695827e+01 1.66e-19 6.83e-07 -12.3 1.32e-07    -  1.00e+00 1.00e+00h  1
#  465  3.2695827e+01 2.71e-20 4.94e-06 -12.3 9.77e-07    -  1.00e+00 1.00e+00h  1
#  466  3.2695827e+01 4.34e-19 3.02e-05 -12.3 2.23e-05    -  1.00e+00 1.00e+00H  1
#  467  3.2695827e+01 1.38e-16 4.99e-06 -12.3 2.32e-05    -  1.00e+00 1.00e+00h  1
#  468  3.2695827e+01 4.34e-19 6.47e-05 -12.3 6.67e-06    -  1.00e+00 1.00e+00H  1
#  469  3.2695827e+01 1.04e-11 1.71e-06 -12.3 6.42e-06    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  470  3.2695827e+01 5.18e-12 6.54e-07 -12.3 7.06e-07    -  1.00e+00 5.00e-01h  2
#  471  3.2695827e+01 2.55e-12 5.77e-06 -12.3 5.56e-06    -  1.00e+00 5.00e-01h  2
#  472  3.2695827e+01 1.90e-12 2.38e-05 -12.3 1.29e-05    -  1.00e+00 2.50e-01h  3
#  473  3.2695827e+01 1.40e-12 1.67e-05 -12.3 9.07e-06    -  1.00e+00 2.50e-01h  3
#  474  3.2695827e+01 1.36e-12 1.79e-05 -12.3 7.86e-05    -  1.00e+00 3.12e-02h  6
#  475  3.2695827e+01 2.17e-19 1.20e-04 -12.3 1.16e-05    -  1.00e+00 1.00e+00H  1
#  476  3.2695827e+01 2.51e-12 5.27e-06 -12.3 1.09e-05    -  1.00e+00 1.00e+00h  1
#  477  3.2695827e+01 4.34e-19 2.32e-04 -12.3 1.77e-05    -  1.00e+00 1.00e+00H  1
#  478  3.2695827e+01 1.78e-11 1.08e-05 -12.3 1.71e-05    -  1.00e+00 1.00e+00h  1
#  479  3.2695827e+01 6.23e-17 1.90e-05 -12.3 6.40e-06    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  480  3.2695827e+01 4.34e-19 1.56e-05 -12.3 1.28e-05    -  1.00e+00 1.00e+00H  1
#  481  3.2695827e+01 2.17e-19 1.36e-04 -12.3 2.21e-04    -  1.00e+00 1.00e+00H  1
#  482  3.2695827e+01 2.81e-19 1.36e-04 -12.3 2.50e-04    -  1.00e+00 1.95e-03h 10
#  483  3.2695827e+01 2.17e-19 1.87e-04 -12.3 2.55e-03    -  1.00e+00 1.08e-05h 15
#  484  3.2695827e+01 9.44e-11 7.58e-05 -12.3 2.79e-04    -  1.00e+00 1.00e+00h  1
#  485  3.2695827e+01 9.32e-11 5.93e-05 -12.3 3.02e-04    -  1.00e+00 1.57e-02h  6
#  486  3.2695827e+01 1.50e-10 1.53e-04 -12.3 1.10e-04    -  1.00e+00 1.00e+00h  1
#  487  3.2695827e+01 2.14e-10 1.30e-04 -12.3 4.66e-03    -  1.00e+00 1.81e-02h  6
#  488  3.2695827e+01 4.34e-19 9.82e-05 -12.3 2.14e-04    -  1.00e+00 1.00e+00H  1
#  489  3.2695827e+01 4.34e-19 9.41e-05 -12.3 4.68e-04    -  1.00e+00 9.77e-04h 11
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  490  3.2695827e+01 5.79e-19 1.26e-04 -12.3 8.98e-03    -  1.00e+00 3.40e-06h 15
#  491  3.2695827e+01 6.08e-19 1.18e-04 -12.3 4.03e-04    -  1.00e+00 1.53e-05h 17
#  492  3.2695827e+01 5.69e-19 1.13e-04 -12.3 5.56e-03    -  1.06e-01 1.91e-06h 20
#  493  3.2695827e+01 2.49e-09 1.02e-03 -12.3 8.50e-04    -  1.00e+00 2.50e-01f  3
#  494  3.2695827e+01 2.40e-09 6.66e-04 -12.3 5.62e-03    -  1.00e+00 6.25e-02h  5
#  495  3.2695827e+01 4.49e-09 6.75e-04 -12.3 2.58e-03    -  1.00e+00 2.50e-01h  3
#  496  3.2695827e+01 5.42e-09 1.01e-03 -12.3 5.40e-03    -  1.00e+00 8.18e-02h  3
#  497  3.2695827e+01 5.45e-09 1.33e-03 -12.3 8.65e-03    -  5.18e-02 1.56e-02h  7
#  498  3.2695827e+01 9.74e-10 1.79e-04 -12.3 4.45e-04    -  1.00e+00 1.00e+00h  1
#  499  3.2695827e+01 9.69e-10 9.04e-05 -12.3 2.86e-03    -  1.00e+00 1.46e-02h  5
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  500  3.2695827e+01 1.79e-09 1.79e-04 -12.3 1.79e-03    -  8.03e-01 1.25e-01h  4
#  501  3.2695827e+01 1.78e-09 1.75e-04 -12.3 1.93e-03    -  1.00e+00 3.91e-03h  9
#  502  3.2695827e+01 1.78e-09 1.66e-04 -12.3 1.67e-03    -  1.00e+00 4.88e-04h 12
#  503  3.2695827e+01 1.78e-09 1.68e-04 -12.3 2.55e-04    -  1.00e+00 2.44e-04h 13
#  504  3.2695827e+01 1.98e-09 2.71e-04 -12.3 1.06e-03    -  1.00e+00 6.25e-02h  5
#  505  3.2695827e+01 1.95e-09 2.46e-04 -12.3 7.30e-04    -  1.00e+00 1.56e-02h  7
#  506  3.2695827e+01 1.95e-09 2.53e-04 -12.3 5.91e-04    -  1.00e+00 7.70e-04h 11
#  507  3.2695827e+01 1.90e-09 1.75e-04 -12.3 6.46e-04    -  1.00e+00 3.12e-02h  6
#  508  3.2695827e+01 4.81e-11 5.18e-04 -12.3 2.81e-04    -  1.00e+00 1.00e+00h  1
#  509  3.2695827e+01 6.85e-11 4.90e-04 -12.3 1.26e-03    -  1.00e+00 1.64e-01h  3
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  510  3.2695827e+01 3.35e-10 5.97e-04 -12.3 3.03e-03    -  5.64e-01 3.12e-02h  6
#  511  3.2695827e+01 3.33e-10 5.61e-04 -12.3 4.53e-03    -  1.00e+00 3.18e-02h  5
#  512  3.2695827e+01 5.19e-10 3.79e-04 -12.3 5.20e-04    -  1.00e+00 1.25e-01h  4
#  513  3.2695827e+01 8.04e-10 1.32e-04 -12.3 1.28e-03    -  5.43e-01 1.25e-01h  4
#  514  3.2695827e+01 9.09e-10 3.24e-04 -12.3 3.22e-03    -  1.00e+00 3.12e-02h  6
#  515  3.2695827e+01 6.97e-10 3.86e-04 -12.3 1.15e-03    -  1.00e+00 2.50e-01h  3
#  516  3.2695827e+01 6.85e-10 3.39e-04 -12.3 4.76e-04    -  1.00e+00 2.50e-01h  3
#  517  3.2695827e+01 9.02e-10 2.42e-04 -12.3 6.47e-03    -  8.55e-02 1.56e-02h  7
#  518  3.2695827e+01 8.01e-10 1.95e-04 -12.3 2.26e-03    -  1.00e+00 1.25e-01h  4
#  519  3.2695842e+01 3.05e-06 5.82e+02 -12.3 2.47e-02    -  8.71e-02 6.04e-01w  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  520  3.2695831e+01 2.18e-06 8.92e+03 -12.3 1.51e-02    -  7.13e-05 3.57e-01w  1
#  521  3.2695826e+01 2.45e-06 2.07e+04 -12.3 2.48e-02    -  3.16e-06 6.59e-02h  1
#  522  3.2695826e+01 2.27e-06 4.96e+04 -12.3 1.23e-02    -  1.00e+00 7.64e-02h  4
# ...
#  532  3.2695827e+01 1.84e-06 3.27e+04 -12.3 1.11e-02    -  2.22e-03 1.52e-06H  1
#  533  3.2695827e+01 1.83e-06 3.46e+04 -12.3 1.12e-02    -  2.50e-02 7.81e-03h  8
#  534  3.2695827e+01 1.82e-06 3.43e+04 -12.3 5.83e-02    -  7.44e-03 7.28e-03h  2
#  535  3.2695827e+01 1.79e-06 4.08e+04 -12.3 1.10e-02    -  7.32e-02 1.56e-02h  7
#  536  3.2695827e+01 1.79e-06 4.16e+04 -12.3 6.97e-03    -  7.56e-02 3.91e-03h  9
#  537  3.2695827e+01 1.78e-06 4.23e+04 -12.3 1.38e-02    -  8.68e-02 1.95e-03h 10
#  538  3.2695844e+01 5.11e-07 2.16e-02 -12.3 6.11e-03    -  6.45e-02 1.00e+00h  1
#  539  3.2695892e+01 4.83e-07 6.69e+00 -12.3 1.46e-02    -  4.37e-02 3.24e-01H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  540  3.2695867e+01 4.51e-07 2.38e+00 -12.3 3.88e-02    -  2.94e-01 2.49e-01f  2
#  541  3.2695867e+01 4.25e-07 2.64e+00 -12.3 2.03e-02    -  5.81e-03 6.25e-02h  1
#  542  3.2696038e+01 2.78e-10 8.19e+00 -12.3 2.20e-02    -  3.08e-05 1.00e+00h  1
#  543  3.2696036e+01 2.77e-10 7.04e+00 -12.3 4.44e-02    -  1.87e-01 4.03e-03h  1
#  544  3.2696036e+01 2.77e-10 7.04e+00 -12.3 2.11e+00    -  7.28e-04 1.67e-07h  1
#  545  3.2695917e+01 7.92e-11 3.30e+00 -12.3 4.28e-02    -  1.62e-01 1.00e+00f  1
#  546  3.2695917e+01 7.92e-11 3.56e+00 -12.3 2.34e+00    -  4.96e-03 9.72e-09h  1
#  547  3.2695899e+01 2.94e-09 5.20e-01 -12.3 6.87e-03    -  5.51e-01 1.00e+00f  1
#  548  3.2695884e+01 2.17e-08 2.25e-01 -12.3 1.82e-01    -  4.05e-01 1.11e-01f  1
#  549  3.2695884e+01 2.17e-08 2.25e-01 -12.3 4.48e-02    -  3.00e-08 2.87e-09h 25
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  550  3.2695884e+01 2.17e-08 2.25e-01 -12.3 3.36e-03    -  4.24e-09 3.94e-08h  2
#  551  3.2695865e+01 3.62e-07 2.25e-01 -12.3 1.30e-02    -  4.13e-07 6.11e-02h  1
#  552  3.2695865e+01 3.62e-07 2.25e-01 -12.3 2.48e-02    -  4.05e-06 7.56e-06h  1
#  553  3.2695865e+01 3.62e-07 2.25e-01 -12.3 1.47e-02    -  8.61e-06 9.46e-04h  1
#  554  3.2695865e+01 3.62e-07 3.22e-01 -12.3 9.36e-03    -  6.29e-05 5.89e-05h  1
#  555  3.2695865e+01 3.62e-07 2.41e+01 -12.3 6.36e-03    -  1.16e-04 1.12e-04h  1
#  556  3.2695776e+01 2.81e-05 1.77e+02 -12.3 6.82e-03    -  3.69e-01 1.00e+00f  1
#  557  3.2695740e+01 4.74e-05 4.29e+03 -12.3 1.51e-02    -  3.65e-01 7.64e-01h  1
#  558  3.2695769e+01 1.39e-05 3.75e+03 -12.3 5.20e-03    -  4.45e-01 1.00e+00h  1
#  559  3.2695797e+01 6.65e-06 5.33e+02 -12.3 2.68e-03    -  8.58e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  560  3.2695808e+01 4.35e-06 4.84e+02 -10.4 2.81e-03    -  7.24e-03 1.00e+00h  1
#  561  3.2695823e+01 2.14e-06 1.61e+02 -10.4 1.36e-03    -  6.69e-01 8.01e-01h  1
#  562  3.2695823e+01 2.14e-06 1.33e+02 -10.4 9.35e-04    -  1.78e-01 1.53e-05f 17
#  563  3.2695850e+01 5.79e-07 1.73e-01 -10.4 8.23e-04    -  1.52e-01 1.00e+00h  1
#  564  3.2695858e+01 3.76e-07 1.58e-01 -10.4 7.37e-04    -  8.19e-02 6.49e-01h  1
#  565  3.2695858e+01 3.76e-07 1.56e-01 -10.4 3.72e-04    -  1.18e-02 6.10e-05f 15
#  566  3.2695859e+01 2.84e-07 1.57e-01 -10.4 4.02e-04    -  4.03e-03 2.91e-01h  1
#  567  3.2695859e+01 2.84e-07 1.57e-01 -10.4 6.90e-04    -  8.87e-05 6.10e-05f 15
# In iteration 567, 1 Slack too small, adjusting variable bound
#  568  3.2695859e+01 2.84e-07 1.51e-01 -10.4 1.79e-03    -  3.37e-02 9.38e-09H  1
#  569  3.2695855e+01 2.00e-07 1.42e-01 -10.4 2.11e-03    -  1.81e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  570  3.2695854e+01 1.99e-08 1.44e-01 -10.4 1.66e-04    -  2.34e-03 1.00e+00h  1
#  571  3.2695844e+01 9.13e-08 5.96e-02 -10.4 4.20e-04    -  6.10e-01 1.00e+00h  1
#  572  3.2695835e+01 1.53e-07 3.60e-02 -10.4 6.13e-04    -  3.96e-01 6.53e-01h  1
#  573  3.2695828e+01 3.54e-07 2.17e-03 -10.4 4.83e-04    -  8.84e-01 1.00e+00f  1
#  574  3.2695827e+01 1.43e-07 4.47e-03 -10.4 4.32e-04    -  8.06e-02 1.00e+00h  1
#  575  3.2695826e+01 2.95e-08 3.08e-03 -10.4 1.75e-04    -  1.00e+00 1.00e+00h  1
#  576  3.2695827e+01 1.13e-08 1.46e-03 -10.4 8.14e-05    -  1.00e+00 1.00e+00h  1
#  577  3.2695827e+01 3.44e-09 2.01e-03 -10.4 7.11e-05    -  1.00e+00 9.67e-01h  1
#  578  3.2695827e+01 3.44e-09 2.06e-03 -10.4 3.32e-05    -  7.73e-01 1.95e-03f 10
#  579  3.2695827e+01 1.65e-09 2.53e-04 -10.4 3.35e-05    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  580  3.2695827e+01 1.81e-10 3.41e-04 -10.4 1.03e-05    -  1.00e+00 1.00e+00h  1
#  581  3.2695827e+01 5.49e-12 2.51e-04 -10.4 6.41e-06    -  1.00e+00 1.00e+00h  1
#  582  3.2695827e+01 1.81e-12 2.50e-04 -10.4 6.55e-06    -  1.00e+00 1.00e+00h  1
#  583  3.2695827e+01 7.21e-15 2.46e-04 -10.4 2.99e-05    -  1.00e+00 1.00e+00h  1
#  584  3.2695827e+01 1.47e-09 1.44e-03 -10.4 6.67e-04    -  1.00e+00 1.00e+00h  1
#  585  3.2695827e+01 2.22e-09 1.38e-03 -10.4 2.85e-03    -  1.00e+00 6.25e-02h  5
#  586  3.2695827e+01 7.99e-09 2.08e-03 -10.4 1.79e-03    -  1.00e+00 3.13e-01h  2
#  587  3.2695827e+01 1.04e-08 6.81e-03 -10.4 1.45e-03    -  1.42e-01 1.00e+00h  1
#  588  3.2695826e+01 3.08e-07 8.04e-03 -10.4 9.91e-04    -  1.00e+00 1.00e+00h  1
#  589  3.2695826e+01 1.41e-07 2.64e-03 -10.4 1.94e-03    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  590  3.2695826e+01 1.44e-07 1.42e-03 -10.4 6.21e-03    -  1.00e+00 1.00e-01h  3
#  591  3.2695826e+01 7.56e-08 1.27e-03 -10.4 2.20e-03    -  3.23e-01 5.00e-01h  2
#  592  3.2695826e+01 6.85e-08 1.08e-03 -10.4 2.05e-03    -  9.83e-01 1.25e-01h  4
#  593  3.2695827e+01 8.75e-09 1.22e-03 -10.4 1.09e-03    -  1.00e+00 1.00e+00h  1
#  594  3.2695827e+01 2.40e-08 1.81e-03 -10.4 7.24e-03    -  8.03e-01 7.68e-02h  1
#  595  3.2695827e+01 2.40e-08 1.80e-03 -10.4 1.50e-04    -  2.86e-03 1.95e-03f 10
#  596  3.2695827e+01 2.40e-08 1.59e-02 -10.4 8.58e-04    -  1.00e+00 2.61e-04H  1
#  597  3.2695827e+01 2.38e-08 7.48e-03 -10.4 1.21e-03    -  6.37e-01 4.80e-03f  8
#  598  3.2695826e+01 3.60e-08 1.17e-02 -10.4 3.69e-01    -  1.95e-02 9.52e-04f  4
#  599  3.2695826e+01 2.80e-08 8.20e-03 -10.4 1.66e-03    -  9.70e-01 3.12e-02h  6
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  600  3.2695826e+01 2.63e-08 3.73e-03 -10.4 7.98e-03    -  7.56e-01 6.25e-02h  5
#  601  3.2695827e+01 2.35e-08 2.04e-03 -10.4 7.08e-03    -  1.00e+00 2.50e-01h  3
#  602  3.2695827e+01 3.46e-09 1.61e-03 -10.4 6.02e-04    -  1.00e+00 9.38e-01H  1
#  603  3.2695827e+01 1.86e-08 1.74e-03 -10.4 9.63e-04    -  2.57e-01 5.00e-01f  2
#  604  3.2695827e+01 2.21e-08 2.92e-03 -10.4 3.12e-04    -  1.00e+00 8.86e-01h  1
#  605  3.2695826e+01 1.88e-08 5.19e-03 -10.4 1.04e-03    -  7.28e-04 1.00e+00f  1
#  606  3.2695826e+01 7.64e-09 9.19e-04 -10.4 8.96e-04    -  1.00e+00 1.00e+00h  1
#  607  3.2695827e+01 7.59e-09 1.44e-03 -11.1 8.26e-04    -  9.67e-01 1.00e+00H  1
#  608  3.2695827e+01 3.75e-08 1.08e-03 -11.1 8.08e-04    -  1.00e+00 1.00e+00h  1
#  609  3.2695827e+01 3.32e-08 5.09e-04 -11.1 7.30e-04    -  5.08e-01 2.50e-01h  3
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  610  3.2695827e+01 5.56e-09 4.29e-04 -11.1 9.45e-05    -  1.00e+00 1.00e+00h  1
#  611  3.2695827e+01 6.84e-10 4.80e-04 -11.1 3.99e-04    -  1.00e+00 1.00e+00h  1
#  612  3.2695827e+01 1.87e-09 9.31e-04 -10.9 7.22e-04    -  1.00e+00 5.00e-01h  2
#  613  3.2695827e+01 7.12e-08 6.91e-03 -11.0 3.42e-04    -  1.00e+00 1.00e+00h  1
#  614  3.2695826e+01 1.27e-07 1.93e-03 -11.0 1.24e-03    -  1.00e+00 1.00e+00h  1
#  615  3.2695827e+01 6.78e-08 5.36e-04 -11.0 1.86e-03    -  7.02e-01 5.00e-01h  2
#  616  3.2695827e+01 6.21e-08 1.03e-03 -11.0 2.84e-03    -  1.00e+00 2.50e-01h  3
#  617  3.2695827e+01 5.75e-08 1.48e-03 -11.0 2.02e-03    -  5.40e-01 1.25e-01h  4
#  618  3.2695827e+01 3.52e-08 8.62e-04 -11.0 2.56e-04    -  1.00e+00 1.00e+00h  1
#  619  3.2695827e+01 2.97e-08 1.70e-03 -11.0 1.67e-03    -  1.00e+00 2.41e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  620  3.2695827e+01 2.97e-08 1.70e-03 -11.0 3.29e-04    -  9.56e-04 4.88e-04f 12
#  621  3.2695827e+01 2.97e-08 3.43e-02 -11.0 2.14e-02    -  3.48e-02 7.25e-07H  1
#  622  3.2695827e+01 2.97e-08 2.36e-03 -11.0 3.54e-04    -  9.25e-01 4.88e-04f 12
#  623  3.2695826e+01 7.43e-08 1.32e-02 -11.0 4.12e-03    -  3.60e-06 5.00e-01f  2
#  624  3.2695826e+01 4.16e-08 3.41e-03 -11.0 3.28e-03    -  1.00e+00 1.00e+00h  1
#  625  3.2695826e+01 3.25e-08 1.90e-03 -11.0 8.62e-03    -  1.00e+00 2.50e-01h  3
#  626  3.2695826e+01 4.56e-08 1.64e-03 -11.0 1.88e-02    -  1.00e+00 3.31e-02h  4
#  627  3.2695826e+01 6.24e-08 1.40e-03 -11.0 9.59e-04    -  8.45e-01 2.39e-01h  3
#  628  3.2695826e+01 5.51e-08 7.71e-04 -11.0 1.17e-03    -  1.00e+00 1.18e-01h  3
#  629  3.2695826e+01 5.12e-08 9.95e-04 -11.0 1.49e-02    -  1.00e+00 1.25e-01h  4
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  630  3.2695826e+01 4.32e-08 1.13e-03 -11.0 2.93e-04    -  1.00e+00 2.03e-01h  2
#  631  3.2695827e+01 4.75e-09 4.59e-04 -11.0 7.96e-04    -  9.07e-01 1.00e+00h  1
#  632  3.2695827e+01 1.26e-09 1.31e-03 -11.8 2.64e-05    -  1.00e+00 1.00e+00h  1
#  633  3.2695827e+01 1.55e-09 7.29e-04 -12.0 9.14e-05    -  1.00e+00 1.00e+00h  1
#  634  3.2695827e+01 4.29e-10 3.41e-04 -12.3 1.84e-05    -  1.00e+00 1.00e+00h  1
#  635  3.2695827e+01 4.81e-11 2.15e-04 -12.3 3.39e-05    -  1.00e+00 1.00e+00h  1
#  636  3.2695827e+01 3.03e-12 1.11e-04 -12.3 2.08e-05    -  1.00e+00 1.00e+00H  1
#  637  3.2695827e+01 3.03e-12 8.26e-05 -12.3 1.67e-05    -  1.00e+00 1.00e+00h  1
#  638  3.2695827e+01 1.13e-12 3.74e-05 -12.3 9.36e-06    -  1.00e+00 1.00e+00h  1
#  639  3.2695827e+01 2.78e-13 1.47e-05 -12.3 6.49e-06    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  640  3.2695827e+01 3.88e-17 2.85e-06 -12.3 1.08e-06    -  1.00e+00 1.00e+00h  1
#  641  3.2695827e+01 1.63e-19 1.43e-06 -12.3 1.17e-06    -  1.00e+00 1.00e+00h  1
#  642  3.2695827e+01 7.03e-13 3.04e-06 -12.3 9.22e-06    -  1.00e+00 1.00e+00h  1
#  643  3.2695827e+01 4.34e-19 5.17e-05 -12.3 4.60e-05    -  1.00e+00 1.00e+00H  1
#  644  3.2695827e+01 2.87e-11 8.14e-05 -12.3 6.94e-05    -  1.00e+00 1.00e+00h  1
#  645  3.2695827e+01 3.48e-11 4.48e-05 -12.3 7.03e-04    -  7.86e-01 1.56e-02h  7
#  646  3.2695827e+01 1.16e-11 2.07e-05 -12.3 7.44e-05    -  1.00e+00 1.00e+00h  1
#  647  3.2695827e+01 5.98e-11 2.80e-04 -12.3 3.04e-04    -  7.91e-01 1.25e-01h  4
#  648  3.2695827e+01 1.21e-10 1.20e-04 -12.3 3.19e-05    -  1.00e+00 1.00e+00h  1
#  649  3.2695827e+01 6.14e-17 1.14e-03 -12.3 3.98e-04    -  1.00e+00 1.00e+00H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  650  3.2695827e+01 9.01e-10 1.24e-04 -12.3 3.65e-04    -  1.00e+00 1.00e+00h  1
#  651  3.2695827e+01 1.04e-11 1.21e-04 -12.3 6.43e-05    -  1.00e+00 1.00e+00h  1
#  652  3.2695827e+01 1.83e-12 1.40e-04 -12.3 1.60e-04    -  1.00e+00 1.00e+00H  1
#  653  3.2695827e+01 3.05e-11 6.29e-05 -12.3 9.70e-04    -  1.00e+00 3.12e-02h  6
#  654  3.2695827e+01 1.06e-10 4.82e-05 -12.3 1.51e-04    -  1.00e+00 1.00e+00h  1
#  655  3.2695827e+01 8.16e-10 8.91e-04 -12.3 1.62e-03    -  1.00e+00 8.75e-02h  2
#  656  3.2695827e+01 7.20e-10 1.61e-04 -12.3 7.91e-05    -  5.50e-01 1.00e+00h  1
#  657  3.2695827e+01 1.01e-10 1.43e-04 -12.3 1.82e-05    -  1.00e+00 1.00e+00h  1
#  658  3.2695827e+01 5.06e-12 1.94e-04 -12.3 5.82e-05    -  1.00e+00 1.00e+00H  1
#  659  3.2695827e+01 1.49e-11 4.47e-05 -12.3 9.48e-05    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  660  3.2695827e+01 5.83e-11 6.64e-05 -12.3 5.48e-04    -  1.00e+00 3.12e-02h  6
#  661  3.2695827e+01 4.34e-11 1.32e-04 -12.3 1.93e-04    -  1.00e+00 5.00e-01h  2
#  662  3.2695827e+01 3.55e-13 3.65e-04 -12.3 4.01e-04    -  1.00e+00 1.00e+00H  1
#  663  3.2695827e+01 6.31e-09 8.08e-04 -12.3 2.65e-04    -  1.00e+00 1.00e+00h  1
#  664  3.2695827e+01 7.00e-09 7.58e-04 -12.3 9.15e-03    -  4.93e-02 6.25e-02h  5
#  665  3.2695827e+01 3.75e-09 2.88e-04 -12.3 3.63e-04    -  1.00e+00 5.00e-01h  2
#  666  3.2695827e+01 4.64e-09 5.05e-04 -12.3 4.51e-03    -  1.00e+00 5.72e-02h  5
#  667  3.2695827e+01 4.62e-09 5.09e-04 -12.3 1.19e-03    -  1.00e+00 1.56e-02h  7
#  668  3.2695827e+01 3.49e-09 7.26e-04 -12.3 1.41e-03    -  1.00e+00 2.50e-01h  3
#  669  3.2695827e+01 3.85e-09 4.37e-04 -12.3 1.06e-02    -  1.00e+00 3.12e-02h  6
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  670  3.2695827e+01 2.08e-09 5.57e-04 -12.3 4.42e-04    -  1.00e+00 5.00e-01h  2
#  671  3.2695827e+01 2.10e-09 2.32e-04 -12.3 6.51e-03    -  1.00e+00 5.15e-02h  4
#  672  3.2695827e+01 1.54e-10 3.42e-04 -12.3 1.78e-04    -  1.00e+00 1.00e+00h  1
#  673  3.2695827e+01 6.18e-10 1.55e-04 -12.3 1.26e-03    -  1.00e+00 1.25e-01h  4
#  674  3.2695827e+01 4.35e-16 8.65e-04 -12.3 1.29e-04    -  1.00e+00 1.00e+00H  1
#  675  3.2695827e+01 1.22e-09 1.29e-03 -12.3 1.57e-04    -  1.00e+00 1.00e+00h  1
#  676  3.2695827e+01 1.59e-08 8.01e-04 -12.3 1.49e-03    -  1.00e+00 5.00e-01h  2
#  677  3.2695827e+01 2.79e-08 3.99e-03 -12.3 8.21e-04    -  1.00e+00 1.00e+00h  1
#  678  3.2695827e+01 2.71e-08 3.06e-03 -12.3 8.78e-04    -  1.00e+00 7.24e-02h  1
#  679  3.2695827e+01 2.71e-08 3.05e-03 -12.3 4.08e-04    -  1.18e-03 4.88e-04h 12
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  680  3.2695827e+01 8.28e-08 5.93e-03 -12.3 1.63e-02    -  3.59e-01 6.59e-02h  4
#  681  3.2695827e+01 4.21e-08 2.79e-03 -12.3 1.15e-03    -  1.00e+00 1.00e+00h  1
#  682  3.2695827e+01 2.20e-08 2.08e-03 -12.3 5.42e-04    -  1.00e+00 5.00e-01h  2
#  683  3.2695827e+01 2.58e-07 3.65e-03 -12.3 3.19e-03    -  1.00e+00 1.00e+00h  1
#  684  3.2695826e+01 2.32e-07 9.81e-04 -12.3 1.95e-03    -  1.00e+00 1.00e+00h  1
#  685  3.2695826e+01 1.27e-07 2.25e-03 -12.3 6.90e-04    -  1.26e-01 5.00e-01h  2
#  686  3.2695827e+01 6.07e-09 1.03e-03 -12.3 1.88e-04    -  1.00e+00 1.00e+00h  1
#  687  3.2695827e+01 3.40e-09 1.90e-03 -12.3 7.00e-04    -  1.00e+00 5.08e-01H  1
#  688  3.2695827e+01 2.87e-09 1.73e-03 -12.3 1.97e-04    -  3.65e-04 5.00e-01f  2
#  689  3.2695827e+01 3.06e-09 2.68e-04 -12.3 2.66e-04    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  690  3.2695827e+01 1.71e-10 5.95e-04 -12.3 5.32e-05    -  1.00e+00 1.00e+00h  1
#  691  3.2695827e+01 2.02e-11 1.47e-04 -12.3 4.67e-05    -  1.00e+00 1.00e+00h  1
#  692  3.2695827e+01 1.29e-12 7.35e-05 -12.2 2.71e-05    -  1.00e+00 1.00e+00H  1
#  693  3.2695827e+01 4.34e-19 4.60e-05 -12.2 1.24e-05    -  1.00e+00 1.00e+00H  1
#  694  3.2695827e+01 1.77e-11 1.73e-05 -12.2 1.65e-05    -  1.00e+00 1.00e+00h  1
#  695  3.2695827e+01 2.01e-11 9.01e-05 -12.2 9.01e-05    -  1.00e+00 2.50e-01h  3
#  696  3.2695827e+01 3.46e-19 2.34e-04 -12.2 1.90e-04    -  1.00e+00 1.00e+00H  1
#  697  3.2695827e+01 4.10e-10 2.03e-04 -12.2 1.97e-04    -  1.00e+00 1.00e+00h  1
#  698  3.2695827e+01 4.09e-10 1.59e-04 -12.2 1.15e-03    -  1.00e+00 4.07e-02h  5
#  699  3.2695827e+01 2.76e-11 1.24e-04 -12.2 1.23e-04    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  700  3.2695827e+01 4.34e-19 1.24e-04 -12.2 2.55e-04    -  1.00e+00 1.00e+00H  1
#  701  3.2695827e+01 4.34e-19 1.16e-04 -12.2 1.23e-03    -  8.51e-01 1.22e-04h 14
#  702  3.2695827e+01 4.34e-19 1.24e-04 -12.2 7.24e-04    -  1.00e+00 9.77e-04h 11
#  703  3.2695827e+01 4.34e-19 1.37e-04 -12.2 1.76e-03    -  1.00e+00 1.53e-05h 17
#  704  3.2695827e+01 4.34e-19 2.01e-04 -12.2 2.23e-04    -  1.00e+00 1.00e+00H  1
#  705  3.2695827e+01 9.78e-09 2.12e-03 -12.2 1.53e-02    -  2.69e-02 3.40e-02f  5
#  706  3.2695827e+01 5.46e-09 1.69e-03 -12.2 9.96e-04    -  1.00e+00 1.00e+00h  1
#  707  3.2695827e+01 6.34e-08 3.42e-03 -12.2 1.09e-02    -  1.00e+00 1.01e-01h  1
#  708  3.2695827e+01 9.05e-08 1.74e-03 -12.2 1.01e-03    -  4.81e-03 1.00e+00f  1
#  709  3.2695827e+01 9.05e-08 2.07e-03 -12.2 6.23e-03    -  9.62e-02 1.48e-05H  1
#  711  3.2695827e+01 9.21e-08 5.42e-03 -12.2 3.67e-01    -  6.36e-02 2.10e-03h  7

# %%
# Get the optimized parameters
optimized_ϵ = value(ϵ)
optimized_h_Re = value(h_Re)
optimized_h_Im = value(h_Im)
optimized_γ = value.(γ)
optimized_a = value.(a)

# Substitute the optimized parameters back into H and C
optimized_H = construct_H(optimized_ϵ, optimized_h_Re, optimized_h_Im)
optimized_C = construct_C(optimized_γ, optimized_a)
# Out:
# 3×3 Matrix{ComplexF64}:
#  0.00131002+0.0im                0.0-0.00179616im         0.0+1.7925e-5im
#         0.0+0.00179616im  0.00241541+0.0im               -0.0+2.75528e-5im
#         0.0-1.7925e-5im         -0.0-2.75528e-5im  1.69275e-5+0.0im

# %%
optimized_H
# Out:
# 2×2 Matrix{ComplexF64}:
#  -2.17442e-13+0.0im           8.07444e-5-0.000239661im
#    8.07444e-5+0.000239661im  2.17442e-13+0.0im

# %%
function get_lindblad_operators(C::Matrix{ComplexF64}, basis_ops::Vector{Matrix{ComplexF64}})
    # Check that C is a square matrix and basis_ops has the same dimension
    n = size(C, 1)
    if size(C, 2) != n || length(basis_ops) != n
        throw(ArgumentError("Dimensions of C and basis_ops do not match"))
    end

    # Perform eigenvalue decomposition of C
    eigvals, eigvecs = eigen(C)

    # Construct the Lindblad operators
    lindblad_ops = []
    for i in 1:n
        if eigvals[i] > 1e-10  # Filter out negligible eigenvalues to ensure numerical stability
            lindblad_op = zeros(ComplexF64, size(basis_ops[1]))
            for j in 1:n
                lindblad_op .+= sqrt(eigvals[i]) * eigvecs[j, i] * basis_ops[j]
            end
            push!(lindblad_ops, lindblad_op)
        end
    end

    return lindblad_ops
end
# Out:
# get_lindblad_operators (generic function with 1 method)

# %%
Hˢⁱᵈ = convert.(ComplexF64,optimized_H)
Cˢⁱᵈ = convert.(ComplexF64,optimized_C)

effective_Lindblad = get_lindblad_operators(Cˢⁱᵈ, fᴼᴺᴮ)
# Out:
# 2-element Vector{Any}:
#  ComplexF64[0.01837934870398452 + 0.0im -0.0036634172925965633 + 0.008969337099264502im; -0.009549260695663276 - 0.005338428187444248im -0.01837934870398452 + 0.0im]
#  ComplexF64[0.012326227270335577 + 0.0im -0.007526236857586301 - 0.0017856474201574622im; 0.03376957992542453 + 0.02663278473166229im -0.012326227270335577 + 0.0im]

# %%
ρᵍ₀ = [ 1 0.
        0 0 ]    # state to measure initial distance from

dodeca_10_states = ["D"*string(n) for n=1:10];

basis_states = ["B"*string(n) for n=1:4];

train_states = basis_states 
test_states = dodeca_10_states;

# %%
using QuantumOptics
basis = NLevelBasis(2)

include("../LiPoSID.jl")

using Statistics
# Out:
# WARNING: replacing module LiPoSID.

# %%
FminStates = []
FmedianStates = []
FmeanStates = []

for state in test_states # loop over initial states
    
    print(state*" ")

    start_time = time()

    tₛ, ρₛ = read_timeevolution(file_name, state, γᵢ)
    ρₛ = convert(Vector{Matrix{ComplexF64}}, ρₛ)
    #bᵗˢᵗ = LiPoSID.bloch(ρₛ)
    ρᵗˢᵗ = [DenseOperator(basis,Hermitian(ρₜ)) for ρₜ in ρₛ]
    tᵗˢᵗ = convert.(Float64, tₛ)

    #Simulated LME 
    #tˢⁱᵐ, ρˢⁱᵐ  = timeevolution.master(tᵗˢᵗ, ρᵗˢᵗ[1], DenseOperator(basis, Hˢⁱᵈ), [Jˢⁱᵐ])
    #bˢⁱᵐ = LiPoSID.bloch([ρᵢ.data for ρᵢ in ρˢⁱᵐ])

    ρₒ = DenseOperator(basis,ρₛ[1])
    dt = tᵗˢᵗ[2] - tᵗˢᵗ[1]
    tᵉⁿᵈ = tᵗˢᵗ[end]

    #print("effective_Lindblad_ops for Kossakowski")

    
    effective_Lindblad_ops = [DenseOperator(basis,j) for j in effective_Lindblad]

    #print("Simulating Kossakowski")

    tout, ρ_t_kossak = timeevolution.master(tᵗˢᵗ, ρₒ, DenseOperator(basis, Hˢⁱᵈ), effective_Lindblad_ops)
    ρˢⁱᵈ  = [ρₜ.data for ρₜ in ρ_t_kossak]

    #print("Calculating Fidelity")

    #F = LiPoSID.fidelity_series(basis, [ρₜ.data for ρₜ in ρˢⁱᵐ], ρˢⁱᵈ)
    F = LiPoSID.fidelity_series(basis, ρₛ, ρˢⁱᵈ)
    
    FminState = minimum(F)
    FmedianState = median(F)
    FmeanState = mean(F)
    
    push!(FminStates, FminState)
    push!(FmedianStates, FmedianState)
    push!(FmeanStates, FmeanState)

end

# Calculate the mean
F_mean_value = mean(FmeanStates)

# Calculate the median
F_median_value = median(FmedianStates)

# Calculate the min
F_min_value = minimum(FminStates)

println()
println("Mimimal fidelity for "*γᵢ*": ", F_min_value)
println("Median fidelity for "*γᵢ*": ", F_median_value)
# Out:
# D1 D2 D3 D4 D5 D6 D7 D8 D9 D10
# Mimimal fidelity for 0.25133: 0.13288614450649827
# Median fidelity for 0.25133: 0.7668635472557752

# %% [markdown]
# D1 D2 D3 D4 D5 D6 D7 D8 D9 D10
#
# Mimimal fidelity for 0.25133: 0.9995188642141652
#
# Median fidelity for 0.25133: 0.9999049135214064

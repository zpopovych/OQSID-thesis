# %%
import h5py

# %%
tests_dir = "../TESTS/"
test_file = "POP_LME_6-H_random_trn4_tst20_2024-Jan-16_at_18-48.h5" #fixed Hamiltonian

# %%
def read_gammas(filename, tests_dir):
    
    with h5py.File(tests_dir+filename, "r") as f:
    
        gammas = ['0.079477', '0.25133', '0.79477', '2.5133', '7.9477', '25.133', '79.477', '251.33']
        
        relaxation = []
        de_phasing = []
        exitation = []
        de_polarisation = []
        #omega = []

               
        for gamma in gammas:

            relaxation.append(f["gamma_"+gamma]["gamma_relaxation"][()])
            de_phasing.append(f["gamma_"+gamma]["gamma_de_phasing"][()])
            exitation.append(f["gamma_"+gamma]["gamma_exitation"][()])
            de_polarisation.append(f["gamma_"+gamma]["gamma_de_polarisation"][()])
            #omega.append(f["gamma_"+gamma]["omega"][()])
            
            print(gamma)

    return gammas, relaxation, exitation, de_phasing, de_polarisation

# %%
gammas, relaxation, exitation, de_phasing, de_polarisation = read_gammas(test_file, tests_dir)
# Out:
# 0.079477
# 0.25133
# 0.79477
# 2.5133
# 7.9477
# 25.133
# 79.477
# 251.33

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(exitation)

# %%
plt.plot(de_phasing)

# %%
plt.plot(de_polarisation)

# %%
plt.plot(relaxation)

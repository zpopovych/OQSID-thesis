# %% [markdown]
# ### Full POP model works

# %%
include("LiPoSID.jl")
using QuantumOptics
basis = NLevelBasis(2)
using DynamicPolynomials
using LinearAlgebra
using Dates
using HDF5

# %% [markdown]
# Consider simple Lindblad master equation with just one dissipator:
#
# $m
#      \frac{d\rho}{dt} = - \frac{i}{\hbar}[H, \rho]+\gamma\left[A \rho A^\dagger - \frac{1}{2}\left\{ A^\dagger A, \rho \right\} \right]
# $,
#
# where Hamiltonian is hermitian with one of the diagonal elemnets set to zero
#
#
# $
#     H = \begin{pmatrix} e_1 & h_1 - i h_2 \\ h_1 + i h_2 & 0
#    \end{pmatrix}
# $
#
#  we can possibly look for jump operator of the form:
#
# $
# A = \begin{pmatrix} a_{11} + i b_{11} & a_{12} \\ a_{21} + i b_{21} & -a_{11} - i b_{11}
#    \end{pmatrix}
# $
#
# or
#
# $
# A = \begin{pmatrix} a_{11} & a_{12} + i b_{12}  \\ a_{21} + i b_{21} & -a_{11}
#    \end{pmatrix}
# $
#
# or assuming zero temperature
#
# $
# A = \begin{pmatrix} a_{11} + i b_{11} & a_{12}   \\ 0 & -a_{11} - i b_{11}
#    \end{pmatrix}
# $

# %%
@polyvar e[1]
@polyvar h[1:2]


Hˢʸᵐᵇ = [ e[1]               h[1] - im*h[2]
          h[1] + im*h[2]     0.             ]
# Out:
# 2×2 Matrix{Polynomial{true, ComplexF64}}:
#  e₁                  h₁ + (0.0-1.0im)h₂
#  h₁ + (0.0+1.0im)h₂  0.0+0.0im

# %%
method = "zero_down_fix-Phi-up_"

@polyvar a[1:4]
@polyvar b[1:4]


#"just-zero-down_ "

#Aˢʸᵐᵇ = [ a[1]+im*b[1]      a[2] + im*b[2] 
#          0                -a[1]-im*b[1]  ]


#"fix-Phi-up_: "

#Aˢʸᵐᵇ = [ a[1]+im*b[1]      a[2]
#          a[3] + im*b[3]   -a[1]-im*b[1] ]


#"zero Temperature and fix-Phi-up_: " zero_down_fix-Phi-up_

Aˢʸᵐᵇ = [ a[1]+im*b[1]      a[2]
          0                -a[1]-im*b[1] ]

#"zero Temperature and fix-Phi-diag_: "

#Aˢʸᵐᵇ = [ a[1]     a[2]+im*b[2] 
#          0        -a[1]        ]
# Out:
# 2×2 Matrix{Polynomial{true, Complex{Int64}}}:
#  a₁ + (0+1im)b₁  a₂
#  0+0im           -a₁ + (0-1im)b₁

# %%
pwd()
# Out:
# "/home/zah/POP23"

# %%
parentdir = pwd()
data_dir = parentdir*"/DATA/"
println(data_dir)

models_dir = parentdir*"/MODELS/"
tests_dir = parentdir*"/TESTS/"

dodeca_files = ["State_D"*string(n) for n=1:20];

basis_files = ["State_B"*string(n) for n=1:4];
# Out:
# /home/zah/POP23/DATA/

# %%
all_files = vcat(dodeca_files, basis_files)
train_files = all_files
test_files = all_files;

# %% [markdown]
# ### Train models loop

# %%
ρᵍ, tᵍ = LiPoSID.get_rho_series(data_dir*"State_B1_2CUT_data.h5", "0.079477")
t = convert(Vector{Float64}, tᵍ)
ρ = convert(Vector{Matrix{ComplexF64}}, ρᵍ)
LiPoSID.simpson_obj(ρ, t,  Hˢʸᵐᵇ, [Aˢʸᵐᵇ])

γᶠ = parse(Float64, "0.079477")
# Out:
# 0.079477

# %%
date_and_time_string =  string(Dates.format(now(), "yyyy-u-dd_at_HH-MM"))
models_file = "POP_fit_trn24_"*method*date_and_time_string * ".h5"
tests_data_file_name = "POP_fit_trn24_tst24_"*method*date_and_time_string * ".h5"

println(models_file)

γ = [ "0.079477",  "0.25133", "0.79477", "2.5133", "7.9477", "25.133", "79.477", "251.33"]

for γᵢ in γ
    
    println("gamma = ", γᵢ)
    
    Hᴸᴹᴱ = [ 25.126        0
             0             0    ]
    γᶠ = parse(Float64, γᵢ)

    Aᴸᴹᴱ = [ 0    √(γᶠ)
             0     0. + 0im  ]

    objₑₓ = 0
    
    objₗₘₑ = 0
    
    for df_trn in train_files # loop over initial states

        ρᵗʳⁿ, tᵗʳⁿ = LiPoSID.get_rho_series(data_dir*df_trn*"_2CUT_data.h5", γᵢ)
        ρᵗʳⁿ = convert(Vector{Matrix{ComplexF64}}, ρᵗʳⁿ)
        ρᵗʳⁿₒₚₛ = [DenseOperator(basis,Hermitian(ρₜ)) for ρₜ in ρᵗʳⁿ]
        tᵗʳⁿ = convert(Vector{Float64}, tᵗʳⁿ)
    
        objₑₓ += LiPoSID.simpson_obj(ρᵗʳⁿ, tᵗʳⁿ,  Hˢʸᵐᵇ, [Aˢʸᵐᵇ])
            
        
        ρˡᵐᵉ = LiPoSID.Lindblad_time_evolution(basis, ρᵗʳⁿ[1], tᵗʳⁿ, Hᴸᴹᴱ, [Aᴸᴹᴱ])
        objₗₘₑ += LiPoSID.simpson_obj(ρˡᵐᵉ, tᵗʳⁿ,  Hˢʸᵐᵇ, [Aˢʸᵐᵇ])
        
    end # of files (initial states) loop
       
    
    println(" POP on ansatz LME simulation")
    
    solˢⁱᵈₗₘₑ, best_methodₐₙ = LiPoSID.sos_min_newton(objₗₘₑ) 
    
    println("Best metod for POP on LME: ", best_methodₐₙ)
    
    solₗₘₑ = [e[1], h[1], h[2], a[1], a[2], a[3], b[1], b[3]] => [25.126, 0, 0, 0,  √(γᶠ), 0, 0, 0]
    
    obj_val_lme = convert(Float64, subs(objₗₘₑ, solₗₘₑ))
    
    obj_val_sid_on_lme = convert(Float64, subs(objₗₘₑ, solˢⁱᵈₗₘₑ))
    
    if obj_val_sid_on_lme < obj_val_lme
        println(" simulated LME overfitting")
    end
    
    Hˢⁱᵈₗₘₑ = subs(Hˢʸᵐᵇ, solˢⁱᵈₗₘₑ)
    Aˢⁱᵈₗₘₑ = subs(Aˢʸᵐᵇ, solˢⁱᵈₗₘₑ)
      
    println(" POP on ansatz EXACT Kurt data ")
    
    solₑₓ, best_methodₑₓ = LiPoSID.sos_min_newton(objₑₓ) 
    
    println("Best metod for POP on EXACT: ", best_methodₑₓ)
    
    obj_val_lme_on_exact = convert(Float64, subs(objₑₓ, solₗₘₑ))
    
    obj_val_sid_on_exact = convert(Float64, subs(objₑₓ, solₑₓ))
    
    if obj_val_sid_on_exact < obj_val_lme_on_exact
        println(" Exact data overfitting")
    end

    Hˢⁱᵈₑₓ = subs(Hˢʸᵐᵇ, solₑₓ)
    Aˢⁱᵈₑₓ = subs(Aˢʸᵐᵇ, solₑₓ)
    
    H = DenseOperator(basis, Hˢⁱᵈₑₓ)
    A = DenseOperator(basis, Aˢⁱᵈₑₓ)

    
    h5open(models_dir*models_file,"cw") do fid  # read-write, create file if not existing, preserve existing contents

        γ_group = create_group(fid, "gamma_"*γᵢ)
        
        
        γ_group["obj_val_lme"] = obj_val_lme
        γ_group["obj_val_sid_on_lme"] = obj_val_sid_on_lme
        
        γ_group["obj_val_lme_on_exact"] = obj_val_lme_on_exact
        γ_group["obj_val_sid_on_exact"] = obj_val_sid_on_exact

        γ_group["H_sid_exact"] = convert.(ComplexF64, Hˢⁱᵈₑₓ)
        γ_group["A_sid_exact"] = convert.(ComplexF64, Aˢⁱᵈₑₓ)
        
        γ_group["H_lme"] = convert.(ComplexF64, Hᴸᴹᴱ)
        γ_group["A_lme"] = convert.(ComplexF64, Aᴸᴹᴱ)
        
        γ_group["H_sid_lme"] = convert.(ComplexF64, Hˢⁱᵈₗₘₑ)
        γ_group["A_sid_lme"] = convert.(ComplexF64, Aˢⁱᵈₗₘₑ)

        
    end # of HDF5 writing
    
    
    h5open(tests_dir*tests_data_file_name,"cw") do fid
        γ_group = create_group(fid, "gamma_"*γᵢ)
    end 
    
    for df in test_files # loop over initial states
        
        print(df*" ")

        start_time = time()

        ρₛ, tₛ = LiPoSID.get_rho_series(data_dir*df*"_2CUT_data.h5", γᵢ)
        ρₛ = convert(Vector{Matrix{ComplexF64}}, ρₛ)

        ρᵗˢᵗ = [DenseOperator(basis,Hermitian(ρₜ)) for ρₜ in ρₛ]

        tᵗˢᵗ = convert(Vector{Float64}, tₛ)

        tᴸᴹᴱ, ρᴸᴹᴱ  = timeevolution.master(tᵗˢᵗ, ρᵗˢᵗ[1], DenseOperator(basis,Hᴸᴹᴱ), [DenseOperator(basis,Aᴸᴹᴱ)])
        tˢⁱᵈₗₘ, ρˢⁱᵈₗₘₑ  = timeevolution.master(tᵗˢᵗ, ρᵗˢᵗ[1], DenseOperator(basis,Hˢⁱᵈₗₘₑ), [DenseOperator(basis,Aˢⁱᵈₗₘₑ)])
        tˢⁱᵈₑₓ, ρˢⁱᵈₑₓ  = timeevolution.master(tᵗˢᵗ, ρᵗˢᵗ[1], DenseOperator(basis,Hˢⁱᵈₑₓ), [DenseOperator(basis,Aˢⁱᵈₑₓ)])   
        

        Fᴸᴹᴱₑₓ = [abs(fidelity(ρ₁, ρ₂)) for (ρ₁, ρ₂) in zip(ρᵗˢᵗ, ρᴸᴹᴱ)]
        Fˢⁱᵈᴸᴹᴱₗₘₑ = [abs(fidelity(ρ₁, ρ₂)) for (ρ₁, ρ₂) in zip(ρˢⁱᵈₗₘₑ, ρᴸᴹᴱ)]
        Fˢⁱᵈᵉˣₑₓ = [abs(fidelity(ρ₁, ρ₂)) for (ρ₁, ρ₂) in zip(ρᵗˢᵗ, ρˢⁱᵈₑₓ)]
                    

        h5open(tests_dir*tests_data_file_name,"cw") do fid
            γ_group = open_group(fid, "gamma_"*γᵢ) # open coupling group

            init_state_group = create_group(γ_group, df) # create initial state group
            init_state_group["F_lme_exact"] = convert.(Float64, Fᴸᴹᴱₑₓ)
            init_state_group["F_sidlme_lme"] = convert.(Float64, Fˢⁱᵈᴸᴹᴱₗₘₑ)
            init_state_group["F_sidexact_exact"] = convert.(Float64, Fˢⁱᵈᵉˣₑₓ)
            
        end
                    
        print(minimum(Fᴸᴹᴱₑₓ), minimum(Fˢⁱᵈᴸᴹᴱₗₘₑ), minimum(Fˢⁱᵈᵉˣₑₓ))
        println(" ")
    
    end
                
    println()
    println()
                            

end
# Out:
# POP_fit_trn24_zero_down_fix-Phi-up_2023-Aug-02_at_17-45.h5
# gamma = 0.079477
#  POP on ansatz LME simulation
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum =
#  POP on ansatz LME simulation
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 5.152245312191108e-8
# Global optimality certified with relative optimality gap 0.000005%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = -9.990380628599746e-9
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [6.41070529994181e-13, 6.412093078722592e-13]
# Best metod for POP on LME: tssos
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.04889347275847347
# Global optimality certified with relative optimality gap 0.000002%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.048893445812363885
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.04889345630804504, 0.04889345630804498]
# Best metod for POP on EXACT: scaled_tssos
#  Exact data overfitting
# State_D1 0.91124510601931090.99999999999999760.9850138600052065
# State_D2 0.9119663713130960.99999999999999830.9849004729531692
# State_D3 0.91487693128799170.99999999999999770.9724845270225273
# State_D4 0.93620316440051480.99999999999999830.9798505330758411
# State_D5 0.91252155500886210.99999999999999780.991388193287414
# State_D6 0.91252155500415010.99999999999999810.9841841703099086
# State_D7 0.91883893874244750.99999999999999740.9690382572758106
# State_D8 0.91313353040438890.99999999999999790.9832274723966831
# State_D9 0.91105351726581320.99999999999999830.9869921351774791
# State_D10 0.91609992316778430.99999999999999830.9782892634968556
# State_D11 0.91487693128799170.99999999999999790.9869003750562277
# State_D12 0.93620316440096230.99999999999999820.9856878998355021
# State_D13 0.91124993894953730.99999999999999780.9836965624474499
# State_D14 0.9119663713146580.99999999999999780.9929943269977848
# State_D15 0.93089575256946620.9999999999999980.9908129304992115
# State_D16 0.93089575257037750.9999999999999980.9885276229716975
# State_D17 0.91883893874296220.99999999999999730.9810999320856323
# State_D18 0.91313353040335010.99999999999999820.9761839100618638
# State_D19 0.91609992316931390.99999999999999860.9840437166773812
# State_D20 0.91105351726791620.99999999999999830.9897836997229368
# State_B1 0.91100954818861280.99999999999999970.9887821750828873
# State_B2 0.93747014433823160.99999999999999930.9826289768102274
# State_B3 0.91282885455376560.99999999999999780.9705278401347786
# State_B4 0.91342780427183190.99999999999999790.9901625625684949
#
#
# gamma = 79.477
#  POP on ansatz LME simulation
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 6.740312719917969e-9
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = -9.590215255756673e-9
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [5.220324172938717e-12, 5.220268661787486e-12]
# Best metod for POP on LME: scaled_tssos
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.011290269442931836
# Global optimality certified with relative optimality gap 0.004496%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.011290246021227433
# Global optimality certified with relative optimality gap 0.004495%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.011335224951281182, 0.011335192518424618]
# Best metod for POP on EXACT: scaled_tssos
#  Exact data overfitting
# State_D1 0.78829457485258740.99999999999999810.9990534900781713
# State_D2 0.7883295725234580.99999999999999810.9995097132877824
# State_D3 0.7873772496849930.99999999999999810.9991722611405718
# State_D4 0.78746555872586730.99999999999999770.9994899042753652
# State_D5 0.78841323589288610.99999999999999780.9995627736533915
# State_D6 0.78841323589162440.99999999999999740.9995558135407256
# State_D7 0.78800765942735440.9999999999999980.9977004667011923
# State_D8 0.78804633541218350.99999999999999820.9990575225627403
# State_D9 0.78805632530926660.99999999999999810.9992780233653262
# State_D10 0.78697585469908350.99999999999999820.9994413572374475
# State_D11 0.78737724968690370.9999999999999980.999160899813606
# State_D12 0.78746555872524150.99999999999999790.9994853482302877
# State_D13 0.78829457485575430.99999999999999810.9990119291760406
# State_D14 0.78832957252473580.99999999999999810.9994546883696587
# State_D15 0.78771534874778090.9999999999999980.9997142265990424
# State_D16 0.78771534874461310.9999999999999980.9997104092552572
# State_D17 0.78800765942480820.9999999999999980.99767547474502
# State_D18 0.78804633541219770.99999999999999740.9990830537683015
# State_D19 0.78697585470035480.99999999999999780.9994456707747841
# State_D20 0.78805632530801550.9999999999999980.9992286244180337
# State_B1 0.78801874858648550.99999999999999960.9992635021699612
# State_B2 0.7869365986965220.99999999999999960.9994473410894757
# State_B3 0.78799398575990760.99999999999999840.9983185606496849
# State_B4 0.78812617635170670.9999999999999980.9996999696290262
#
#
# gamma = 251.33
#  POP on ansatz LME simulation
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 7.376304759823973e-8
# Global optimality certified with relative optimality gap 0.000007%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = -1.3734335795701274e-9
# Global optimality certified with relative optimality gap 0.000000%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [7.949640945525971e-12, 7.949640945525971e-12]
# Best metod for POP on LME: tssos
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.08324658566701709
# Global optimality certified with relative optimality gap 0.000238%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.08324656353508714
# Global optimality certified with relative optimality gap 0.000236%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.08324896264845139, 0.08324892333247463]
# Best metod for POP on EXACT: scaled_tssos
#  Exact data overfitting
# State_D1 0.73688039058929820.99999999999999630.996559391661545
# State_D2 0.73688971180127630.99999999999999640.9950629786631958
# State_D3 0.73392638838295920.99999999999999630.9958279662907512
# State_D4 0.73394585204433690.99999999999999680.9943874207656798
# State_D5 0.73822607234890770.99999999999999610.9935241309921079
# State_D6 0.73822607234891480.99999999999999620.9933993647086585
# State_D7 0.73977887159394380.99999999999999660.9996931626126714
# State_D8 0.73981430787393880.99999999999999620.9983101591334245
# State_D9 0.73435691393744280.99999999999999580.9947835414635918
# State_D10 0.72932820338321790.99999999999999610.9936350687444693
# State_D11 0.73392638838381130.99999999999999640.9957457558767858
# State_D12 0.73394585204461990.99999999999999620.9944703927225846
# State_D13 0.73688039059007470.99999999999999620.9965063161021606
# State_D14 0.73688971180127630.99999999999999580.9951613509772828
# State_D15 0.73672455527686750.99999999999999620.9929521245629488
# State_D16 0.73672455527884740.99999999999999620.9930836639466598
# State_D17 0.73977887157479960.99999999999999660.9995892832674566
# State_D18 0.73981430787000060.99999999999999680.9982429435596707
# State_D19 0.72932820338394840.99999999999999690.993630943787587
# State_D20 0.7343569139367490.99999999999999610.9948010036275067
# State_B1 0.73377416181133570.99999999999999670.9940288220890623
# State_B2 0.72847859237988370.99999999999999760.992785804257718
# State_B3 0.73983488473540450.99999999999999630.9998056703440994
# State_B4 0.73979594803965290.99999999999999630.9932814580223442

# %%
tests_data_file_name
# Out:
# "POP_fit_trn24_tst24_zero_down_fix-Phi-up_2023-Aug-02_at_17-45.h5"

# %% [markdown]
# ### Full POP model works

# %%
include("LiPoSID.jl")
using QuantumOptics
basis = NLevelBasis(2)
using DynamicPolynomials
using LinearAlgebra
using Dates
using HDF5

# %% [markdown]
# Consider simple Lindblad master equation with just one dissipator:
#
# $m
#      \frac{d\rho}{dt} = - \frac{i}{\hbar}[H, \rho]+\gamma\left[A \rho A^\dagger - \frac{1}{2}\left\{ A^\dagger A, \rho \right\} \right]
# $,
#
# where Hamiltonian is hermitian with one of the diagonal elemnets set to zero
#
#
# $
#     H = \begin{pmatrix} e_1 & h_1 - i h_2 \\ h_1 + i h_2 & 0
#    \end{pmatrix}
# $
#
#  we can possibly look for jump operator of the form:
#
# $
# A = \begin{pmatrix} a_{11} + i b_{11} & a_{12} \\ a_{21} + i b_{21} & -a_{11} - i b_{11}
#    \end{pmatrix}
# $
#
# or
#
# $
# A = \begin{pmatrix} a_{11} & a_{12} + i b_{12}  \\ a_{21} + i b_{21} & -a_{11}
#    \end{pmatrix}
# $
#
# or assuming zero temperature
#
# $
# A = \begin{pmatrix} a_{11} + i b_{11} & a_{12}   \\ 0 & -a_{11} - i b_{11}
#    \end{pmatrix}
# $

# %%
@polyvar e[1]
@polyvar h[1:2]


Hˢʸᵐᵇ = [ e[1]               h[1] - im*h[2]
          h[1] + im*h[2]     0.             ]
# Out:
# 2×2 Matrix{Polynomial{true, ComplexF64}}:
#  e₁                  h₁ + (0.0-1.0im)h₂
#  h₁ + (0.0+1.0im)h₂  0.0+0.0im

# %%
method = "fix-Phi-up_"

@polyvar a[1:4]
@polyvar b[1:4]


#"just-zero-down_ "

#Aˢʸᵐᵇ = [ a[1]+im*b[1]      a[2] + im*b[2] 
#          0                -a[1]-im*b[1]  ]


#"fix-Phi-up_: "

Aˢʸᵐᵇ = [ a[1]+im*b[1]      a[2]
          a[3] + im*b[3]   -a[1]-im*b[1] ]


#"zero Temperature and fix-Phi-up_: " zero_down_fix-Phi-up_

#Aˢʸᵐᵇ = [ a[1]+im*b[1]      a[2]
#          0                -a[1]-im*b[1] ]

#"zero Temperature and fix-Phi-diag_: "

#Aˢʸᵐᵇ = [ a[1]     a[2]+im*b[2] 
#          0        -a[1]        ]
# Out:
# 2×2 Matrix{Polynomial{true, Complex{Int64}}}:
#  a₁ + (0+1im)b₁  a₂
#  a₃ + (0+1im)b₃  -a₁ + (0-1im)b₁

# %%
pwd()
# Out:
# "/home/zah/POP23"

# %%
parentdir = pwd()
data_dir = parentdir*"/DATA/"
println(data_dir)

models_dir = parentdir*"/MODELS/"
tests_dir = parentdir*"/TESTS/"

dodeca_files = ["State_D"*string(n) for n=1:20];

basis_files = ["State_B"*string(n) for n=1:4];
# Out:
# /home/zah/POP23/DATA/

# %%
all_files = vcat(dodeca_files, basis_files)
train_files = basis_files 
test_files = dodeca_files;

# %% [markdown]
# ### Train models loop

# %%
import Base.real
function remove_micro_coefs(p::AbstractPolynomial, cutoff)
    sum(
        
        [abs(coef) > cutoff ? real(coef) * mon : 0 for (coef, mon) in zip(coefficients(p), monomials(p))]
        )
end
# Out:
# remove_micro_coefs (generic function with 1 method)

# %%
date_and_time_string =  string(Dates.format(now(), "yyyy-u-dd_at_HH-MM"))
models_file = "POP_Rm1238_trn4_tst20_"*method*date_and_time_string * ".h5"
tests_data_file_name = "POP_Rm1238_trn4_tst20_"*method*date_and_time_string * ".h5"

println(models_file)

γ = [ "0.079477",  "0.25133", "0.79477", "2.5133", "7.9477", "25.133", "79.477", "251.33"]

for γᵢ in γ
    
    println("---------------")
    println("gamma = ", γᵢ)
    
    Hᴸᴹᴱ = [ 25.126        0
             0             0    ]
    γᶠ = parse(Float64, γᵢ)

    Aᴸᴹᴱ = [ 0    √(γᶠ)
             0     0. + 0im  ]

    objₑₓ = 0
    
    objₗₘₑ = 0
    
    for df_trn in train_files # loop over initial states

        ρᵗʳⁿ, tᵗʳⁿ = LiPoSID.get_rho_series(data_dir*df_trn*"_2CUT_data.h5", γᵢ)
        
        if length(tᵗʳⁿ) > 1200 end_train = 1200 else end_train = length(tᵗʳⁿ) end
            
        ρᵗʳⁿ = convert(Vector{Matrix{ComplexF64}}, ρᵗʳⁿ[1:end_train])
        
        ρᵗʳⁿₒₚₛ = [DenseOperator(basis,Hermitian(ρₜ)) for ρₜ in ρᵗʳⁿ]
        tᵗʳⁿ = convert(Vector{Float64}, tᵗʳⁿ[1:end_train])
    
        objₑₓ += LiPoSID.simpson_obj(ρᵗʳⁿ, tᵗʳⁿ,  Hˢʸᵐᵇ, [Aˢʸᵐᵇ])
         
        
        ρˡᵐᵉ = LiPoSID.Lindblad_time_evolution(basis, ρᵗʳⁿ[1], tᵗʳⁿ, Hᴸᴹᴱ, [Aᴸᴹᴱ])
        objₗₘₑ += LiPoSID.simpson_obj(ρˡᵐᵉ, tᵗʳⁿ,  Hˢʸᵐᵇ, [Aˢʸᵐᵇ])
            
        
    end # of files (initial states) loop
            
    
    if γᵢ == γ[1] #"0.079477" 
        objₑₓrm = remove_micro_coefs(objₑₓ, 5e-3)
        objₗₘₑrm = remove_micro_coefs(objₗₘₑ, 5e-5)
    elseif  γᵢ == γ[2] #"0.25133" 
        objₑₓrm = remove_micro_coefs(objₑₓ, 1e-3)
        objₗₘₑrm = remove_micro_coefs(objₗₘₑ, 1e-6)           
    elseif  γᵢ == γ[3] #"0.79477"
        objₑₓrm = remove_micro_coefs(objₑₓ, 5e-4) # min 1.6170299538613683e-05
        objₗₘₑrm = remove_micro_coefs(objₗₘₑ, 1e-6)# min 9.266037758749431e-07
    elseif  γᵢ == γ[8] #"251.33
        objₑₓrm = remove_micro_coefs(objₑₓ, 1e-6) # min 1.3748393001901435e-08
        objₗₘₑrm = remove_micro_coefs(objₗₘₑ, 5e-6) # min 3.4346580884012564e-07
    else 
        objₑₓrm = objₑₓ
        objₗₘₑrm = objₗₘₑ
    end
            
    coef_minₑₓ = minimum(abs.(coefficients(objₑₓ)))
    coef_maxₑₓ = maximum(abs.(coefficients(objₑₓ)))
            
    cutoffₑₓ = log10(coef_maxₑₓ)-4

    coefs_gapₑₓ = coef_maxₑₓ/coef_minₑₓ 
            
    coef_minₗₘₑ = minimum(abs.(coefficients(objₗₘₑ)))
    coef_maxₗₘₑ = maximum(abs.(coefficients(objₗₘₑ)))
            
    cutoffₗₘₑ = log10(coef_maxₗₘₑ)-4

    coefs_gapₗₘₑ= coef_maxₗₘₑ/coef_minₗₘₑ 
       
    println("-------------------------------------------")
    println(" POP on ansatz LME simulation")
    println(cutoffₗₘₑ)
            
    #objₗₘₑrm = coefs_gapₗₘₑ > 1e6 ? remove_micro_coefs(objₗₘₑ, cutoffₗₘₑ) : objₗₘₑ
    
    solˢⁱᵈₗₘₑ, best_methodˢⁱᵈₗₘₑ = LiPoSID.sos_min_newton(objₗₘₑrm)

    
    println("Best metod for POP on LME: ", best_methodˢⁱᵈₗₘₑ)
    println("-------------------------------------------")
    
    solₗₘₑ = [e[1], h[1], h[2], a[1], a[2], a[3], b[1], b[3]] => [25.126, 0, 0, 0,  √(γᶠ), 0, 0, 0]
    
    obj_val_lme = convert(Float64, subs(objₗₘₑ, solₗₘₑ))
    
    obj_val_sid_on_lme = convert(Float64, subs(objₗₘₑ, solˢⁱᵈₗₘₑ))
    
    if obj_val_sid_on_lme < obj_val_lme
        println(" simulated LME overfitting")
    end
    
    Hˢⁱᵈₗₘₑ = subs(Hˢʸᵐᵇ, solˢⁱᵈₗₘₑ)
    Aˢⁱᵈₗₘₑ = subs(Aˢʸᵐᵇ, solˢⁱᵈₗₘₑ)
      
    println(" POP on ansatz EXACT Kurt data ")
    println(cutoffₑₓ)
                
    #objₑₓrm = coefs_gapₑₓ > 1e6 ? remove_micro_coefs(objₑₓ, cutoffₑₓ) : objₑₓ
    #objₑₓrm = coefs_gapₑₓ > 1e6 ? remove_micro_coefs(objₑₓ, -3) : objₑₓ
    
    solₑₓ, best_methodₑₓ = LiPoSID.sos_min_newton(objₑₓrm) 
    
    println("Best metod for POP on EXACT: ", best_methodₑₓ)
    
    obj_val_lme_on_exact = convert(Float64, subs(objₑₓ, solₗₘₑ))
    
    obj_val_sid_on_exact = convert(Float64, subs(objₑₓ, solₑₓ))
    
    if obj_val_sid_on_exact < obj_val_lme_on_exact
        println(" Exact data overfitting")
    end

    Hˢⁱᵈₑₓ = subs(Hˢʸᵐᵇ, solₑₓ)
    Aˢⁱᵈₑₓ = subs(Aˢʸᵐᵇ, solₑₓ)
    
    H = DenseOperator(basis, Hˢⁱᵈₑₓ)
    A = DenseOperator(basis, Aˢⁱᵈₑₓ)

    
    h5open(models_dir*models_file,"cw") do fid  # read-write, create file if not existing, preserve existing contents

        γ_group = create_group(fid, "gamma_"*γᵢ)
        
        
        γ_group["coef_min_ex"] = coef_minₑₓ
        γ_group["coef_max_ex"] = coef_maxₑₓ
        γ_group["coef_gap_ex"] = coefs_gapₑₓ
                        
        γ_group["coef_min_lme"] = coef_minₗₘₑ
        γ_group["coef_max_lme"] = coef_maxₗₘₑ
        γ_group["coef_gap_lme"] = coefs_gapₗₘₑ       
                        
        γ_group["obj_val_lme"] = obj_val_lme
        γ_group["obj_val_sid_on_lme"] = obj_val_sid_on_lme
        
        γ_group["obj_val_lme_on_exact"] = obj_val_lme_on_exact
        γ_group["obj_val_sid_on_exact"] = obj_val_sid_on_exact


        γ_group["H_sid_exact"] = convert.(ComplexF64, Hˢⁱᵈₑₓ)
        γ_group["A_sid_exact"] = convert.(ComplexF64, Aˢⁱᵈₑₓ)
        
        γ_group["H_lme"] = convert.(ComplexF64, Hᴸᴹᴱ)
        γ_group["A_lme"] = convert.(ComplexF64, Aᴸᴹᴱ)
        
        γ_group["H_sid_lme"] = convert.(ComplexF64, Hˢⁱᵈₗₘₑ)
        γ_group["A_sid_lme"] = convert.(ComplexF64, Aˢⁱᵈₗₘₑ)

        
    end # of HDF5 writing
    
    
    h5open(tests_dir*tests_data_file_name,"cw") do fid
        γ_group = create_group(fid, "gamma_"*γᵢ)
    end 
    
    for df in test_files # loop over initial states
        
        print(df*" ")

        start_time = time()

        ρₛ, tₛ = LiPoSID.get_rho_series(data_dir*df*"_2CUT_data.h5", γᵢ)
        ρₛ = convert(Vector{Matrix{ComplexF64}}, ρₛ)

        ρᵗˢᵗ = [DenseOperator(basis,Hermitian(ρₜ)) for ρₜ in ρₛ]

        tᵗˢᵗ = convert(Vector{Float64}, tₛ)

        tᴸᴹᴱ, ρᴸᴹᴱ  = timeevolution.master(tᵗˢᵗ, ρᵗˢᵗ[1], DenseOperator(basis,Hᴸᴹᴱ), [DenseOperator(basis,Aᴸᴹᴱ)])
        tˢⁱᵈₗₘ, ρˢⁱᵈₗₘₑ  = timeevolution.master(tᵗˢᵗ, ρᵗˢᵗ[1], DenseOperator(basis,Hˢⁱᵈₗₘₑ), [DenseOperator(basis,Aˢⁱᵈₗₘₑ)])
        tˢⁱᵈₑₓ, ρˢⁱᵈₑₓ  = timeevolution.master(tᵗˢᵗ, ρᵗˢᵗ[1], DenseOperator(basis,Hˢⁱᵈₑₓ), [DenseOperator(basis,Aˢⁱᵈₑₓ)])   
        

        Fᴸᴹᴱₑₓ = [abs(fidelity(ρ₁, ρ₂)) for (ρ₁, ρ₂) in zip(ρᵗˢᵗ, ρᴸᴹᴱ)]
        Fˢⁱᵈᴸᴹᴱₗₘₑ = [abs(fidelity(ρ₁, ρ₂)) for (ρ₁, ρ₂) in zip(ρˢⁱᵈₗₘₑ, ρᴸᴹᴱ)]
        Fˢⁱᵈᵉˣₑₓ = [abs(fidelity(ρ₁, ρ₂)) for (ρ₁, ρ₂) in zip(ρᵗˢᵗ, ρˢⁱᵈₑₓ)]
                    

        h5open(tests_dir*tests_data_file_name,"cw") do fid
            γ_group = open_group(fid, "gamma_"*γᵢ) # open coupling group

            init_state_group = create_group(γ_group, df) # create initial state group
            init_state_group["F_lme_exact"] = convert.(Float64, Fᴸᴹᴱₑₓ)
            init_state_group["F_sidlme_lme"] = convert.(Float64, Fˢⁱᵈᴸᴹᴱₗₘₑ)
            init_state_group["F_sidexact_exact"] = convert.(Float64, Fˢⁱᵈᵉˣₑₓ)
            
        end
                    
        print(minimum(Fᴸᴹᴱₑₓ), minimum(Fˢⁱᵈᴸᴹᴱₗₘₑ), minimum(Fˢⁱᵈᵉˣₑₓ))
        println(" ")
    
    end
                
    println()
    println()
                            

end
# Out:
# POP_Rm1238_trn4_tst20_fix-Phi-up_2023-Aug-12_at_12-04.h5
# ---------------
# gamma = 0.079477
# -------------------------------------------
#  POP on ansatz LME simulation
# -1.306163553400041
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 7.163137151311779e-8
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.01048907.
# The relative optimality gap is: 1.048900%.
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = -2.289250896940321e-8
# Global optimality certified with relative optimality gap 0.000000%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.010489068180447703, -1.914207814479596e-8]
# Best metod for POP on LME: scaled_tssos
# -------------------------------------------
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# -1.3058306715553685
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.0004975469374493475
# Global optimality certified with relative optimality gap 0.000002%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.0004975296434001089
# Global optimality certified with relative optimality gap 0.000000%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.000497525216530903, 0.0004975252164740596]
# Best metod for POP on EXACT: scaled_tssos
# State_D1 0.99935352098189480.99940274592942220.9991621230070726
# State_D2 0.99935681686812320.99940644237750540.9991483630478053
# State_D3 0.99935661462665140.99940274445910970.9993469426927171
# State_D4 0.99935836191064240.99940644094792560.9993286467224882
# State_D5 0.99916672493201930.99922066764256870.9990067517553977
# State_D6 0.99916671038345820.99922066776128150.9989957365667193
# State_D7 0.99902949097376310.99910478959658310.9989453582095045
# State_D8 0.99903081651906030.99910848616251810.9989298569958024
# State_D9 0.99984294340485670.99988628973638670.9997598679151855
# State_D10 0.99987599922945370.99988629317363680.9998689464255593
# State_D11 0.99935660567504080.99940274457271560.9993271619706525
# State_D12 0.99935835884283440.99940644079377830.9993407611306053
# State_D13 0.99935347663438970.99940274599685240.9991535691658543
# State_D14 0.99935679644617110.99940644227781040.9991461969801709
# State_D15 0.99916730532163460.99922066682802320.9991106911992975
# State_D16 0.99916726653008370.99922066664633320.9991332433931248
# State_D17 0.99902947501450470.99910478967234680.9989271262148067
# State_D18 0.99903081160160560.9991084862980370.9989330198813833
# State_D19 0.99987600398464640.99988629318262490.9998647960827702
# State_D20 0.99984292059548430.99988628975930440.9997597992346196
#
#
# ---------------
# gamma = 0.25133
# -------------------------------------------
#  POP on ansatz LME simulation
# -2.2465703193430797
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 1.4277751856164458e-7
# Global optimality certified with relative optimality gap 0.000014%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = -8.290915460370812e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.01111940.
# The relative optimality gap is: 1.111941%.
# No higher TS step of the TSSOS hierarchy!
# val_p = [-1.6221690657403087e-10, 0.01111939713133836]
# Best metod for POP on LME: tssos
# -------------------------------------------
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# -2.2461428801721377
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.0011885954951882135
# Global optimality certified with relative optimality gap 0.000002%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.0011885752305250646
# Global optimality certified with relative optimality gap 0.000000%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.0011885796697228557, 0.0011885796696873285]
# Best metod for POP on EXACT: scaled_tssos
# State_D1 0.99955152061585510.99999999165810480.9999199515960226
# State_D2 0.99956356530292250.99999999182690840.9999000683269268
# State_D3 0.99983272399378680.99999999165752240.999966345413238
# State_D4 0.99982901753082830.99999999182657470.9999775230460463
# State_D5 0.99964268595998840.99999998919441420.9998514114467536
# State_D6 0.99964306428345340.99999998919431140.9999023309390894
# State_D7 0.999736012691620.99999998752640050.9998702140120159
# State_D8 0.99973592154082720.99999998769580320.9999196258252971
# State_D9 0.99938774542035480.99999999842231650.9999395660829132
# State_D10 0.99989563535763570.99999999842188660.9999830917902384
# State_D11 0.99983272041672590.99999999165817720.9999530296121335
# State_D12 0.99982902090567520.99999999182690310.9999535563295896
# State_D13 0.99955147670823830.99999999165800490.999872055395544
# State_D14 0.99956306569172870.99999999182715930.999850348435577
# State_D15 0.99978674445289430.99999998919427390.9999727739442947
# State_D16 0.99978677794349450.9999999891940850.9999098018194228
# State_D17 0.99973587609783330.99999998752678150.9998230862852524
# State_D18 0.99973592477672040.99999998769526640.9999620876637474
# State_D19 0.99989564287510440.99999999842225610.9999929700026903
# State_D20 0.99938728054729950.99999999842232410.9999288059323528
#
#
# ---------------
# gamma = 0.79477
# -------------------------------------------
#  POP on ansatz LME simulation
# -3.1594305069528215
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 7.941103205979783e-8
# Global optimality certified with relative optimality gap 0.000008%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = -2.86926235706615e-9
# Global optimality certified with relative optimality gap 0.000000%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [3.47455397786689e-12, 3.4736657994471898e-12]
# Best metod for POP on LME: scaled_tssos
# -------------------------------------------
#  POP on ansatz EXACT Kurt data
# -3.1591074872133382
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.0009536414601571555
# Global optimality certified with relative optimality gap 0.000022%!
# optimum = 0.0009534794107117739
# Global optimality certified with relative optimality gap 0.000006%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.0009533814658981536
# Global optimality certified with relative optimality gap 0.000004%!
# optimum = 0.0009534043324700249
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.0009534168433820156, 0.0009534168433855683]
# Best metod for POP on EXACT: tssos
# State_D1 0.99809643593360950.99999999999729080.999658138511339
# State_D2 0.99812929838099360.99999999999912870.9997183395946003
# State_D3 0.99882914759186530.99999999999940760.9997982023337693
# State_D4 0.99883459456136880.99999999999970010.9997980864372316
# State_D5 0.99827581834072980.99999999999761780.9992700796126351
# State_D6 0.99827600330230990.99999999999753970.9997601427316307
# State_D7 0.99850148794723810.99999999999894850.9997764405980496
# State_D8 0.99851388008865440.99999999999782330.9997175578915272
# State_D9 0.99789548674089160.99999999999990790.9997404655822547
# State_D10 0.99899482220359910.99999999999977010.9998118605391595
# State_D11 0.99882898529036370.99999999999939780.99939126547923
# State_D12 0.99883370462813540.99999999999963970.9997550180792376
# State_D13 0.99809719710336380.99999999999728170.9993453419649385
# State_D14 0.9981294057959960.99999999999908280.9994606131955066
# State_D15 0.9987200680942190.99999999999881430.9996125277707513
# State_D16 0.99872051243386570.99999999999888280.9996085585551862
# State_D17 0.99850183419307970.99999999999877340.9986976207411278
# State_D18 0.99851380960311230.99999999999800990.999777864704074
# State_D19 0.99899505916456450.99999999999976770.9998085263586531
# State_D20 0.99789912772182470.99999999999990850.9997420535628077
#
#
# ---------------
# gamma = 2.5133
# -------------------------------------------
#  POP on ansatz LME simulation
# -3.9561107114686718
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 2.4179307732712406e-7
# Global optimality certified with relative optimality gap 0.000024%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = -1.376752729783944e-9
# Global optimality certified with relative optimality gap 0.000000%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [5.21249710061511e-12, 5.212275056010185e-12]
# Best metod for POP on LME: scaled_tssos
# -------------------------------------------
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# -3.9595332771234477
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.0012968598696760647
# Global optimality certified with relative optimality gap 0.000015%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.0012967086126839937
# Global optimality certified with relative optimality gap 0.000000%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.0012967106689663055, 0.0012967106689658614]
# Best metod for POP on EXACT: scaled_tssos
#  Exact data overfitting
# State_D1 0.99329503112404440.99999999999998880.9965262129727711
# State_D2 0.9934706527111560.99999999999998950.9965308816817653
# State_D3 0.99485498029184340.99999999999997280.9966594384094274
# State_D4 0.99489418614275260.99999999999997370.9966681320020795
# State_D5 0.99369200299696150.99999999999998580.9965453884264617
# State_D6 0.9936872823793240.9999999999999850.9965439233344049
# State_D7 0.9940840127457260.9999999999999790.9965798623967903
# State_D8 0.99416359770568630.99999999999998020.9965801803844395
# State_D9 0.99309558356315260.99999999999999640.9965229011908149
# State_D10 0.99528592577601020.99999999999997060.9967377185956204
# State_D11 0.99485841291352760.99999999999997270.9966490618192282
# State_D12 0.99489358961893970.99999999999997420.9966703945387569
# State_D13 0.99330365132792160.99999999999998850.9965245684751365
# State_D14 0.99346810272975930.99999999999998960.9965346767074477
# State_D15 0.99461544917441620.99999999999997590.9966194726988449
# State_D16 0.99461410620583830.99999999999997580.9966283702429751
# State_D17 0.99408471481591740.99999999999997970.9965694140678547
# State_D18 0.99416336919947280.99999999999998030.9965868143909336
# State_D19 0.99528518432713350.99999999999997090.9967366264840049
# State_D20 0.99309568786937410.9999999999999960.9965230625245118
#
#
# ---------------
# gamma = 7.9477
# -------------------------------------------
#  POP on ansatz LME simulation
# -4.886826303518809
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 4.862486825031776e-8
# Global optimality certified with relative optimality gap 0.000005%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = -2.3983273551021893e-9
# Global optimality certified with relative optimality gap 0.000000%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [6.768752225383423e-13, 6.697142840295101e-13]
# Best metod for POP on LME: scaled_tssos
# -------------------------------------------
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# -4.928645395120415
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.0015467705231459923
# Global optimality certified with relative optimality gap 0.000002%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.0015467500173362214
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.0015467551319388179, 0.001546755131938804]
# Best metod for POP on EXACT: scaled_tssos
#  Exact data overfitting
# State_D1 0.97672504259896330.99999999999999530.9993997336069964
# State_D2 0.97774941730723240.99999999999999630.9992334375206202
# State_D3 0.98101678334406990.99999999999999420.9996412166365358
# State_D4 0.98136148002746780.99999999999999570.9992955558823818
# State_D5 0.97803188916246430.99999999999999570.9994144671962164
# State_D6 0.97803188929302030.99999999999999510.9984547981657571
# State_D7 0.97861975148893270.9999999999999940.9991217897471834
# State_D8 0.97924654746507740.99999999999999470.9990663923243398
# State_D9 0.9767588002107730.9999999999999980.9991690965620761
# State_D10 0.98246650476308160.99999999999999610.9997631271522694
# State_D11 0.98101678333942080.99999999999999430.9976151234281343
# State_D12 0.9813614800610090.99999999999999560.999583733443034
# State_D13 0.97672504260648490.99999999999999490.9978650302201314
# State_D14 0.97774941742322750.99999999999999640.9994993971570676
# State_D15 0.98047793347612970.99999999999999470.9981280398000374
# State_D16 0.98047793345915250.99999999999999510.9994785424859486
# State_D17 0.97861975147508910.99999999999999330.9967460760077886
# State_D18 0.97924654742324810.99999999999999490.9994824368471167
# State_D19 0.98246650475196750.99999999999999610.9993904348266991
# State_D20 0.97675880035836470.99999999999999780.99909697058808
#
#
# ---------------
# gamma = 25.133
# -------------------------------------------
#  POP on ansatz LME simulation
# -5.562048255415158
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 1.1549148634579922e-8
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = -1.5273466094578458e-8
# Global optimality certified with relative optimality gap 0.000002%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [1.1930734178378088e-13, 1.1854059400739914e-13]
# Best metod for POP on LME: scaled_tssos
# -------------------------------------------
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# -5.942775041590153
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.0021410832445032738
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.00214101078960322
# Global optimality certified with relative optimality gap 0.000007%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.0021410765514372123, 0.0021410765514372244]
# Best metod for POP on EXACT: tssos
#  Exact data overfitting
# State_D1 0.91124510601931090.99999999999999780.9960232854193523
# State_D2 0.9119663713130960.9999999999999980.9973636887300927
# State_D3 0.91487693128799170.99999999999999760.9954879579111386
# State_D4 0.93620316440051480.99999999999999820.99900263791689
# State_D5 0.91252155500886210.99999999999999790.9984749561095557
# State_D6 0.91252155500415010.99999999999999730.98413949852068
# State_D7 0.91883893874244750.99999999999999690.9925845950082341
# State_D8 0.91313353040438890.99999999999999790.9872449828480925
# State_D9 0.91105351726581320.99999999999999830.9996045152390973
# State_D10 0.91609992316778430.99999999999999840.9996393856066992
# State_D11 0.91487693128799170.99999999999999710.9791308002004737
# State_D12 0.93620316440096230.9999999999999980.9960928555989563
# State_D13 0.91124993894953730.99999999999999720.9781511726417409
# State_D14 0.9119663713146580.9999999999999980.995192531334133
# State_D15 0.93089575256946620.99999999999999790.9888831793437165
# State_D16 0.93089575257037750.99999999999999790.9987132426940916
# State_D17 0.91883893874296220.99999999999999660.9731104302013389
# State_D18 0.91313353040335010.99999999999999780.9976315798219683
# State_D19 0.91609992316931390.99999999999999830.9946794369191561
# State_D20 0.91105351726791620.99999999999999810.9936644092998217
#
#
# ---------------
# gamma = 79.477
# -------------------------------------------
#  POP on ansatz LME simulation
# -5.303000641653664
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 6.180723464426086e-8
# Global optimality certified with relative optimality gap 0.000006%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = -3.768433630772922e-9
# Global optimality certified with relative optimality gap 0.000000%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [8.770345560904502e-13, 8.769929227270268e-13]
# Best metod for POP on LME: scaled_tssos
# -------------------------------------------
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# -6.236668553017445
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.001863502703262079
# Global optimality certified with relative optimality gap 0.000005%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.001863444548748615
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00198461.
# The relative optimality gap is: 0.012117%.
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.001863456281843277, 0.0019846095750617513]
# Best metod for POP on EXACT: tssos
#  Exact data overfitting
# State_D1 0.78829457485258740.99999999999999820.9998472922317987
# State_D2 0.7883295725234580.99999999999999810.9999347758999597
# State_D3 0.7873772496849930.99999999999999810.9997605440781803
# State_D4 0.78746555872586730.99999999999999830.9996710589908833
# State_D5 0.78841323589288610.99999999999999780.9998370610146488
# State_D6 0.78841323589162440.9999999999999980.9997854543184097
# State_D7 0.78800765942735440.99999999999999820.9992955390356556
# State_D8 0.78804633541218350.99999999999999780.9989689980500336
# State_D9 0.78805632530926660.99999999999999770.9999480414571121
# State_D10 0.78697585469908350.99999999999999820.9995510505093705
# State_D11 0.78737724968690370.99999999999999820.9991529159016996
# State_D12 0.78746555872524150.99999999999999780.9994497885047904
# State_D13 0.78829457485575430.99999999999999830.9991578851563111
# State_D14 0.78832957252473580.99999999999999780.9996603794314032
# State_D15 0.78771534874778090.99999999999999810.9996492328402227
# State_D16 0.78771534874461310.99999999999999820.9996914091191316
# State_D17 0.78800765942480820.99999999999999820.9978908617771739
# State_D18 0.78804633541219770.99999999999999810.999780633830078
# State_D19 0.78697585470035480.99999999999999780.9993845009173997
# State_D20 0.78805632530801550.99999999999999830.9997142882015363
#
#
# ---------------
# gamma = 251.33
# -------------------------------------------
#  POP on ansatz LME simulation
# -4.661743316117351
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
#  TSSOS failed
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# Scaled TSSOS failed
# All methods fail !!!Best metod for POP on LME: fail
# -------------------------------------------
#  POP on ansatz EXACT Kurt data
# -5.820051639850056
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.014494379254962015
# Global optimality certified with relative optimality gap 0.000007%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.014494238303912768
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.01507529.
# The relative optimality gap is: 0.058105%.
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.014494308917493329, 0.015075286153000881]
# Best metod for POP on EXACT: tssos
#  Exact data overfitting
# State_D1 0.73688039058929820.70696393326855770.9979400038795943
# State_D2 0.73688971180127630.69197928878408650.9970408719079473
# State_D3 0.73392638838295920.74484257639741140.9978333639053297
# State_D4 0.73394585204433690.73063450778699470.9969272717385701
# State_D5 0.73822607234890770.7031074614141150.9964135918990478
# State_D6 0.73822607234891480.67855837870120250.9959961759450491
# State_D7 0.73977887159394380.73289983251023180.9984407593252366
# State_D8 0.73981430787393880.68161579821071170.9989218093433108
# State_D9 0.73435691393744280.68099815282645320.9968491026570625
# State_D10 0.72932820338321790.74346309418513070.9966517206282807
# State_D11 0.73392638838381130.69927637335014330.9976108721635992
# State_D12 0.73394585204461990.71410665519733880.9972189486450278
# State_D13 0.73688039059007470.65878261455172830.9977075017946713
# State_D14 0.73688971180127630.67450553105161710.9973265586251252
# State_D15 0.73672455527686750.70315615391793850.9959226012213953
# State_D16 0.73672455527884740.72687425555816340.9963410109308426
# State_D17 0.73977887157479960.67203482177971830.9958149646268268
# State_D18 0.73981430787000060.72401548049395690.9990068632602838
# State_D19 0.72932820338394840.72458590396110270.9966763042796128
# State_D20 0.7343569139367490.66033738391497320.9968678969993628

# %%
tests_data_file_name
# Out:
# "POP_Rm1238_trn4_tst20_fix-Phi-up_2023-Aug-12_at_12-04.h5"

# %% [markdown]
# ### Full POP model works

# %%
include("LiPoSID.jl")
using QuantumOptics
basis = NLevelBasis(2)
using DynamicPolynomials
using LinearAlgebra
using Dates
using HDF5

# %% [markdown]
# Consider simple Lindblad master equation with just one dissipator:
#
# $m
#      \frac{d\rho}{dt} = - \frac{i}{\hbar}[H, \rho]+\gamma\left[A \rho A^\dagger - \frac{1}{2}\left\{ A^\dagger A, \rho \right\} \right]
# $,
#
# where Hamiltonian is hermitian with one of the diagonal elemnets set to zero
#
#
# $
#     H = \begin{pmatrix} e_1 & h_1 - i h_2 \\ h_1 + i h_2 & 0
#    \end{pmatrix}
# $
#
#  we can possibly look for jump operator of the form:
#
# $
# A = \begin{pmatrix} a_{11} + i b_{11} & a_{12} \\ a_{21} + i b_{21} & -a_{11} - i b_{11}
#    \end{pmatrix}
# $
#
# or
#
# $
# A = \begin{pmatrix} a_{11} & a_{12} + i b_{12}  \\ a_{21} + i b_{21} & -a_{11}
#    \end{pmatrix}
# $
#
# or assuming zero temperature
#
# $
# A = \begin{pmatrix} a_{11} + i b_{11} & a_{12}   \\ 0 & -a_{11} - i b_{11}
#    \end{pmatrix}
# $

# %%
@polyvar e[1]
@polyvar h[1:2]


Hˢʸᵐᵇ = [ e[1]               h[1] - im*h[2]
          h[1] + im*h[2]     0.             ]
# Out:
# 2×2 Matrix{Polynomial{true, ComplexF64}}:
#  e₁                  h₁ + (0.0-1.0im)h₂
#  h₁ + (0.0+1.0im)h₂  0.0+0.0im

# %%
method = "T0_diag0_fix-Phi-up_"

@polyvar a[1:4]
@polyvar b[1:4]


#"just-zero-down_ "

#Aˢʸᵐᵇ = [ a[1]+im*b[1]      a[2] + im*b[2] 
#          0                -a[1]-im*b[1]  ]


#"fix-Phi-up_: "

#Aˢʸᵐᵇ = [ a[1]+im*b[1]      a[2]
#          a[3] + im*b[3]   -a[1]-im*b[1] ]


#"zero Temperature and fix-Phi-up_: " zero_down_fix-Phi-up_

#Aˢʸᵐᵇ = [ a[1]+im*b[1]      a[2]
#          0                -a[1]-im*b[1] ]

#"zero Temperature and fix-Phi-diag_: "

#Aˢʸᵐᵇ = [ a[1]     a[2]+im*b[2] 
#          0        -a[1]        ]

#"zero Temperature, 00-diagonal, fix-Phi-up_: "

Aˢʸᵐᵇ = [ 0       a[2] 
          0        0        ]
# Out:
# 2×2 Matrix{Term{true, Int64}}:
#  0  a₂
#  0  0

# %%
pwd()
# Out:
# "/home/zah/POP23"

# %%
parentdir = pwd()
data_dir = parentdir*"/DATA/"
println(data_dir)

models_dir = parentdir*"/MODELS/"
tests_dir = parentdir*"/TESTS/"

dodeca_files = ["State_D"*string(n) for n=1:20];

basis_files = ["State_B"*string(n) for n=1:4];
# Out:
# /home/zah/POP23/DATA/

# %%
all_files = vcat(dodeca_files, basis_files)
train_files = basis_files 
test_files = dodeca_files;

# %% [markdown]
# ### Train models loop

# %%
import Base.real
function remove_micro_coefs(p::AbstractPolynomial, cutoff)
    sum(
        
        [abs(coef) > cutoff ? real(coef) * mon : 0 for (coef, mon) in zip(coefficients(p), monomials(p))]
        )
end
# Out:
# remove_micro_coefs (generic function with 1 method)

# %%
date_and_time_string =  string(Dates.format(now(), "yyyy-u-dd_at_HH-MM"))
models_file = "POP_NoRmT0d0LME_trn4_gap_"*method*date_and_time_string * ".h5"
tests_data_file_name = "POP_NoRmT0d0LME_trn4_gap_tst20_"*method*date_and_time_string * ".h5"

println(models_file)

γ = [ "0.079477",  "0.25133", "0.79477", "2.5133", "7.9477", "25.133", "79.477", "251.33"]

for γᵢ in γ
    
    println("---------------")
    println("gamma = ", γᵢ)
    
    Hᴸᴹᴱ = [ 25.126        0
             0             0    ]
    γᶠ = parse(Float64, γᵢ)

    Aᴸᴹᴱ = [ 0    √(γᶠ)
             0     0. + 0im  ]

    objₑₓ = 0
    
    objₗₘₑ = 0
    
    for df_trn in train_files # loop over initial states

        ρᵗʳⁿ, tᵗʳⁿ = LiPoSID.get_rho_series(data_dir*df_trn*"_2CUT_data.h5", γᵢ)
        
        if length(tᵗʳⁿ) > 1200 end_train = 1200 else end_train = length(tᵗʳⁿ) end
            
        ρᵗʳⁿ = convert(Vector{Matrix{ComplexF64}}, ρᵗʳⁿ[1:end_train])
        
        ρᵗʳⁿₒₚₛ = [DenseOperator(basis,Hermitian(ρₜ)) for ρₜ in ρᵗʳⁿ]
        tᵗʳⁿ = convert(Vector{Float64}, tᵗʳⁿ[1:end_train])
    
        objₑₓ += LiPoSID.simpson_obj(ρᵗʳⁿ, tᵗʳⁿ,  Hˢʸᵐᵇ, [Aˢʸᵐᵇ])
         
        
        ρˡᵐᵉ = LiPoSID.Lindblad_time_evolution(basis, ρᵗʳⁿ[1], tᵗʳⁿ, Hᴸᴹᴱ, [Aᴸᴹᴱ])
        objₗₘₑ += LiPoSID.simpson_obj(ρˡᵐᵉ, tᵗʳⁿ,  Hˢʸᵐᵇ, [Aˢʸᵐᵇ])
            
        
    end # of files (initial states) loop
    
    objₑₓrm = objₑₓ
    objₗₘₑrm = objₗₘₑ
    
    # if γᵢ == γ[1] #"0.079477" 
    #     objₑₓrm = remove_micro_coefs(objₑₓ, 5e-3)
    #     objₗₘₑrm = remove_micro_coefs(objₗₘₑ, 5e-5)
    # elseif  γᵢ == γ[2] #"0.25133" 
    #     objₑₓrm = remove_micro_coefs(objₑₓ, 1e-3)
    #     objₗₘₑrm = remove_micro_coefs(objₗₘₑ, 5e-7)           
    # elseif  γᵢ == γ[3] #"0.79477"
    #     objₑₓrm = remove_micro_coefs(objₑₓ, 5e-4)
    #     objₗₘₑrm = remove_micro_coefs(objₗₘₑ, 1e-6)
    # else 
    #     objₑₓrm = objₑₓ
    #     objₗₘₑrm = objₗₘₑ
    # end
            
    coef_minₑₓ = minimum(abs.(coefficients(objₑₓ)))
    coef_maxₑₓ = maximum(abs.(coefficients(objₑₓ)))
            
    cutoffₑₓ = log10(coef_maxₑₓ)-4

    coefs_gapₑₓ = coef_maxₑₓ/coef_minₑₓ 
            
    coef_minₗₘₑ = minimum(abs.(coefficients(objₗₘₑ)))
    coef_maxₗₘₑ = maximum(abs.(coefficients(objₗₘₑ)))
            
    cutoffₗₘₑ = log10(coef_maxₗₘₑ)-4

    coefs_gapₗₘₑ= coef_maxₗₘₑ/coef_minₗₘₑ 
       
    println("-------------------------------------------")
    println(" POP on ansatz LME simulation")
    println(cutoffₗₘₑ)
            
    #objₗₘₑrm = coefs_gapₗₘₑ > 1e6 ? remove_micro_coefs(objₗₘₑ, cutoffₗₘₑ) : objₗₘₑ
    
    solˢⁱᵈₗₘₑ, best_methodˢⁱᵈₗₘₑ = LiPoSID.sos_min_newton(objₗₘₑrm)

    
    println("Best metod for POP on LME: ", best_methodˢⁱᵈₗₘₑ)
    println("-------------------------------------------")
    
    solₗₘₑ = [e[1], h[1], h[2], a[1], a[2], a[3], b[1], b[3]] => [25.126, 0, 0, 0,  √(γᶠ), 0, 0, 0]
    
    obj_val_lme = convert(Float64, subs(objₗₘₑ, solₗₘₑ))
    
    obj_val_sid_on_lme = convert(Float64, subs(objₗₘₑ, solˢⁱᵈₗₘₑ))
    
    if obj_val_sid_on_lme < obj_val_lme
        println(" simulated LME overfitting")
    end
    
    Hˢⁱᵈₗₘₑ = subs(Hˢʸᵐᵇ, solˢⁱᵈₗₘₑ)
    Aˢⁱᵈₗₘₑ = subs(Aˢʸᵐᵇ, solˢⁱᵈₗₘₑ)
      
    println(" POP on ansatz EXACT Kurt data ")
    println(cutoffₑₓ)
                
    #objₑₓrm = coefs_gapₑₓ > 1e6 ? remove_micro_coefs(objₑₓ, cutoffₑₓ) : objₑₓ
    #objₑₓrm = coefs_gapₑₓ > 1e6 ? remove_micro_coefs(objₑₓ, -3) : objₑₓ
    
    solₑₓ, best_methodₑₓ = LiPoSID.sos_min_newton(objₑₓrm) 
    
    println("Best metod for POP on EXACT: ", best_methodₑₓ)
    
    obj_val_lme_on_exact = convert(Float64, subs(objₑₓ, solₗₘₑ))
    
    obj_val_sid_on_exact = convert(Float64, subs(objₑₓ, solₑₓ))
    
    if obj_val_sid_on_exact < obj_val_lme_on_exact
        println(" Exact data overfitting")
    end

    Hˢⁱᵈₑₓ = subs(Hˢʸᵐᵇ, solₑₓ)
    Aˢⁱᵈₑₓ = subs(Aˢʸᵐᵇ, solₑₓ)
    
    H = DenseOperator(basis, Hˢⁱᵈₑₓ)
    A = DenseOperator(basis, Aˢⁱᵈₑₓ)

    
    h5open(models_dir*models_file,"cw") do fid  # read-write, create file if not existing, preserve existing contents

        γ_group = create_group(fid, "gamma_"*γᵢ)
        
        
        γ_group["coef_min_ex"] = coef_minₑₓ
        γ_group["coef_max_ex"] = coef_maxₑₓ
        γ_group["coef_gap_ex"] = coefs_gapₑₓ
                        
        γ_group["coef_min_lme"] = coef_minₗₘₑ
        γ_group["coef_max_lme"] = coef_maxₗₘₑ
        γ_group["coef_gap_lme"] = coefs_gapₗₘₑ       
                        
        γ_group["obj_val_lme"] = obj_val_lme
        γ_group["obj_val_sid_on_lme"] = obj_val_sid_on_lme
        
        γ_group["obj_val_lme_on_exact"] = obj_val_lme_on_exact
        γ_group["obj_val_sid_on_exact"] = obj_val_sid_on_exact


        γ_group["H_sid_exact"] = convert.(ComplexF64, Hˢⁱᵈₑₓ)
        γ_group["A_sid_exact"] = convert.(ComplexF64, Aˢⁱᵈₑₓ)
        
        γ_group["H_lme"] = convert.(ComplexF64, Hᴸᴹᴱ)
        γ_group["A_lme"] = convert.(ComplexF64, Aᴸᴹᴱ)
        
        γ_group["H_sid_lme"] = convert.(ComplexF64, Hˢⁱᵈₗₘₑ)
        γ_group["A_sid_lme"] = convert.(ComplexF64, Aˢⁱᵈₗₘₑ)

        
    end # of HDF5 writing
    
    
    h5open(tests_dir*tests_data_file_name,"cw") do fid
        γ_group = create_group(fid, "gamma_"*γᵢ)
    end 
    
    for df in test_files # loop over initial states
        
        print(df*" ")

        start_time = time()

        ρₛ, tₛ = LiPoSID.get_rho_series(data_dir*df*"_2CUT_data.h5", γᵢ)
        ρₛ = convert(Vector{Matrix{ComplexF64}}, ρₛ)

        ρᵗˢᵗ = [DenseOperator(basis,Hermitian(ρₜ)) for ρₜ in ρₛ]

        tᵗˢᵗ = convert(Vector{Float64}, tₛ)

        tᴸᴹᴱ, ρᴸᴹᴱ  = timeevolution.master(tᵗˢᵗ, ρᵗˢᵗ[1], DenseOperator(basis,Hᴸᴹᴱ), [DenseOperator(basis,Aᴸᴹᴱ)])
        tˢⁱᵈₗₘ, ρˢⁱᵈₗₘₑ  = timeevolution.master(tᵗˢᵗ, ρᵗˢᵗ[1], DenseOperator(basis,Hˢⁱᵈₗₘₑ), [DenseOperator(basis,Aˢⁱᵈₗₘₑ)])
        tˢⁱᵈₑₓ, ρˢⁱᵈₑₓ  = timeevolution.master(tᵗˢᵗ, ρᵗˢᵗ[1], DenseOperator(basis,Hˢⁱᵈₑₓ), [DenseOperator(basis,Aˢⁱᵈₑₓ)])   
        

        Fᴸᴹᴱₑₓ = [abs(fidelity(ρ₁, ρ₂)) for (ρ₁, ρ₂) in zip(ρᵗˢᵗ, ρᴸᴹᴱ)]
        Fˢⁱᵈᴸᴹᴱₗₘₑ = [abs(fidelity(ρ₁, ρ₂)) for (ρ₁, ρ₂) in zip(ρˢⁱᵈₗₘₑ, ρᴸᴹᴱ)]
        Fˢⁱᵈᵉˣₑₓ = [abs(fidelity(ρ₁, ρ₂)) for (ρ₁, ρ₂) in zip(ρᵗˢᵗ, ρˢⁱᵈₑₓ)]
                    

        h5open(tests_dir*tests_data_file_name,"cw") do fid
            γ_group = open_group(fid, "gamma_"*γᵢ) # open coupling group

            init_state_group = create_group(γ_group, df) # create initial state group
            init_state_group["F_lme_exact"] = convert.(Float64, Fᴸᴹᴱₑₓ)
            init_state_group["F_sidlme_lme"] = convert.(Float64, Fˢⁱᵈᴸᴹᴱₗₘₑ)
            init_state_group["F_sidexact_exact"] = convert.(Float64, Fˢⁱᵈᵉˣₑₓ)
            
        end
                    
        print(minimum(Fᴸᴹᴱₑₓ), minimum(Fˢⁱᵈᴸᴹᴱₗₘₑ), minimum(Fˢⁱᵈᵉˣₑₓ))
        println(" ")
    
    end
                
    println()
    println()
                            

end
# Out:
# POP_NoRmT0d0LME_trn4_gap_T0_diag0_fix-Phi-up_2023-Aug-10_at_17-26.h5
# ---------------
# gamma = 0.079477
# -------------------------------------------
#  POP on ansatz LME simulation
# -1.306163553400041
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 1.4732054544616481e-8
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 2.4858890861786955e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.01048907.
# The relative optimality gap is: 1.048907%.
# No higher TS step of the TSSOS hierarchy!
# val_p = [3.21847437589895e-9, 0.010489068180447703]
# Best metod for POP on LME: tssos
# -------------------------------------------
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# -1.3058306715553685
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.001268525407136564
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.01175844.
# The relative optimality gap is: 1.048991%.
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.001268512438910077
# The local solver failed refining the solution!
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.011758438139736427, 0.011758448433170088]
# Best metod for POP on EXACT: tssos
# State_D1 0.99935352098189480.99940274185644670.9453849143232598
# State_D2 0.99935681686812320.99940646706360580.9464530475670476
# State_D3 0.99935661462665140.9994027400102630.6444137845499791
# State_D4 0.99935836191064240.9994064652381790.6485413122638852
# State_D5 0.99916672493201930.99922069552241480.9084630508542012
# State_D6 0.99916671038345820.99922069553279760.908462925702725
# State_D7 0.99902949097376310.99910477841306820.8293615467828594
# State_D8 0.99903081651906030.99910850473846390.8321533578250732
# State_D9 0.99984294340485670.99988629633252210.9928634423983348
# State_D10 0.99987599922945370.99988629335639830.4650348257073582
# State_D11 0.99935660567504080.99940274002081810.6444071622831244
# State_D12 0.99935835884283440.9994064652519560.6485364248773621
# State_D13 0.99935347663438970.99940274186929780.9453833040952123
# State_D14 0.99935679644617110.99940646706885940.9464504131738134
# State_D15 0.99916730532163460.99922069439034990.7282331205375376
# State_D16 0.99916726653008370.99922069438600740.7282336658357234
# State_D17 0.99902947501450470.99910477843864660.8293548450153482
# State_D18 0.99903081160160560.99910850471850290.8321591756029961
# State_D19 0.99987600398464640.9998862933663260.46502944938336094
# State_D20 0.99984292059548430.99988629633996930.9928619200493345
#
#
# ---------------
# gamma = 0.25133
# -------------------------------------------
#  POP on ansatz LME simulation
# -2.2465703193430797
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 9.995362649125614e-9
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = -3.797219940210379e-9
# Global optimality certified with relative optimality gap 0.000000%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [1.4523493518936448e-11, 1.4516388091578847e-11]
# Best metod for POP on LME: scaled_tssos
# -------------------------------------------
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# -2.2461428801721377
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.0014358374953162862
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.0014358258056953546
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.01254270.
# The relative optimality gap is: 1.110687%.
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.001435827410077195, 0.012542700080999225]
# Best metod for POP on EXACT: tssos
#  Exact data overfitting
# State_D1 0.99955152061585510.99999999168233930.9995821640204777
# State_D2 0.99956356530292250.99999999183577950.9995945277401042
# State_D3 0.99983272399378680.99999999168205680.9998738909120075
# State_D4 0.99982901753082830.99999999183549830.9998743803661913
# State_D5 0.99964268595998840.99999998923584690.9996828179940502
# State_D6 0.99964306428345340.99999998923586260.9996832420681873
# State_D7 0.999736012691620.99999998754182250.999785156629788
# State_D8 0.99973592154082720.99999998769527740.9997878711938979
# State_D9 0.99938774542035480.99999999842271640.9993942121830458
# State_D10 0.99989563535763570.99999999842225470.9999031639439596
# State_D11 0.99983272041672590.99999999168206770.9998738004647543
# State_D12 0.99982902090567520.99999999183548470.9998742884925452
# State_D13 0.99955147670823830.99999999168235520.9995824436726669
# State_D14 0.99956306569172870.99999999183576890.9995941768175511
# State_D15 0.99978674445289430.99999998923568630.9998480093092555
# State_D16 0.99978677794349450.99999998923567170.9998483384911653
# State_D17 0.99973587609783330.99999998754183170.9997850601833531
# State_D18 0.99973592477672040.99999998769528440.9997880016145594
# State_D19 0.99989564287510440.99999999842225130.9999031694967714
# State_D20 0.99938728054729950.99999999842271870.9993937809511655
#
#
# ---------------
# gamma = 0.79477
# -------------------------------------------
#  POP on ansatz LME simulation
# -3.1594305069528215
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 1.0161944348539702e-8
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = -5.981099105330935e-9
# The local solver failed refining the solution!
# No higher TS step of the TSSOS hierarchy!
# val_p = [1.5857537505326036e-11, 0.012970889415075959]
# Best metod for POP on LME: tssos
# -------------------------------------------
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# -3.1591074872133382
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.0017854625000763614
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.0017854479273443022
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.01468737.
# The relative optimality gap is: 1.290192%.
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.0017854517200612818, 0.014687368389806998]
# Best metod for POP on EXACT: tssos
#  Exact data overfitting
# State_D1 0.99809643593360950.99999999999993550.9981101064898222
# State_D2 0.99812929838099360.99999999999993680.9981437834216743
# State_D3 0.99882914759186530.99999999999978580.9988545685842066
# State_D4 0.99883459456136880.99999999999978710.9988603617814619
# State_D5 0.99827581834072980.99999999999990830.9982948699353187
# State_D6 0.99827600330230990.99999999999990760.998295203760565
# State_D7 0.99850148794723810.999999999999860.9985251963218283
# State_D8 0.99851388008865440.99999999999986120.99853832113312
# State_D9 0.99789548674089160.99999999999998580.9979003500387397
# State_D10 0.99899482220359910.99999999999974090.9990171904745906
# State_D11 0.99882898529036370.99999999999978530.9988546978789684
# State_D12 0.99883370462813540.99999999999978620.9988596121105079
# State_D13 0.99809719710336380.99999999999993630.9981112105634102
# State_D14 0.9981294057959960.99999999999993690.9981440321284472
# State_D15 0.9987200680942190.99999999999981450.998746347781682
# State_D16 0.99872051243386570.9999999999998150.9987466551479767
# State_D17 0.99850183419307970.99999999999985930.9985259745179441
# State_D18 0.99851380960311230.99999999999986110.9985379373572196
# State_D19 0.99899505916456450.99999999999973990.9990175514444574
# State_D20 0.99789912772182470.99999999999998630.9979040516126702
#
#
# ---------------
# gamma = 2.5133
# -------------------------------------------
#  POP on ansatz LME simulation
# -3.9561107114686718
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 2.9176784445080815e-8
# Global optimality certified with relative optimality gap 0.000003%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = -1.4904447476829e-9
# Global optimality certified with relative optimality gap 0.000000%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [5.21249710061511e-12, 5.21249710061511e-12]
# Best metod for POP on LME: tssos
# -------------------------------------------
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# -3.9595332771234477
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.0030260895373680906
# Global optimality certified with relative optimality gap 0.000003%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.0030260542130255124
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.02148988.
# The relative optimality gap is: 1.846383%.
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.0030260550501903793, 0.021489883095680007]
# Best metod for POP on EXACT: tssos
#  Exact data overfitting
# State_D1 0.99329503112404440.99999999999998890.9933831050678236
# State_D2 0.9934706527111560.99999999999998980.9935751525593344
# State_D3 0.99485498029184340.99999999999997320.9950833978206918
# State_D4 0.99489418614275260.99999999999997350.9951275694953978
# State_D5 0.99369200299696150.99999999999998590.9938191401742417
# State_D6 0.9936872823793240.99999999999998510.9938166446502615
# State_D7 0.9940840127457260.99999999999997930.9942465639051074
# State_D8 0.99416359770568630.99999999999998070.9943378563271695
# State_D9 0.99309558356315260.99999999999999610.9931598761312517
# State_D10 0.99528592577601020.99999999999997080.9955479815019177
# State_D11 0.99485841291352760.99999999999997310.9950910057091417
# State_D12 0.99489358961893970.99999999999997360.9951286419407865
# State_D13 0.99330365132792160.99999999999998880.9933961881900929
# State_D14 0.99346810272975930.99999999999998980.993574248305003
# State_D15 0.99461544917441620.99999999999997570.9948282049864743
# State_D16 0.99461410620583830.99999999999997620.9948247632113542
# State_D17 0.99408471481591740.99999999999997950.9942531177500044
# State_D18 0.99416336919947280.99999999999997990.9943336424361449
# State_D19 0.99528518432713350.99999999999997070.9955490350766938
# State_D20 0.99309568786937410.99999999999999580.9931611894982927
#
#
# ---------------
# gamma = 7.9477
# -------------------------------------------
#  POP on ansatz LME simulation
# -4.886826303518809
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 1.5335576261533614e-9
# Global optimality certified with relative optimality gap 0.000000%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = -2.5478808676202213e-9
# Global optimality certified with relative optimality gap 0.000000%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [6.703249066930539e-13, 6.696587728782788e-13]
# Best metod for POP on LME: scaled_tssos
# -------------------------------------------
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# -4.928645395120415
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.004758009708975494
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.004757992474592784
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.004758001928907948, 0.004758001928907879]
# Best metod for POP on EXACT: scaled_tssos
#  Exact data overfitting
# State_D1 0.97672504259896330.99999999999999530.978886155773767
# State_D2 0.97774941730723240.99999999999999660.9805006307611435
# State_D3 0.98101678334406990.99999999999999390.9856144650425389
# State_D4 0.98136148002746780.99999999999999560.9861323191735073
# State_D5 0.97803188916246430.99999999999999530.9810934795646395
# State_D6 0.97803188929302030.99999999999999530.9809608758997264
# State_D7 0.97861975148893270.99999999999999420.981754686214908
# State_D8 0.97924654746507740.99999999999999490.9831397203649632
# State_D9 0.9767588002107730.99999999999999790.9791039235470159
# State_D10 0.98246650476308160.9999999999999960.9879610935651071
# State_D11 0.98101678333942080.99999999999999430.9857571294916216
# State_D12 0.9813614800610090.99999999999999560.9864192675959722
# State_D13 0.97672504260648490.99999999999999520.9790186664272476
# State_D14 0.97774941742322750.99999999999999640.9807816901614151
# State_D15 0.98047793347612970.99999999999999480.9847825569773757
# State_D16 0.98047793345915250.99999999999999440.9849051322522995
# State_D17 0.97861975147508910.99999999999999380.9820709098490321
# State_D18 0.97924654742324810.99999999999999490.9827621843479745
# State_D19 0.98246650475196750.99999999999999570.9880910800964786
# State_D20 0.97675880035836470.99999999999999770.9791980913471111
#
#
# ---------------
# gamma = 25.133
# -------------------------------------------
#  POP on ansatz LME simulation
# -5.562048255415158
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 3.895390017024612e-10
# Global optimality certified with relative optimality gap 0.000000%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = -2.5087284516869655e-8
# Global optimality certified with relative optimality gap 0.000003%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [1.1858916626472649e-13, 1.1858222737082258e-13]
# Best metod for POP on LME: scaled_tssos
# -------------------------------------------
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# -5.942775041590153
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.0064463145063492
# Global optimality certified with relative optimality gap 0.000003%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.006446274187932444
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.006446281859038275, 0.006446281859038277]
# Best metod for POP on EXACT: tssos
#  Exact data overfitting
# State_D1 0.91124510601931090.99999999999999730.9520968621684825
# State_D2 0.9119663713130960.99999999999999820.9714493914139383
# State_D3 0.91487693128799170.99999999999999740.9643825431065961
# State_D4 0.93620316440051480.99999999999999820.9911770399640951
# State_D5 0.91252155500886210.99999999999999770.9757182101948781
# State_D6 0.91252155500415010.99999999999999790.9295938129872479
# State_D7 0.91883893874244750.99999999999999730.9396039531429446
# State_D8 0.91313353040438890.99999999999999780.9476317161816921
# State_D9 0.91105351726581320.99999999999999780.9744048697460826
# State_D10 0.91609992316778430.99999999999999810.9907449251893821
# State_D11 0.91487693128799170.99999999999999770.9211249809398783
# State_D12 0.93620316440096230.99999999999999840.9822343986738409
# State_D13 0.91124993894953730.99999999999999730.8984767018240702
# State_D14 0.9119663713146580.99999999999999830.9777834162456233
# State_D15 0.93089575256946620.99999999999999810.9532970861941954
# State_D16 0.93089575257037750.99999999999999770.9878427311818649
# State_D17 0.91883893874296220.99999999999999730.8824026922864068
# State_D18 0.91313353040335010.99999999999999780.9723969260187473
# State_D19 0.91609992316931390.99999999999999820.9810975265144117
# State_D20 0.91105351726791620.99999999999999810.9587506033307956
#
#
# ---------------
# gamma = 79.477
# -------------------------------------------
#  POP on ansatz LME simulation
# -5.303000641653664
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 1.7380238834044925e-8
# Global optimality certified with relative optimality gap 0.000002%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = -1.063095336706366e-8
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [8.770068005148346e-13, 8.770276171965463e-13]
# Best metod for POP on LME: tssos
# -------------------------------------------
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# -6.695362510837062
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.0019846110150451308
# Global optimality certified with relative optimality gap 0.000000%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.0019846076041449365
# Global optimality certified with relative optimality gap 0.000000%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.0019846096424982755, 0.001984609600051652]
# Best metod for POP on EXACT: scaled_tssos
#  Exact data overfitting
# State_D1 0.78829457485258740.99999999999999830.9990455060795269
# State_D2 0.7883295725234580.99999999999999780.999552717851909
# State_D3 0.7873772496849930.99999999999999810.9991499481677997
# State_D4 0.78746555872586730.99999999999999790.9994879427108596
# State_D5 0.78841323589288610.99999999999999820.9995704710867996
# State_D6 0.78841323589162440.99999999999999760.9995212652711478
# State_D7 0.78800765942735440.99999999999999810.997660899373433
# State_D8 0.78804633541218350.99999999999999810.9989565549014275
# State_D9 0.78805632530926660.99999999999999820.9993222016723433
# State_D10 0.78697585469908350.9999999999999980.9994323092234842
# State_D11 0.78737724968690370.99999999999999810.9990975349908398
# State_D12 0.78746555872524150.99999999999999820.9994652527206689
# State_D13 0.78829457485575430.99999999999999820.9988893638857255
# State_D14 0.78832957252473580.99999999999999820.9993353675637036
# State_D15 0.78771534874778090.99999999999999830.9997206308436244
# State_D16 0.78771534874461310.99999999999999790.9997071527278889
# State_D17 0.78800765942480820.99999999999999820.9975560509447412
# State_D18 0.78804633541219770.99999999999999810.9990631963163719
# State_D19 0.78697585470035480.99999999999999820.999441958675892
# State_D20 0.78805632530801550.99999999999999820.9991298203750649
#
#
# ---------------
# gamma = 251.33
# -------------------------------------------
#  POP on ansatz LME simulation
# -4.661743316117351
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 8.402379597768667e-9
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = -2.98309649376517e-8
# Global optimality certified with relative optimality gap 0.000003%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [1.3231915563238772e-12, 1.323136045172646e-12]
# Best metod for POP on LME: scaled_tssos
# -------------------------------------------
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# -5.820051639850056
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.0150754488712718
# Global optimality certified with relative optimality gap 0.000009%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.015075338459228602
# Global optimality certified with relative optimality gap 0.000002%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.015075358338296945, 0.015075358125456993]
# Best metod for POP on EXACT: scaled_tssos
#  Exact data overfitting
# State_D1 0.73688039058929820.99999999999999560.9965663234700142
# State_D2 0.73688971180127630.99999999999999580.9949289913061576
# State_D3 0.73392638838295920.99999999999999630.995918004493425
# State_D4 0.73394585204433690.99999999999999610.9943139855961333
# State_D5 0.73822607234890770.9999999999999960.9938482457437078
# State_D6 0.73822607234891480.99999999999999640.9929399960414851
# State_D7 0.73977887159394380.99999999999999620.9996795880410558
# State_D8 0.73981430787393880.99999999999999610.9987150613459997
# State_D9 0.73435691393744280.99999999999999570.9947426369931474
# State_D10 0.72932820338321790.99999999999999610.9936658206215343
# State_D11 0.73392638838381130.99999999999999570.9940696869231795
# State_D12 0.73394585204461990.99999999999999610.9948816440028694
# State_D13 0.73688039059007470.99999999999999520.995765582043482
# State_D14 0.73688971180127630.9999999999999960.9956223326743261
# State_D15 0.73672455527686750.99999999999999590.99247463601174
# State_D16 0.73672455527884740.99999999999999640.993426579149667
# State_D17 0.73977887157479960.99999999999999580.996860146750745
# State_D18 0.73981430787000060.99999999999999660.9982655590229293
# State_D19 0.72932820338394840.99999999999999620.9936161885212896
# State_D20 0.7343569139367490.99999999999999430.9948603404655045

# %%
tests_data_file_name
# Out:
# "POP_NoRmT0d0LME_trn4_gap_tst20_T0_diag0_fix-Phi-up_2023-Aug-10_at_17-26.h5"

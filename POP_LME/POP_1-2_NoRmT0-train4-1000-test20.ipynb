# %% [markdown]
# ### Full POP model works

# %%
include("LiPoSID.jl")
using QuantumOptics
basis = NLevelBasis(2)
using DynamicPolynomials
using LinearAlgebra
using Dates
using HDF5

# %% [markdown]
# Consider simple Lindblad master equation with just one dissipator:
#
# $m
#      \frac{d\rho}{dt} = - \frac{i}{\hbar}[H, \rho]+\gamma\left[A \rho A^\dagger - \frac{1}{2}\left\{ A^\dagger A, \rho \right\} \right]
# $,
#
# where Hamiltonian is hermitian with one of the diagonal elemnets set to zero
#
#
# $
#     H = \begin{pmatrix} e_1 & h_1 - i h_2 \\ h_1 + i h_2 & 0
#    \end{pmatrix}
# $
#
#  we can possibly look for jump operator of the form:
#
# $
# A = \begin{pmatrix} a_{11} + i b_{11} & a_{12} \\ a_{21} + i b_{21} & -a_{11} - i b_{11}
#    \end{pmatrix}
# $
#
# or
#
# $
# A = \begin{pmatrix} a_{11} & a_{12} + i b_{12}  \\ a_{21} + i b_{21} & -a_{11}
#    \end{pmatrix}
# $
#
# or assuming zero temperature
#
# $
# A = \begin{pmatrix} a_{11} + i b_{11} & a_{12}   \\ 0 & -a_{11} - i b_{11}
#    \end{pmatrix}
# $

# %%
@polyvar e[1]
@polyvar h[1:2]


Hˢʸᵐᵇ = [ e[1]               h[1] - im*h[2]
          h[1] + im*h[2]     0.             ]
# Out:
# 2×2 Matrix{Polynomial{true, ComplexF64}}:
#  e₁                  h₁ + (0.0-1.0im)h₂
#  h₁ + (0.0+1.0im)h₂  0.0+0.0im

# %%
method = "T0_fix-Phi-up_"

@polyvar a[1:4]
@polyvar b[1:4]


#"just-zero-down_ "

#Aˢʸᵐᵇ = [ a[1]+im*b[1]      a[2] + im*b[2] 
#          0                -a[1]-im*b[1]  ]


#"fix-Phi-up_: "

#Aˢʸᵐᵇ = [ a[1]+im*b[1]      a[2]
#          a[3] + im*b[3]   -a[1]-im*b[1] ]


#"zero Temperature and fix-Phi-up_: " zero_down_fix-Phi-up_

Aˢʸᵐᵇ = [ a[1]+im*b[1]      a[2]
          0                -a[1]-im*b[1] ]

#"zero Temperature and fix-Phi-diag_: "

#Aˢʸᵐᵇ = [ a[1]     a[2]+im*b[2] 
#          0        -a[1]        ]
# Out:
# 2×2 Matrix{Polynomial{true, Complex{Int64}}}:
#  a₁ + (0+1im)b₁  a₂
#  0+0im           -a₁ + (0-1im)b₁

# %%
pwd()
# Out:
# "/home/zah/POP23"

# %%
parentdir = pwd()
data_dir = parentdir*"/DATA/"
println(data_dir)

models_dir = parentdir*"/MODELS/"
tests_dir = parentdir*"/TESTS/"

dodeca_files = ["State_D"*string(n) for n=1:20];

basis_files = ["State_B"*string(n) for n=1:4];
# Out:
# /home/zah/POP23/DATA/

# %%
all_files = vcat(dodeca_files, basis_files)
train_files = basis_files 
test_files = dodeca_files;

# %% [markdown]
# ### Train models loop

# %%
import Base.real
function remove_micro_coefs(p::AbstractPolynomial, cutoff)
    sum(
        
        [abs(coef) > cutoff ? real(coef) * mon : 0 for (coef, mon) in zip(coefficients(p), monomials(p))]
        )
end
# Out:
# remove_micro_coefs (generic function with 1 method)

# %%
date_and_time_string =  string(Dates.format(now(), "yyyy-u-dd_at_HH-MM"))
models_file = "POP_NoRmT0LME_trn4_gap_"*method*date_and_time_string * ".h5"
tests_data_file_name = "POP_NoRmT0LME_trn4_gap_tst20_"*method*date_and_time_string * ".h5"

println(models_file)

γ = [ "0.079477",  "0.25133", "0.79477", "2.5133", "7.9477", "25.133", "79.477", "251.33"]

for γᵢ in γ
    
    println("---------------")
    println("gamma = ", γᵢ)
    
    Hᴸᴹᴱ = [ 25.126        0
             0             0    ]
    γᶠ = parse(Float64, γᵢ)

    Aᴸᴹᴱ = [ 0    √(γᶠ)
             0     0. + 0im  ]

    objₑₓ = 0
    
    objₗₘₑ = 0
    
    for df_trn in train_files # loop over initial states

        ρᵗʳⁿ, tᵗʳⁿ = LiPoSID.get_rho_series(data_dir*df_trn*"_2CUT_data.h5", γᵢ)
        
        if length(tᵗʳⁿ) > 1200 end_train = 1200 else end_train = length(tᵗʳⁿ) end
            
        ρᵗʳⁿ = convert(Vector{Matrix{ComplexF64}}, ρᵗʳⁿ[1:end_train])
        
        ρᵗʳⁿₒₚₛ = [DenseOperator(basis,Hermitian(ρₜ)) for ρₜ in ρᵗʳⁿ]
        tᵗʳⁿ = convert(Vector{Float64}, tᵗʳⁿ[1:end_train])
    
        objₑₓ += LiPoSID.simpson_obj(ρᵗʳⁿ, tᵗʳⁿ,  Hˢʸᵐᵇ, [Aˢʸᵐᵇ])
         
        
        ρˡᵐᵉ = LiPoSID.Lindblad_time_evolution(basis, ρᵗʳⁿ[1], tᵗʳⁿ, Hᴸᴹᴱ, [Aᴸᴹᴱ])
        objₗₘₑ += LiPoSID.simpson_obj(ρˡᵐᵉ, tᵗʳⁿ,  Hˢʸᵐᵇ, [Aˢʸᵐᵇ])
            
        
    end # of files (initial states) loop
    
    objₑₓrm = objₑₓ
    objₗₘₑrm = objₗₘₑ
    
    # if γᵢ == γ[1] #"0.079477" 
    #     objₑₓrm = remove_micro_coefs(objₑₓ, 5e-3)
    #     objₗₘₑrm = remove_micro_coefs(objₗₘₑ, 5e-5)
    # elseif  γᵢ == γ[2] #"0.25133" 
    #     objₑₓrm = remove_micro_coefs(objₑₓ, 1e-3)
    #     objₗₘₑrm = remove_micro_coefs(objₗₘₑ, 5e-7)           
    # elseif  γᵢ == γ[3] #"0.79477"
    #     objₑₓrm = remove_micro_coefs(objₑₓ, 5e-4)
    #     objₗₘₑrm = remove_micro_coefs(objₗₘₑ, 1e-6)
    # else 
    #     objₑₓrm = objₑₓ
    #     objₗₘₑrm = objₗₘₑ
    # end
            
    coef_minₑₓ = minimum(abs.(coefficients(objₑₓ)))
    coef_maxₑₓ = maximum(abs.(coefficients(objₑₓ)))
            
    cutoffₑₓ = log10(coef_maxₑₓ)-4

    coefs_gapₑₓ = coef_maxₑₓ/coef_minₑₓ 
            
    coef_minₗₘₑ = minimum(abs.(coefficients(objₗₘₑ)))
    coef_maxₗₘₑ = maximum(abs.(coefficients(objₗₘₑ)))
            
    cutoffₗₘₑ = log10(coef_maxₗₘₑ)-4

    coefs_gapₗₘₑ= coef_maxₗₘₑ/coef_minₗₘₑ 
       
    println("-------------------------------------------")
    println(" POP on ansatz LME simulation")
    println(cutoffₗₘₑ)
            
    #objₗₘₑrm = coefs_gapₗₘₑ > 1e6 ? remove_micro_coefs(objₗₘₑ, cutoffₗₘₑ) : objₗₘₑ
    
    solˢⁱᵈₗₘₑ, best_methodˢⁱᵈₗₘₑ = LiPoSID.sos_min_newton(objₗₘₑrm)

    
    println("Best metod for POP on LME: ", best_methodˢⁱᵈₗₘₑ)
    println("-------------------------------------------")
    
    solₗₘₑ = [e[1], h[1], h[2], a[1], a[2], a[3], b[1], b[3]] => [25.126, 0, 0, 0,  √(γᶠ), 0, 0, 0]
    
    obj_val_lme = convert(Float64, subs(objₗₘₑ, solₗₘₑ))
    
    obj_val_sid_on_lme = convert(Float64, subs(objₗₘₑ, solˢⁱᵈₗₘₑ))
    
    if obj_val_sid_on_lme < obj_val_lme
        println(" simulated LME overfitting")
    end
    
    Hˢⁱᵈₗₘₑ = subs(Hˢʸᵐᵇ, solˢⁱᵈₗₘₑ)
    Aˢⁱᵈₗₘₑ = subs(Aˢʸᵐᵇ, solˢⁱᵈₗₘₑ)
      
    println(" POP on ansatz EXACT Kurt data ")
    println(cutoffₑₓ)
                
    #objₑₓrm = coefs_gapₑₓ > 1e6 ? remove_micro_coefs(objₑₓ, cutoffₑₓ) : objₑₓ
    #objₑₓrm = coefs_gapₑₓ > 1e6 ? remove_micro_coefs(objₑₓ, -3) : objₑₓ
    
    solₑₓ, best_methodₑₓ = LiPoSID.sos_min_newton(objₑₓrm) 
    
    println("Best metod for POP on EXACT: ", best_methodₑₓ)
    
    obj_val_lme_on_exact = convert(Float64, subs(objₑₓ, solₗₘₑ))
    
    obj_val_sid_on_exact = convert(Float64, subs(objₑₓ, solₑₓ))
    
    if obj_val_sid_on_exact < obj_val_lme_on_exact
        println(" Exact data overfitting")
    end

    Hˢⁱᵈₑₓ = subs(Hˢʸᵐᵇ, solₑₓ)
    Aˢⁱᵈₑₓ = subs(Aˢʸᵐᵇ, solₑₓ)
    
    H = DenseOperator(basis, Hˢⁱᵈₑₓ)
    A = DenseOperator(basis, Aˢⁱᵈₑₓ)

    
    h5open(models_dir*models_file,"cw") do fid  # read-write, create file if not existing, preserve existing contents

        γ_group = create_group(fid, "gamma_"*γᵢ)
        
        
        γ_group["coef_min_ex"] = coef_minₑₓ
        γ_group["coef_max_ex"] = coef_maxₑₓ
        γ_group["coef_gap_ex"] = coefs_gapₑₓ
                        
        γ_group["coef_min_lme"] = coef_minₗₘₑ
        γ_group["coef_max_lme"] = coef_maxₗₘₑ
        γ_group["coef_gap_lme"] = coefs_gapₗₘₑ       
                        
        γ_group["obj_val_lme"] = obj_val_lme
        γ_group["obj_val_sid_on_lme"] = obj_val_sid_on_lme
        
        γ_group["obj_val_lme_on_exact"] = obj_val_lme_on_exact
        γ_group["obj_val_sid_on_exact"] = obj_val_sid_on_exact


        γ_group["H_sid_exact"] = convert.(ComplexF64, Hˢⁱᵈₑₓ)
        γ_group["A_sid_exact"] = convert.(ComplexF64, Aˢⁱᵈₑₓ)
        
        γ_group["H_lme"] = convert.(ComplexF64, Hᴸᴹᴱ)
        γ_group["A_lme"] = convert.(ComplexF64, Aᴸᴹᴱ)
        
        γ_group["H_sid_lme"] = convert.(ComplexF64, Hˢⁱᵈₗₘₑ)
        γ_group["A_sid_lme"] = convert.(ComplexF64, Aˢⁱᵈₗₘₑ)

        
    end # of HDF5 writing
    
    
    h5open(tests_dir*tests_data_file_name,"cw") do fid
        γ_group = create_group(fid, "gamma_"*γᵢ)
    end 
    
    for df in test_files # loop over initial states
        
        print(df*" ")

        start_time = time()

        ρₛ, tₛ = LiPoSID.get_rho_series(data_dir*df*"_2CUT_data.h5", γᵢ)
        ρₛ = convert(Vector{Matrix{ComplexF64}}, ρₛ)

        ρᵗˢᵗ = [DenseOperator(basis,Hermitian(ρₜ)) for ρₜ in ρₛ]

        tᵗˢᵗ = convert(Vector{Float64}, tₛ)

        tᴸᴹᴱ, ρᴸᴹᴱ  = timeevolution.master(tᵗˢᵗ, ρᵗˢᵗ[1], DenseOperator(basis,Hᴸᴹᴱ), [DenseOperator(basis,Aᴸᴹᴱ)])
        tˢⁱᵈₗₘ, ρˢⁱᵈₗₘₑ  = timeevolution.master(tᵗˢᵗ, ρᵗˢᵗ[1], DenseOperator(basis,Hˢⁱᵈₗₘₑ), [DenseOperator(basis,Aˢⁱᵈₗₘₑ)])
        tˢⁱᵈₑₓ, ρˢⁱᵈₑₓ  = timeevolution.master(tᵗˢᵗ, ρᵗˢᵗ[1], DenseOperator(basis,Hˢⁱᵈₑₓ), [DenseOperator(basis,Aˢⁱᵈₑₓ)])   
        

        Fᴸᴹᴱₑₓ = [abs(fidelity(ρ₁, ρ₂)) for (ρ₁, ρ₂) in zip(ρᵗˢᵗ, ρᴸᴹᴱ)]
        Fˢⁱᵈᴸᴹᴱₗₘₑ = [abs(fidelity(ρ₁, ρ₂)) for (ρ₁, ρ₂) in zip(ρˢⁱᵈₗₘₑ, ρᴸᴹᴱ)]
        Fˢⁱᵈᵉˣₑₓ = [abs(fidelity(ρ₁, ρ₂)) for (ρ₁, ρ₂) in zip(ρᵗˢᵗ, ρˢⁱᵈₑₓ)]
                    

        h5open(tests_dir*tests_data_file_name,"cw") do fid
            γ_group = open_group(fid, "gamma_"*γᵢ) # open coupling group

            init_state_group = create_group(γ_group, df) # create initial state group
            init_state_group["F_lme_exact"] = convert.(Float64, Fᴸᴹᴱₑₓ)
            init_state_group["F_sidlme_lme"] = convert.(Float64, Fˢⁱᵈᴸᴹᴱₗₘₑ)
            init_state_group["F_sidexact_exact"] = convert.(Float64, Fˢⁱᵈᵉˣₑₓ)
            
        end
                    
        print(minimum(Fᴸᴹᴱₑₓ), minimum(Fˢⁱᵈᴸᴹᴱₗₘₑ), minimum(Fˢⁱᵈᵉˣₑₓ))
        println(" ")
    
    end
                
    println()
    println()
                            

end
# Out:
# POP_NoRmT0LME_trn4_gap_T0_fix-Phi-up_2023-Aug-10_at_12-14.h5
# ---------------
# gamma = 0.079477
# -------------------------------------------
#  POP on ansatz LME simulation
# -1.306163553400041
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 5.9418786526989696e-8
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# Global optimality certified with relative optimality gap 0.000006%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 2.9684260172295893e-10
# Global optimality certified with relative optimality gap 0.000000%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [3.2185312193178106e-9, 3.21847437589895e-9]
# Best metod for POP on LME: scaled_tssos
# -------------------------------------------
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# -1.3058306715553685
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.0012685597411291937
# The local solver failed refining the solution!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.0012684984427339054
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.01175844.
# The relative optimality gap is: 1.048994%.
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.011758448836530988, 0.011758438139850114]
# Best metod for POP on EXACT: scaled_tssos
# State_D1 0.99935352098189480.99940274185808340.9453849121658083
# State_D2 0.99935681686812320.99940646705388450.946453045428224
# State_D3 0.99935661462665140.9994027400221520.6444137813892435
# State_D4 0.99935836191064240.99940646520031030.6485413091424397
# State_D5 0.99916672493201930.99922069554000680.9084630479290371
# State_D6 0.99916671038345820.99922069552060470.9084629227780594
# State_D7 0.99902949097376310.99910477840985720.8293615431022943
# State_D8 0.99903081651906030.99910850476748940.8321533541744124
# State_D9 0.99984294340485670.99988629633003730.9928634420076801
# State_D10 0.99987599922945370.99988629334736870.4650348248731553
# State_D11 0.99935660567504080.99940274001307560.6444071591227608
# State_D12 0.99935835884283440.99940646529394730.6485364217556631
# State_D13 0.99935347663438970.99940274187177980.9453833019380684
# State_D14 0.99935679644617110.99940646708265860.9464504110345826
# State_D15 0.99916730532163460.99922069435655010.7282331168888929
# State_D16 0.99916726653008370.99922069442519310.7282336621867493
# State_D17 0.99902947501450470.99910477844805560.8293548413348621
# State_D18 0.99903081160160560.99910850469564650.8321591719480417
# State_D19 0.99987600398464640.99988629337617860.46502944854940653
# State_D20 0.99984292059548430.99988629634323720.9928619196586757
#
#
# ---------------
# gamma = 0.25133
# -------------------------------------------
#  POP on ansatz LME simulation
# -2.2465703193430797
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 9.483830873658238e-9
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = -1.5732067587815924e-8
# The local solver failed refining the solution!
# No higher TS step of the TSSOS hierarchy!
# val_p = [1.4516388091578847e-11, 0.011119486171395465]
# Best metod for POP on LME: tssos
# -------------------------------------------
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# -2.2461428801721377
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.0014357129346001677
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.0014356934570977761
# The local solver failed refining the solution!
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.001435703183013004, 0.0125429283791334]
# Best metod for POP on EXACT: tssos
#  Exact data overfitting
# State_D1 0.99955152061585510.9999999916823490.9995822233360506
# State_D2 0.99956356530292250.99999999183578750.9995945526091002
# State_D3 0.99983272399378680.99999999168204230.999873910096454
# State_D4 0.99982901753082830.9999999918355010.9998743826482706
# State_D5 0.99964268595998840.99999998923586180.9996828759123422
# State_D6 0.99964306428345340.99999998923588480.9996832573872091
# State_D7 0.999736012691620.99999998754182630.9997851826681785
# State_D8 0.99973592154082720.99999998769530650.9997879103593672
# State_D9 0.99938774542035480.99999999842271740.9993942447864991
# State_D10 0.99989563535763570.9999999984222370.9999031721254757
# State_D11 0.99983272041672590.9999999916820970.9998738086760561
# State_D12 0.99982902090567520.99999999183549860.9998743137234581
# State_D13 0.99955147670823830.99999999168237390.9995824781076877
# State_D14 0.99956306569172870.99999999183578790.9995942384875832
# State_D15 0.99978674445289430.99999998923571140.9998480108185568
# State_D16 0.99978677794349450.99999998923567450.9998483725389465
# State_D17 0.99973587609783330.99999998754187090.9997850833327108
# State_D18 0.99973592477672040.99999998769529050.9997880136629815
# State_D19 0.99989564287510440.99999999842225640.9999031807172502
# State_D20 0.99938728054729950.99999999842272010.9993938162413204
#
#
# ---------------
# gamma = 0.79477
# -------------------------------------------
#  POP on ansatz LME simulation
# -3.1594305069528215
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 9.950038905298429e-8
# Global optimality certified with relative optimality gap 0.000010%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = -5.4224943327802474e-8
# Global optimality certified with relative optimality gap 0.000005%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [1.5857537505326036e-11, 1.5856649326906336e-11]
# Best metod for POP on LME: scaled_tssos
# -------------------------------------------
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# -3.1591074872133382
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.0017838545238601322
# Global optimality certified with relative optimality gap 0.000010%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.0017837445282496694
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.01468737.
# The relative optimality gap is: 1.290362%.
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.0017837498491699577, 0.014687368389805222]
# Best metod for POP on EXACT: tssos
#  Exact data overfitting
# State_D1 0.99809643593360950.99999999999994240.9981112198431552
# State_D2 0.99812929838099360.99999999999994250.9981443509770316
# State_D3 0.99882914759186530.99999999999980930.9988551872249439
# State_D4 0.99883459456136880.99999999999981080.9988605994739191
# State_D5 0.99827581834072980.99999999999991720.9982959903895318
# State_D6 0.99827600330230990.99999999999991670.9982956236276566
# State_D7 0.99850148794723810.99999999999987450.9985259720840205
# State_D8 0.99851388008865440.9999999999998760.9985390936067611
# State_D9 0.99789548674089160.99999999999998790.9979007191534267
# State_D10 0.99899482220359910.99999999999977030.9990175145009735
# State_D11 0.99882898529036370.9999999999998090.998854960047021
# State_D12 0.99883370462813540.99999999999981040.9988602284106737
# State_D13 0.99809719710336380.99999999999994250.9981118877205054
# State_D14 0.9981294057959960.99999999999994340.9981450365305228
# State_D15 0.9987200680942190.99999999999983410.9987465424615108
# State_D16 0.99872051243386570.99999999999983410.9987474701389256
# State_D17 0.99850183419307970.99999999999987420.9985265202961586
# State_D18 0.99851380960311230.99999999999987670.9985384290727882
# State_D19 0.99899505916456450.9999999999997710.999017881520527
# State_D20 0.99789912772182470.99999999999998750.997904423608994
#
#
# ---------------
# gamma = 2.5133
# -------------------------------------------
#  POP on ansatz LME simulation
# -3.9561107114686718
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 4.790432859212246e-8
# Global optimality certified with relative optimality gap 0.000005%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = -7.758240220337246e-9
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.01897177.
# The relative optimality gap is: 1.897178%.
# No higher TS step of the TSSOS hierarchy!
# val_p = [5.212275056010185e-12, 0.01897177269458261]
# Best metod for POP on LME: tssos
# -------------------------------------------
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# -3.9595332771234477
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.002994181244219293
# Global optimality certified with relative optimality gap 0.000006%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.0029941162012150522
# Global optimality certified with relative optimality gap 0.000000%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.0029941189102480337, 0.0029941189102475896]
# Best metod for POP on EXACT: scaled_tssos
#  Exact data overfitting
# State_D1 0.99329503112404440.99999999999998820.9934119531975074
# State_D2 0.9934706527111560.99999999999998960.9935896034585981
# State_D3 0.99485498029184340.99999999999997280.9951034163040186
# State_D4 0.99489418614275260.99999999999997320.9951378214950203
# State_D5 0.99369200299696150.99999999999998510.9938461154772701
# State_D6 0.9936872823793240.99999999999998470.9938289571219789
# State_D7 0.9940840127457260.99999999999997910.9942714142425947
# State_D8 0.99416359770568630.99999999999997980.9943563204302905
# State_D9 0.99309558356315260.99999999999999610.993167639710713
# State_D10 0.99528592577601020.99999999999997050.9955598634023445
# State_D11 0.99485841291352760.99999999999997270.9950994182808687
# State_D12 0.99489358961893970.99999999999997350.9951450629501973
# State_D13 0.99330365132792160.9999999999999880.9934129750347378
# State_D14 0.99346810272975930.99999999999998960.9935943419135199
# State_D15 0.99461544917441620.99999999999997520.994836202187341
# State_D16 0.99461410620583830.99999999999997580.9948473493143606
# State_D17 0.99408471481591740.99999999999997890.9942676206584133
# State_D18 0.99416336919947280.99999999999997990.9943506089594248
# State_D19 0.99528518432713350.99999999999996960.9955593234357545
# State_D20 0.99309568786937410.99999999999999630.9931681555473711
#
#
# ---------------
# gamma = 7.9477
# -------------------------------------------
#  POP on ansatz LME simulation
# -4.886826303518809
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 4.2613970791457736e-8
# Global optimality certified with relative optimality gap 0.000004%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = -2.4025020089772474e-8
# Global optimality certified with relative optimality gap 0.000002%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [6.715461520201416e-13, 6.696587728782788e-13]
# Best metod for POP on LME: scaled_tssos
# -------------------------------------------
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# -4.928645395120415
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.004368025044418254
# Global optimality certified with relative optimality gap 0.000007%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.004367948312692755
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.00436795551105125, 0.0043679555110512636]
# Best metod for POP on EXACT: tssos
#  Exact data overfitting
# State_D1 0.97672504259896330.9999999999999950.9802136123922068
# State_D2 0.97774941730723240.99999999999999620.9811805765401203
# State_D3 0.98101678334406990.99999999999999420.9866204269187719
# State_D4 0.98136148002746780.99999999999999530.986735547699518
# State_D5 0.97803188916246430.99999999999999510.9821106094576634
# State_D6 0.97803188929302030.9999999999999950.9816335165344846
# State_D7 0.97861975148893270.99999999999999390.9831906330082643
# State_D8 0.97924654746507740.9999999999999950.983729106632762
# State_D9 0.9767588002107730.99999999999999790.9795001860511263
# State_D10 0.98246650476308160.99999999999999630.9884912067087475
# State_D11 0.98101678333942080.99999999999999440.986132376514522
# State_D12 0.9813614800610090.99999999999999520.9869089729383914
# State_D13 0.97672504260648490.99999999999999520.9798069104679071
# State_D14 0.97774941742322750.99999999999999640.9813469742574806
# State_D15 0.98047793347612970.99999999999999490.9852821860998544
# State_D16 0.98047793345915250.99999999999999460.9858064591705453
# State_D17 0.97861975147508910.99999999999999360.9827435306046987
# State_D18 0.97924654742324810.99999999999999530.9837446442590891
# State_D19 0.98246650475196750.99999999999999580.9883955605451381
# State_D20 0.97675880035836470.99999999999999740.9794747956395632
#
#
# ---------------
# gamma = 25.133
# -------------------------------------------
#  POP on ansatz LME simulation
# -5.562048255415158
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 1.0269693050309586e-7
# Global optimality certified with relative optimality gap 0.000010%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = -2.726745741533789e-8
# Global optimality certified with relative optimality gap 0.000003%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [1.1857875792387063e-13, 1.1857181902996672e-13]
# Best metod for POP on LME: scaled_tssos
# -------------------------------------------
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# -5.942775041590153
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.005924686356808773
# Global optimality certified with relative optimality gap 0.000003%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.005924647560797386
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.005924653212879575, 0.005924653212879572]
# Best metod for POP on EXACT: scaled_tssos
#  Exact data overfitting
# State_D1 0.91124510601931090.99999999999999760.9850104335886197
# State_D2 0.9119663713130960.9999999999999980.9751516720792269
# State_D3 0.91487693128799170.99999999999999770.9844036834161523
# State_D4 0.93620316440051480.99999999999999810.990576412067763
# State_D5 0.91252155500886210.99999999999999780.9934584751845414
# State_D6 0.91252155500415010.99999999999999720.9494686945949482
# State_D7 0.91883893874244750.99999999999999720.9732811533992793
# State_D8 0.91313353040438890.99999999999999760.9598510978800268
# State_D9 0.91105351726581320.99999999999999830.982200343892873
# State_D10 0.91609992316778430.99999999999999860.9891722922948468
# State_D11 0.91487693128799170.99999999999999710.9443911157558463
# State_D12 0.93620316440096230.99999999999999830.97862641830511
# State_D13 0.91124993894953730.99999999999999740.9360722363331291
# State_D14 0.9119663713146580.99999999999999820.9861731993297612
# State_D15 0.93089575256946620.99999999999999770.9616061887676149
# State_D16 0.93089575257037750.99999999999999790.9923952214978327
# State_D17 0.91883893874296220.99999999999999680.923483143246687
# State_D18 0.91313353040335010.9999999999999980.9827353992296987
# State_D19 0.91609992316931390.99999999999999820.9795887260225113
# State_D20 0.91105351726791620.99999999999999830.9729650742886136
#
#
# ---------------
# gamma = 79.477
# -------------------------------------------
#  POP on ansatz LME simulation
# -5.303000641653664
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 1.0425733133098619e-7
# Global optimality certified with relative optimality gap 0.000010%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = -2.9665156443104955e-9
# Global optimality certified with relative optimality gap 0.000000%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [8.770345560904502e-13, 8.77048433878258e-13]
# Best metod for POP on LME: tssos
# -------------------------------------------
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# -6.695362510837062
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.0019738002308099314
# Global optimality certified with relative optimality gap 0.001842%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.0019737932422771204
# Global optimality certified with relative optimality gap 0.001846%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.001992219103772798, 0.001992254392619867]
# Best metod for POP on EXACT: tssos
#  Exact data overfitting
# State_D1 0.78829457485258740.99999999999999840.9991169363006824
# State_D2 0.7883295725234580.99999999999999790.9995717648143699
# State_D3 0.7873772496849930.99999999999999790.9991884421567065
# State_D4 0.78746555872586730.99999999999999790.9995078788627128
# State_D5 0.78841323589288610.99999999999999790.9994339599824615
# State_D6 0.78841323589162440.99999999999999790.9993220223075939
# State_D7 0.78800765942735440.99999999999999820.9977397132611057
# State_D8 0.78804633541218350.99999999999999810.9988297628813839
# State_D9 0.78805632530926660.99999999999999820.9993108835746162
# State_D10 0.78697585469908350.99999999999999820.9994235544764112
# State_D11 0.78737724968690370.9999999999999980.9990274862990678
# State_D12 0.78746555872524150.99999999999999790.9994338243308778
# State_D13 0.78829457485575430.99999999999999740.9984447482722294
# State_D14 0.78832957252473580.99999999999999780.9989943976770921
# State_D15 0.78771534874778090.99999999999999760.9996456852551345
# State_D16 0.78771534874461310.9999999999999980.9996297829301102
# State_D17 0.78800765942480820.9999999999999980.9974042859261141
# State_D18 0.78804633541219770.99999999999999780.9991324117316933
# State_D19 0.78697585470035480.99999999999999820.9994394207875955
# State_D20 0.78805632530801550.99999999999999830.9988099094249738
#
#
# ---------------
# gamma = 251.33
# -------------------------------------------
#  POP on ansatz LME simulation
# -4.661743316117351
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 2.1484826371094082e-8
# Global optimality certified with relative optimality gap 0.000002%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = -1.3311929016316221e-8
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [1.3224976669334865e-12, 1.3224976669334865e-12]
# Best metod for POP on LME: tssos
# -------------------------------------------
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# -5.820051639850056
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.015071847987465747
# Global optimality certified with relative optimality gap 0.000831%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.015071741450758059
# Global optimality certified with relative optimality gap 0.000847%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.015080159441124142, 0.01508021442715729]
# Best metod for POP on EXACT: tssos
#  Exact data overfitting
# State_D1 0.73688039058929820.99999999999999570.996612373442309
# State_D2 0.73688971180127630.99999999999999540.9948370321992873
# State_D3 0.73392638838295920.99999999999999590.9960019468201047
# State_D4 0.73394585204433690.99999999999999630.9942442101215142
# State_D5 0.73822607234890770.99999999999999580.9939535254860168
# State_D6 0.73822607234891480.9999999999999960.9928413683940547
# State_D7 0.73977887159394380.99999999999999570.9997100027706585
# State_D8 0.73981430787393880.99999999999999560.9987515533682909
# State_D9 0.73435691393744280.99999999999999570.9947234835305239
# State_D10 0.72932820338321790.99999999999999660.9936758956000673
# State_D11 0.73392638838381130.99999999999999590.9935403561863292
# State_D12 0.73394585204461990.99999999999999580.9949317951057971
# State_D13 0.73688039059007470.99999999999999480.9955750246929211
# State_D14 0.73688971180127630.99999999999999560.9956969586332484
# State_D15 0.73672455527686750.99999999999999580.9923698794690408
# State_D16 0.73672455527884740.99999999999999620.9935376219699686
# State_D17 0.73977887157479960.9999999999999950.9964814903074435
# State_D18 0.73981430787000060.9999999999999960.9981998013562982
# State_D19 0.72932820338394840.99999999999999640.9936038912102819
# State_D20 0.7343569139367490.99999999999999530.9948790244284063

# %%
tests_data_file_name
# Out:
# "POP_NoRmT0LME_trn4_gap_tst20_T0_fix-Phi-up_2023-Aug-10_at_12-14.h5"

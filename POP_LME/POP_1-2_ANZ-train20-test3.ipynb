# %% [markdown]
# ### Full POP model works

# %%
include("LiPoSID.jl")
using QuantumOptics
basis = NLevelBasis(2)
using DynamicPolynomials
using LinearAlgebra
using Dates
using HDF5

# %% [markdown]
# Consider simple Lindblad master equation with just one dissipator:
#
# $m
#      \frac{d\rho}{dt} = - \frac{i}{\hbar}[H, \rho]+\gamma\left[A \rho A^\dagger - \frac{1}{2}\left\{ A^\dagger A, \rho \right\} \right]
# $,
#
# where Hamiltonian is hermitian with one of the diagonal elemnets set to zero
#
#
# $
#     H = \begin{pmatrix} e_1 & h_1 - i h_2 \\ h_1 + i h_2 & 0
#    \end{pmatrix}
# $
#
#  we can possibly look for jump operator of the form:
#
# $
# A = \begin{pmatrix} a_{11} + i b_{11} & a_{12} \\ a_{21} + i b_{21} & -a_{11} - i b_{11}
#    \end{pmatrix}
# $
#
# or
#
# $
# A = \begin{pmatrix} a_{11} & a_{12} + i b_{12}  \\ a_{21} + i b_{21} & -a_{11}
#    \end{pmatrix}
# $
#
# or assuming zero temperature
#
# $
# A = \begin{pmatrix} a_{11} + i b_{11} & a_{12}   \\ 0 & -a_{11} - i b_{11}
#    \end{pmatrix}
# $

# %%
@polyvar e[1]
@polyvar h[1:2]


Hˢʸᵐᵇ = [ e[1]               h[1] - im*h[2]
          h[1] + im*h[2]     0.             ]
# Out:
# 2×2 Matrix{Polynomial{true, ComplexF64}}:
#  e₁                  h₁ + (0.0-1.0im)h₂
#  h₁ + (0.0+1.0im)h₂  0.0+0.0im

# %%
method = "_fix-Phi-up_"

@polyvar a[1:4]
@polyvar b[1:4]


#"just-zero-down_ "

#Aˢʸᵐᵇ = [ a[1]+im*b[1]      a[2] + im*b[2] 
#          0                -a[1]-im*b[1]  ]


#"fix-Phi-up_: "

Aˢʸᵐᵇ = [ a[1]+im*b[1]      a[2]
          a[3] + im*b[3]   -a[1]-im*b[1] ]


#"zero Temperature and fix-Phi-up_: " zero_down_fix-Phi-up_

#Aˢʸᵐᵇ = [ a[1]+im*b[1]      a[2]
#          0                -a[1]-im*b[1] ]

#"zero Temperature and fix-Phi-diag_: "

#Aˢʸᵐᵇ = [ a[1]     a[2]+im*b[2] 
#          0        -a[1]        ]
# Out:
# 2×2 Matrix{Polynomial{true, Complex{Int64}}}:
#  a₁ + (0+1im)b₁  a₂
#  a₃ + (0+1im)b₃  -a₁ + (0-1im)b₁

# %%
pwd()
# Out:
# "/home/zah/POP23"

# %%
parentdir = pwd()
data_dir = parentdir*"/DATA/"
println(data_dir)

models_dir = parentdir*"/MODELS/"
tests_dir = parentdir*"/TESTS/"

dodeca_files = ["State_D"*string(n) for n=1:20];

basis_files = ["State_B"*string(n) for n=1:4];
# Out:
# /home/zah/POP23/DATA/

# %%
all_files = vcat(dodeca_files, basis_files)
train_files = dodeca_files
test_files = basis_files[2:4];

# %% [markdown]
# ### Train models loop

# %%
date_and_time_string =  string(Dates.format(now(), "yyyy-u-dd_at_HH-MM"))
models_file = "POP_fit_trn20_"*method*date_and_time_string * ".h5"
tests_data_file_name = "POP_fit_trn20_tst3_"*method*date_and_time_string * ".h5"

println(models_file)

γ = [ "0.079477",  "0.25133", "0.79477", "2.5133", "7.9477", "25.133", "79.477", "251.33"]

for γᵢ in γ
    
    println("---------------")
    println("gamma = ", γᵢ)
    
    Hᴸᴹᴱ = [ 25.126        0
             0             0    ]
    γᶠ = parse(Float64, γᵢ)

    Aᴸᴹᴱ = [ 0    √(γᶠ)
             0     0. + 0im  ]

    objₑₓ = 0
    
    objₗₘₑ = 0
    
    for df_trn in train_files # loop over initial states

        ρᵗʳⁿ, tᵗʳⁿ = LiPoSID.get_rho_series(data_dir*df_trn*"_2CUT_data.h5", γᵢ)
        ρᵗʳⁿ = convert(Vector{Matrix{ComplexF64}}, ρᵗʳⁿ)
        ρᵗʳⁿₒₚₛ = [DenseOperator(basis,Hermitian(ρₜ)) for ρₜ in ρᵗʳⁿ]
        tᵗʳⁿ = convert(Vector{Float64}, tᵗʳⁿ)
    
        objₑₓ += LiPoSID.simpson_obj(ρᵗʳⁿ, tᵗʳⁿ,  Hˢʸᵐᵇ, [Aˢʸᵐᵇ])
            
        
        ρˡᵐᵉ = LiPoSID.Lindblad_time_evolution(basis, ρᵗʳⁿ[1], tᵗʳⁿ, Hᴸᴹᴱ, [Aᴸᴹᴱ])
        objₗₘₑ += LiPoSID.simpson_obj(ρˡᵐᵉ, tᵗʳⁿ,  Hˢʸᵐᵇ, [Aˢʸᵐᵇ])
        
    end # of files (initial states) loop
       
    println("-------------------------------------------")
    println(" POP on ansatz LME simulation")
    
    solˢⁱᵈₗₘₑ, best_methodₐₙ = LiPoSID.sos_min_newton(objₗₘₑ) 
    
    println("Best metod for POP on LME: ", best_methodₐₙ)
    println("-------------------------------------------")
    
    solₗₘₑ = [e[1], h[1], h[2], a[1], a[2], a[3], b[1], b[3]] => [25.126, 0, 0, 0,  √(γᶠ), 0, 0, 0]
    
    obj_val_lme = convert(Float64, subs(objₗₘₑ, solₗₘₑ))
    
    obj_val_sid_on_lme = convert(Float64, subs(objₗₘₑ, solˢⁱᵈₗₘₑ))
    
    if obj_val_sid_on_lme < obj_val_lme
        println(" simulated LME overfitting")
    end
    
    Hˢⁱᵈₗₘₑ = subs(Hˢʸᵐᵇ, solˢⁱᵈₗₘₑ)
    Aˢⁱᵈₗₘₑ = subs(Aˢʸᵐᵇ, solˢⁱᵈₗₘₑ)
      
    println(" POP on ansatz EXACT Kurt data ")
    
    solₑₓ, best_methodₑₓ = LiPoSID.sos_min_newton(objₑₓ) 
    
    println("Best metod for POP on EXACT: ", best_methodₑₓ)
    
    obj_val_lme_on_exact = convert(Float64, subs(objₑₓ, solₗₘₑ))
    
    obj_val_sid_on_exact = convert(Float64, subs(objₑₓ, solₑₓ))
    
    if obj_val_sid_on_exact < obj_val_lme_on_exact
        println(" Exact data overfitting")
    end

    Hˢⁱᵈₑₓ = subs(Hˢʸᵐᵇ, solₑₓ)
    Aˢⁱᵈₑₓ = subs(Aˢʸᵐᵇ, solₑₓ)
    
    H = DenseOperator(basis, Hˢⁱᵈₑₓ)
    A = DenseOperator(basis, Aˢⁱᵈₑₓ)

    
    h5open(models_dir*models_file,"cw") do fid  # read-write, create file if not existing, preserve existing contents

        γ_group = create_group(fid, "gamma_"*γᵢ)
        
        
        γ_group["obj_val_lme"] = obj_val_lme
        γ_group["obj_val_sid_on_lme"] = obj_val_sid_on_lme
        
        γ_group["obj_val_lme_on_exact"] = obj_val_lme_on_exact
        γ_group["obj_val_sid_on_exact"] = obj_val_sid_on_exact

        γ_group["H_sid_exact"] = convert.(ComplexF64, Hˢⁱᵈₑₓ)
        γ_group["A_sid_exact"] = convert.(ComplexF64, Aˢⁱᵈₑₓ)
        
        γ_group["H_lme"] = convert.(ComplexF64, Hᴸᴹᴱ)
        γ_group["A_lme"] = convert.(ComplexF64, Aᴸᴹᴱ)
        
        γ_group["H_sid_lme"] = convert.(ComplexF64, Hˢⁱᵈₗₘₑ)
        γ_group["A_sid_lme"] = convert.(ComplexF64, Aˢⁱᵈₗₘₑ)

        
    end # of HDF5 writing
    
    
    h5open(tests_dir*tests_data_file_name,"cw") do fid
        γ_group = create_group(fid, "gamma_"*γᵢ)
    end 
    
    for df in test_files # loop over initial states
        
        print(df*" ")

        start_time = time()

        ρₛ, tₛ = LiPoSID.get_rho_series(data_dir*df*"_2CUT_data.h5", γᵢ)
        ρₛ = convert(Vector{Matrix{ComplexF64}}, ρₛ)

        ρᵗˢᵗ = [DenseOperator(basis,Hermitian(ρₜ)) for ρₜ in ρₛ]

        tᵗˢᵗ = convert(Vector{Float64}, tₛ)

        tᴸᴹᴱ, ρᴸᴹᴱ  = timeevolution.master(tᵗˢᵗ, ρᵗˢᵗ[1], DenseOperator(basis,Hᴸᴹᴱ), [DenseOperator(basis,Aᴸᴹᴱ)])
        tˢⁱᵈₗₘ, ρˢⁱᵈₗₘₑ  = timeevolution.master(tᵗˢᵗ, ρᵗˢᵗ[1], DenseOperator(basis,Hˢⁱᵈₗₘₑ), [DenseOperator(basis,Aˢⁱᵈₗₘₑ)])
        tˢⁱᵈₑₓ, ρˢⁱᵈₑₓ  = timeevolution.master(tᵗˢᵗ, ρᵗˢᵗ[1], DenseOperator(basis,Hˢⁱᵈₑₓ), [DenseOperator(basis,Aˢⁱᵈₑₓ)])   
        

        Fᴸᴹᴱₑₓ = [abs(fidelity(ρ₁, ρ₂)) for (ρ₁, ρ₂) in zip(ρᵗˢᵗ, ρᴸᴹᴱ)]
        Fˢⁱᵈᴸᴹᴱₗₘₑ = [abs(fidelity(ρ₁, ρ₂)) for (ρ₁, ρ₂) in zip(ρˢⁱᵈₗₘₑ, ρᴸᴹᴱ)]
        Fˢⁱᵈᵉˣₑₓ = [abs(fidelity(ρ₁, ρ₂)) for (ρ₁, ρ₂) in zip(ρᵗˢᵗ, ρˢⁱᵈₑₓ)]
                    

        h5open(tests_dir*tests_data_file_name,"cw") do fid
            γ_group = open_group(fid, "gamma_"*γᵢ) # open coupling group

            init_state_group = create_group(γ_group, df) # create initial state group
            init_state_group["F_lme_exact"] = convert.(Float64, Fᴸᴹᴱₑₓ)
            init_state_group["F_sidlme_lme"] = convert.(Float64, Fˢⁱᵈᴸᴹᴱₗₘₑ)
            init_state_group["F_sidexact_exact"] = convert.(Float64, Fˢⁱᵈᵉˣₑₓ)
            
        end
                    
        print(minimum(Fᴸᴹᴱₑₓ), minimum(Fˢⁱᵈᴸᴹᴱₗₘₑ), minimum(Fˢⁱᵈᵉˣₑₓ))
        println(" ")
    
    end
                
    println()
    println()
                            

end
# Out:
# POP_fit_trn20__fix-Phi-up_2023-Aug-03_at_23-19.h5
# ---------------
# gamma = 0.079477
# -------------------------------------------
#  POP on ansatz LME simulation
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 2.6412659669253523e-8
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# termination status: INFEASIBLE
# solution status: NO_SOLUTION
# optimum = -3.7808930565504544
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00000002.
# The relative optimality gap is: 378.089308%.
# No higher TS step of the TSSOS hierarchy!
# val_p = [2.0514107745839283e-8, 2.0515471987891942e-8]
# Best metod for POP on LME: tssos
# -------------------------------------------
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.0032331886710609504
# Global optimality certified with relative optimality gap 0.000000%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.003233243393407522
# Global optimality certified with relative optimality gap 0.000006%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.003233187657315284, 0.003233187657315284]
# Best metod for POP on EXACT: tssos
#  Exact data overfitting
# State_B2 0.99999789107944310.99999999327369740.9997344446370666
# State_B3 0.99902848201989710.99910652110661660.9948756547711997
# State_B4 0.99904564980817590.99910686899106670.9948687321100511
#
#
# ---------------
# gamma = 0.25133
# -------------------------------------------
#  POP on ansatz LME simulation
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 5.778686283190645e-9
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# termination status: INFEASIBLE
# solution status: NO_SOLUTION
# optimum = -3.1968194155531453
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00000000.
# The relative optimality gap is: 319.681942%.
# No higher TS step of the TSSOS hierarchy!
# val_p = [1.1294787327642553e-10, 1.1323209037072957e-10]
# Best metod for POP on LME: tssos
# -------------------------------------------
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.005949132413594483
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.005949122954975402
# Global optimality certified with relative optimality gap 0.000000%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.005949124421476881, 0.005949124421590568]
# Best metod for POP on EXACT: tssos
#  Exact data overfitting
# State_B2 0.99990521021476930.99999999999847790.9932836857476854
# State_B3 0.99973474290172170.99999998762003720.991564719237755
# State_B4 0.99974081616217750.99999998767357220.9915644170569665
#
#
# ---------------
# gamma = 0.79477
# -------------------------------------------
#  POP on ansatz LME simulation
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 2.6097270970589387e-8
# The local solver failed refining the solution!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = -4.4229588514448704e-8
# Global optimality certified with relative optimality gap 0.000004%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.06328036182578245, 1.2016698747174814e-10]
# Best metod for POP on LME: scaled_tssos
# -------------------------------------------
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.006686324935706393
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.006686246550632837
# Global optimality certified with relative optimality gap 0.000007%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.006686311932369904, 0.006686311932384115]
# Best metod for POP on EXACT: tssos
#  Exact data overfitting
# State_B2 0.99902367146566640.99999999999940150.9951790855272987
# State_B3 0.99850687107994680.99999999999973640.9948029477508435
# State_B4 0.99851440128695380.99999999999973580.9947989174904396
#
#
# ---------------
# gamma = 2.5133
# -------------------------------------------
#  POP on ansatz LME simulation
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 1.2465373633634096e-8
# The local solver failed refining the solution!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = -1.923490829751535e-8
# Global optimality certified with relative optimality gap 0.000002%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.09171930564093156, 3.6061820196664485e-11]
# Best metod for POP on LME: scaled_tssos
# -------------------------------------------
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.009385594694637043
# Global optimality certified with relative optimality gap 0.000033%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.00938521557258664
# Global optimality certified with relative optimality gap 0.000005%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.009385269688968911, 0.009385269688967135]
# Best metod for POP on EXACT: scaled_tssos
#  Exact data overfitting
# State_B2 0.99536177961912650.99999999999994390.9979865084462751
# State_B3 0.99412255701123080.99999999999996670.9978547039439285
# State_B4 0.99415926308262140.99999999999996660.9978520780520982
#
#
# ---------------
# gamma = 7.9477
# -------------------------------------------
#  POP on ansatz LME simulation
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 3.730857623540662e-8
# The local solver failed refining the solution!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = -5.366717240701771e-9
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.09096203764693123, 4.297007194509206e-12]
# Best metod for POP on LME: scaled_tssos
# -------------------------------------------
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.012250833257395104
# Global optimality certified with relative optimality gap 0.000007%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.012250738445916398
# Global optimality certified with relative optimality gap 0.000003%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.012250764240520629, 0.012250764240520295]
# Best metod for POP on EXACT: scaled_tssos
#  Exact data overfitting
# State_B2 0.98269658224740360.99999999999999610.9996425184422001
# State_B3 0.97893747066545530.99999999999999370.999013445630696
# State_B4 0.97923034528223310.9999999999999940.999141350425204
#
#
# ---------------
# gamma = 25.133
# -------------------------------------------
#  POP on ansatz LME simulation
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 1.2957665748951884e-8
# The local solver failed refining the solution!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = -1.6335884297781266e-8
# Global optimality certified with relative optimality gap 0.000002%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.08639124364455796, 5.22221155208058e-13]
# Best metod for POP on LME: scaled_tssos
# -------------------------------------------
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.018327300351885418
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.018327237685801634
# Global optimality certified with relative optimality gap 0.000005%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.018327286935678373, 0.018327286935678408]
# Best metod for POP on EXACT: tssos
#  Exact data overfitting
# State_B2 0.93747014433823160.99999999999999940.9998864224308495
# State_B3 0.91282885455376560.99999999999999720.9894901462922454
# State_B4 0.91342780427183190.99999999999999790.9941210700882364
#
#
# ---------------
# gamma = 79.477
# -------------------------------------------
#  POP on ansatz LME simulation
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 2.2449339048857685e-7
# The local solver failed refining the solution!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = -1.2239086943152629e-8
# Global optimality certified with relative optimality gap 0.000001%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.2465395653189995, 4.343247983484844e-12]
# Best metod for POP on LME: scaled_tssos
# -------------------------------------------
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.008943743111318469
# Global optimality certified with relative optimality gap 0.000020%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.00894353961980639
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.00934843.
# The relative optimality gap is: 0.040489%.
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.008943543266832343, 0.009348427843553091]
# Best metod for POP on EXACT: tssos
#  Exact data overfitting
# State_B2 0.7869365986965220.99999999999999960.9994509935670086
# State_B3 0.78799398575990760.99999999999999820.9995665431312342
# State_B4 0.78812617635170670.99999999999999820.9997749795262515
#
#
# ---------------
# gamma = 251.33
# -------------------------------------------
#  POP on ansatz LME simulation
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 1.515366533336678e-9
# Global optimality certified with relative optimality gap 0.000000%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = -1.540834321560506e-9
# Global optimality certified with relative optimality gap 0.000028%!
# No higher TS step of the TSSOS hierarchy!
# val_p = [6.610045844013257e-12, 2.7366687604946094e-7]
# Best metod for POP on LME: tssos
# -------------------------------------------
#  simulated LME overfitting
#  POP on ansatz EXACT Kurt data
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.06554067852142362
# Global optimality certified with relative optimality gap 0.000008%!
# No higher TS step of the TSSOS hierarchy!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# optimum = 0.0655405658376918
# Found a locally optimal solution by Ipopt, giving an upper bound: 0.06812287.
# The relative optimality gap is: 0.258231%.
# No higher TS step of the TSSOS hierarchy!
# val_p = [0.06554060076727397, 0.06812287478604322]
# Best metod for POP on EXACT: tssos
#  Exact data overfitting
# State_B2 0.72847859237988370.99999999999999670.9961826846265738
# State_B3 0.73983488473540450.99999999999999250.9984280032328623
# State_B4 0.73979594803965290.99999999999999560.9961704709266428

# %%
tests_data_file_name
# Out:
# "POP_fit_trn20_tst3__fix-Phi-up_2023-Aug-03_at_23-19.h5"
